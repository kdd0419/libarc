# %%
import json
import csv

# %%
import libarc as arc
# Out:
# static_uuid: 41EA0069-AED7-4902-BF82-1E03793146A7
# auth_str:

# %%
dir(arc)
# Out:
# ['__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  'auth_str',
#  'base64',
#  'calc_score',
#  'char_awaken',
#  'char_upgrade',
#  'frag_friend_slot',
#  'frag_stamina',
#  'friend_add',
#  'friend_del',
#  'get_character_info',
#  'get_map_token',
#  'get_score_token',
#  'get_world_map',
#  'headers',
#  'json',
#  'post_score',
#  'rank_friend',
#  'rank_me',
#  'rank_world',
#  'requests',
#  'set_character',
#  'set_map',
#  'static_uuid',
#  'user_info',
#  'user_login',
#  'user_register',
#  'uuid']

# %%
help(arc.rank_me)
# Out:
# Help on function rank_me in module libarc:
#
# rank_me(song_id, difficulty, start, limit)
#     usage:
#         song_id: please check song_id.json
#         dificcuty: 0=pst, 1=prs, 2=ftr
#         start: larger start, higher rank (start from you: start=0)
#         limit: returns at most 101 records when limit>=100
#         in theory, you can get the whole rank list via rank_me
#     example:
#         rank_me('themessage', 2, 0, 10)

# %%
from getpass import getpass

# %%
user_name = input('input username > ')
user_pw = getpass('input PW > ')
# Out:
# input username > k3id
# input PW > ········

# %%
arc.user_login(user_name, user_pw, change_device_id=True)
# Out:
# new_uuid: 6EF7E31F-851F-46B1-AA7A-F10E1217E2CE
# {
#     "access_token": "+bFrHtO4rvH00RaBpmVnjsPlSmsOizXidNGY4yIL7p4=",
#     "token_type": "Bearer",
#     "success": true
# }
# new_auth: Bearer +bFrHtO4rvH00RaBpmVnjsPlSmsOizXidNGY4yIL7p4=
# {'access_token': '+bFrHtO4rvH00RaBpmVnjsPlSmsOizXidNGY4yIL7p4=',
#  'token_type': 'Bearer',
#  'success': True}

# %%
with open('songlist.json', 'r', encoding="utf-8") as songlist_f:
    songlist = json.loads(songlist_f.read())

# %%
songlist = songlist['songs']
songlist
# Out:
# [{'id': 'sayonarahatsukoi',
#   'title_localized': {'en': 'Sayonara Hatsukoi'},
#   'artist': 'REDSHiFT',
#   'bpm': '178',
#   'bpm_base': 178,
#   'set': 'base',
#   'purchase': '',
#   'audioPreview': 44494,
#   'audioPreviewEnd': 76853,
#   'side': 0,
#   'bg': '',
#   'date': 1487980800,
#   'difficulties': [{'ratingClass': 0,
#     'chartDesigner': 'Nitro',
#     'jacketDesigner': '',
#     'rating': 1},
#    {'ratingClass': 1,
#     'chartDesigner': 'Nitro',
#     'jacketDesigner': '',
#     'rating': 4},
#    {'ratingClass': 2,
#     'chartDesigner': 'Toaster',
#     'jacketDesigner': '',
#     'rating': 6}]},
#  {'id': 'lostcivilization',
#   'title_localized': {'en': 'Lost Civilization'},
#   'artist': 'Laur vs CK',
#   'bpm': '75 - 210',
#   'bpm_base': 210,
#   'set': 'base',
#   'purchase': '',
#   'audioPreview': 81142,
#   'audioPreviewEnd': 110285,
#   'side': 1,
#   'bg': '',
#   'date': 1487980808,
#   'difficulties': [{'ratingClass': 0,
#     'chartDesigner': 'Toaster',
#     'jacketDesigner': '',
#     'rating': 4},
#    {'ratingClass': 1,
#     'chartDesigner': 'Toaster',
#     'jacketDesigner': '',
#     'rating': 7},
#    {'ratingClass': 2,
#     'chartDesigner': 'Toaster',
#     'jacketDesigner': '',
#     'rating': 9}]},
#  {'id': 'goodtek',
#   'title_localized': {'en': 'GOODTEK (Arcaea Edit)'},
#   'artist': 'EBIMAYO',
#   'bpm': '190',
#   'bpm_base': 190,
#   'set': 'base',
#   'purchase': '',
#   'audioPreview': 80842,
#   'audioPreviewEnd': 111157,
#   'side': 0,
#   'world_unlock': True,
#   'bg': '',
#   'date': 1487980809,
#   'difficulties': [{'ratingClass': 0,
#     'chartDesigner': 'Nitro',
#     'jacketDesigner': 'Koyama Mai',
#     'rating': 4},
#    {'ratingClass': 1,
#     'chartDesigner': 'Nitro',
#     'jacketDesigner': 'Koyama Mai',
#     'rating': 6},
#    {'ratingClass': 2,
#     'chartDesigner': 'Nitro',
#     'jacketDesigner': 'Koyama Mai',
#     'rating': 9}]},
#  {'id': 'viyella',
#   'title_localized': {'en': 'cry of viyella'},
#   'artist': 'Laur',
#   'bpm': '75 - 180',
#   'bpm_base': 180,
#   'set': 'core',
#   'purchase': 'core',
#   'audioPreview': 71551,
#   'audioPreviewEnd': 103551,
#   'side': 1,
#   'bg': '',
#   'remote_dl': True,
#   'date': 1487980811,
#   'difficulties': [{'ratingClass': 0,
#     'chartDesigner': 'Toaster',
#     'jacketDesigner': '',
#     'rating': 3},
#    {'ratingClass': 1,
#     'chartDesigner': 'Toaster',
#     'jacketDesigner': '',
#     'rating': 6},
#    {'ratingClass': 2,
#     'chartDesigner': 'Toaster',
#     'jacketDesigner': '',
#     'rating': 8}]},
#  {'id': 'rise',
#   'title_localized': {'en': 'Rise'},
#   'artist': 'Combatplayer',
#   'bpm': '140',
#   'bpm_base': 140,
#   'set': 'base',
#   'purchase': '',
#   'audioPreview': 54910,
#   'audioPreviewEnd': 82338,
#   'side': 0,
#   'bg': '',
#   'date': 1487980803,
#   'difficulties': [{'ratingClass': 0,
#     'chartDesigner': 'Nitro',
#     'jacketDesigner': '',
#     'rating': 2},
#    {'ratingClass': 1,
#     'chartDesigner': 'Nitro',
#     'jacketDesigner': '',
#     'rating': 4},
#    {'ratingClass': 2,
#     'chartDesigner': 'Nitro',
#     'jacketDesigner': '',
#     'rating': 7}]},
#  {'id': 'lucifer',
#   'title_localized': {'en': 'Lucifer'},
#   'artist': 'chitose',
#   'bpm': '165',
#   'bpm_base': 165,
#   'set': 'base',
#   'purchase': '',
#   'audioPreview': 46545,
#   'audioPreviewEnd': 81454,
#   'side': 1,
#   'world_unlock': True,
#   'bg': '',
#   'date': 1487980804,
#   'difficulties': [{'ratingClass': 0,
#     'chartDesigner': 'Nitro',
#     'jacketDesigner': '',
#     'rating': 3},
#    {'ratingClass': 1,
#     'chartDesigner': 'Nitro',
#     'jacketDesigner': '',
#     'rating': 5},
#    {'ratingClass': 2,
#     'chartDesigner': 'Nitro',
#     'jacketDesigner': '',
#     'rating': 8}]},
#  {'id': 'fairytale',
#   'title_localized': {'en': 'Fairytale'},
#   'artist': 'chitose',
#   'bpm': '189',
#   'bpm_base': 189,
#   'set': 'base',
#   'purchase': '',
#   'audioPreview': 36399,
#   'audioPreviewEnd': 68780,
#   'side': 0,
#   'bg': '',
#   'date': 1487980801,
#   'difficulties': [{'ratingClass': 0,
#     'chartDesigner': 'Toaster',
#     'jacketDesigner': '',
#     'rating': 1},
#    {'ratingClass': 1,
#     'chartDesigner': 'Toaster',
#     'jacketDesigner': '',
#     'rating': 3},
#    {'ratingClass': 2,
#     'chartDesigner': 'Toaster',
#     'jacketDesigner': '',
#     'rating': 7}]},
#  {'id': 'hearditsaid',
#   'title_localized': {'en': "I've heard it said"},
#   'artist': 'Combatplayer',
#   'bpm': '165',
#   'bpm_base': 165,
#   'set': 'core',
#   'purchase': 'core',
#   'audioPreview': 49454,
#   'audioPreviewEnd': 72727,
#   'side': 0,
#   'bg': '',
#   'remote_dl': True,
#   'date': 1487980812,
#   'difficulties': [{'ratingClass': 0,
#     'chartDesigner': 'Toaster',
#     'jacketDesigner': '',
#     'rating': 3},
#    {'ratingClass': 1,
#     'chartDesigner': 'Toaster',
#     'jacketDesigner': '',
#     'rating': 6},
#    {'ratingClass': 2,
#     'chartDesigner': 'Toaster',
#     'jacketDesigner': '',
#     'rating': 8}]},
#  {'id': 'babaroque',
#   'title_localized': {'en': 'Babaroque'},
#   'artist': 'cYsmix',
#   'bpm': '136',
#   'bpm_base': 136,
#   'set': 'base',
#   'purchase': '',
#   'audioPreview': 64411,
#   'audioPreviewEnd': 92647,
#   'side': 0,
#   'world_unlock': True,
#   'bg': '',
#   'date': 1487980807,
#   'difficulties': [{'ratingClass': 0,
#     'chartDesigner': 'Toaster',
#     'jacketDesigner': '',
#     'rating': 3},
#    {'ratingClass': 1,
#     'chartDesigner': 'Toaster',
#     'jacketDesigner': '',
#     'rating': 6},
#    {'ratingClass': 2,
#     'chartDesigner': 'Toaster',
#     'jacketDesigner': '',
#     'rating': 8}]},
#  {'id': 'memoryfactory',
#   'title_localized': {'en': 'memoryfactory.lzh'},
#   'artist': 'Frums',
#   'bpm': '100',
#   'bpm_base': 180,
#   'set': 'core',
#   'purchase': 'core',
#   'audioPreview': 50400,
#   'audioPreviewEnd': 79200,
#   'side': 0,
#   'bg': '',
#   'remote_dl': True,
#   'date': 1487980813,
#   'difficulties': [{'ratingClass': 0,
#     'chartDesigner': 'Nitro',
#     'jacketDesigner': 'Frums',
#     'rating': 2},
#    {'ratingClass': 1,
#     'chartDesigner': 'Nitro',
#     'jacketDesigner': 'Frums',
#     'rating': 5},
#    {'ratingClass': 2,
#     'chartDesigner': 'Nitro',
#     'jacketDesigner': 'Frums',
#     'rating': 8}]},
#  {'id': 'snowwhite',
#   'title_localized': {'en': 'Snow White'},
#   'artist': 'Puru',
#   'bpm': '150',
#   'bpm_base': 150,
#   'set': 'base',
#   'purchase': '',
#   'audioPreview': 24400,
#   'audioPreviewEnd': 57600,
#   'side': 0,
#   'bg': '',
#   'date': 1487980805,
#   'difficulties': [{'ratingClass': 0,
#     'chartDesigner': 'Toaster',
#     'jacketDesigner': '',
#     'rating': 2},
#    {'ratingClass': 1,
#     'chartDesigner': 'Toaster',
#     'jacketDesigner': '',
#     'rating': 5},
#    {'ratingClass': 2,
#     'chartDesigner': 'Toaster',
#     'jacketDesigner': '',
#     'rating': 8}]},
#  {'id': 'relentless',
#   'title_localized': {'en': 'Relentless'},
#   'artist': 'Akira Complex',
#   'bpm': '174',
#   'bpm_base': 174,
#   'set': 'core',
#   'purchase': 'core',
#   'audioPreview': 44137,
#   'audioPreviewEnd': 77241,
#   'side': 1,
#   'bg': '',
#   'remote_dl': True,
#   'date': 1487980814,
#   'difficulties': [{'ratingClass': 0,
#     'chartDesigner': 'Nitro',
#     'jacketDesigner': 'SERXPHIS',
#     'rating': 4},
#    {'ratingClass': 1,
#     'chartDesigner': 'Nitro',
#     'jacketDesigner': 'SERXPHIS',
#     'rating': 6},
#    {'ratingClass': 2,
#     'chartDesigner': 'Nitro',
#     'jacketDesigner': 'SERXPHIS',
#     'rating': 8}]},
#  {'id': 'shadesoflight',
#   'title_localized': {'en': 'Shades of Light in a Transcendent Realm'},
#   'artist': 'ak+q',
#   'bpm': '170',
#   'bpm_base': 170,
#   'set': 'base',
#   'purchase': '',
#   'audioPreview': 33882,
#   'audioPreviewEnd': 68470,
#   'side': 0,
#   'world_unlock': True,
#   'bg': '',
#   'date': 1487980806,
#   'difficulties': [{'ratingClass': 0,
#     'chartDesigner': 'Nitro',
#     'jacketDesigner': 'RiceGnat',
#     'rating': 3},
#    {'ratingClass': 1,
#     'chartDesigner': 'Nitro',
#     'jacketDesigner': 'RiceGnat',
#     'rating': 6},
#    {'ratingClass': 2,
#     'chartDesigner': 'Nitro',
#     'jacketDesigner': 'RiceGnat',
#     'rating': 8}]},
#  {'id': 'vexaria',
#   'title_localized': {'en': 'Vexaria'},
#   'artist': 'ak+q',
#   'bpm': '180',
#   'bpm_base': 180,
#   'set': 'base',
#   'purchase': '',
#   'audioPreview': 31057,
#   'audioPreviewEnd': 66390,
#   'side': 0,
#   'bg': '',
#   'date': 1487980802,
#   'difficulties': [{'ratingClass': 0,
#     'chartDesigner': 'Nitro',
#     'jacketDesigner': 'Koyama Mai',
#     'rating': 2},
#    {'ratingClass': 1,
#     'chartDesigner': 'Nitro',
#     'jacketDesigner': 'Koyama Mai',
#     'rating': 5},
#    {'ratingClass': 2,
#     'chartDesigner': 'Nitro',
#     'jacketDesigner': 'Koyama Mai',
#     'rating': 7}]},
#  {'id': 'essenceoftwilight',
#   'title_localized': {'en': 'Essence of Twilight'},
#   'artist': 'ak+q',
#   'bpm': '164',
#   'bpm_base': 164,
#   'set': 'core',
#   'purchase': 'core',
#   'audioPreview': 103371,
#   'audioPreviewEnd': 132639,
#   'side': 1,
#   'world_unlock': True,
#   'bg': '',
#   'remote_dl': True,
#   'date': 1487980816,
#   'difficulties': [{'ratingClass': 0,
#     'chartDesigner': 'Nitro',
#     'jacketDesigner': 'deel',
#     'rating': 4},
#    {'ratingClass': 1,
#     'chartDesigner': 'Nitro',
#     'jacketDesigner': 'deel',
#     'rating': 7},
#    {'ratingClass': 2,
#     'chartDesigner': 'Nitro',
#     'jacketDesigner': 'deel',
#     'rating': 9}]},
#  {'id': 'qualia',
#   'title_localized': {'en': 'qualia -ideaesthesia-'},
#   'artist': 'nitro',
#   'bpm': '144',
#   'bpm_base': 144,
#   'set': 'base',
#   'purchase': '',
#   'audioPreview': 110000,
#   'audioPreviewEnd': 136666,
#   'side': 1,
#   'world_unlock': True,
#   'bg': '',
#   'date': 1487980810,
#   'difficulties': [{'ratingClass': 0,
#     'chartDesigner': '-chartaesthesia-',
#     'jacketDesigner': 'Khronetic',
#     'rating': 5},
#    {'ratingClass': 1,
#     'chartDesigner': '-chartaesthesia-',
#     'jacketDesigner': 'Khronetic',
#     'rating': 7},
#    {'ratingClass': 2,
#     'chartDesigner': '-chartaesthesia-',
#     'jacketDesigner': 'Khronetic',
#     'rating': 9}]},
#  {'id': 'pragmatism',
#   'title_localized': {'en': 'PRAGMATISM'},
#   'artist': 'Laur',
#   'bpm': '174',
#   'bpm_base': 174,
#   'set': 'core',
#   'purchase': 'core',
#   'audioPreview': 31724,
#   'audioPreviewEnd': 67586,
#   'side': 0,
#   'world_unlock': True,
#   'bg': 'pragmatism',
#   'remote_dl': True,
#   'date': 1487980817,
#   'difficulties': [{'ratingClass': 0,
#     'chartDesigner': '東星',
#     'jacketDesigner': 'シエラ',
#     'rating': 4},
#    {'ratingClass': 1,
#     'chartDesigner': '東星',
#     'jacketDesigner': 'シエラ',
#     'rating': 8},
#    {'ratingClass': 2,
#     'chartDesigner': '東星',
#     'jacketDesigner': 'シエラ',
#     'rating': 10}]},
#  {'id': 'sheriruth',
#   'title_localized': {'en': 'Sheriruth'},
#   'artist': 'Team Grimoire',
#   'bpm': '185',
#   'bpm_base': 185,
#   'set': 'core',
#   'purchase': 'core',
#   'audioPreview': 57140,
#   'audioPreviewEnd': 88275,
#   'side': 1,
#   'world_unlock': True,
#   'bg': 'sheriruth',
#   'remote_dl': True,
#   'date': 1487980818,
#   'difficulties': [{'ratingClass': 0,
#     'chartDesigner': '夜浪',
#     'jacketDesigner': 'シエラ',
#     'rating': 5},
#    {'ratingClass': 1,
#     'chartDesigner': '夜浪',
#     'jacketDesigner': 'シエラ',
#     'rating': 7},
#    {'ratingClass': 2,
#     'chartDesigner': '夜浪',
#     'jacketDesigner': 'シエラ',
#     'rating': 10}]},
#  {'id': 'lumia',
#   'title_localized': {'en': 'Lumia'},
#   'artist': 'sky_delta',
#   'bpm': '180',
#   'bpm_base': 180,
#   'set': 'core',
#   'purchase': 'core',
#   'audioPreview': 69600,
#   'audioPreviewEnd': 100000,
#   'side': 0,
#   'bg': '',
#   'remote_dl': True,
#   'date': 1487980815,
#   'difficulties': [{'ratingClass': 0,
#     'chartDesigner': 'Nitro',
#     'jacketDesigner': 'mins',
#     'rating': 2},
#    {'ratingClass': 1,
#     'chartDesigner': 'Nitro',
#     'jacketDesigner': 'mins',
#     'rating': 6},
#    {'ratingClass': 2,
#     'chartDesigner': 'Toaster missing Nitro.',
#     'jacketDesigner': 'mins',
#     'rating': 8}]},
#  {'id': 'dement',
#   'title_localized': {'en': 'Dement ~after legend~'},
#   'artist': 'Lunatic Sounds',
#   'bpm': '210',
#   'bpm_base': 210,
#   'set': 'base',
#   'purchase': '',
#   'audioPreview': 24401,
#   'audioPreviewEnd': 56401,
#   'side': 1,
#   'bg': '',
#   'date': 1489968000,
#   'difficulties': [{'ratingClass': 0,
#     'chartDesigner': 'Toaster',
#     'jacketDesigner': '',
#     'rating': 3},
#    {'ratingClass': 1,
#     'chartDesigner': 'Toaster',
#     'jacketDesigner': '',
#     'rating': 6},
#    {'ratingClass': 2,
#     'chartDesigner': 'Toaster',
#     'jacketDesigner': '',
#     'rating': 7}]},
#  {'id': 'dandelion',
#   'title_localized': {'en': 'Dandelion'},
#   'artist': 'Farhan',
#   'bpm': '169',
#   'bpm_base': 169,
#   'set': 'base',
#   'purchase': '',
#   'audioPreview': 63420,
#   'audioPreviewEnd': 97148,
#   'side': 0,
#   'bg': '',
#   'date': 1489968000,
#   'difficulties': [{'ratingClass': 0,
#     'chartDesigner': 'Nitro',
#     'jacketDesigner': '',
#     'rating': 2},
#    {'ratingClass': 1,
#     'chartDesigner': 'Nitro',
#     'jacketDesigner': '',
#     'rating': 6},
#    {'ratingClass': 2,
#     'chartDesigner': 'Nitro',
#     'jacketDesigner': '',
#     'rating': 8}]},
#  {'id': 'anokumene',
#   'title_localized': {'en': 'Anökumene',
#    'ko': 'Anokumene',
#    'zh-Hant': 'Anokumene',
#    'zh-Hans': 'Anokumene'},
#   'artist': 'Jun Kuroda',
#   'bpm': '186',
#   'bpm_base': 186,
#   'set': 'base',
#   'purchase': '',
#   'audioPreview': 24918,
#   'audioPreviewEnd': 45563,
#   'side': 1,
#   'world_unlock': True,
#   'bg': '',
#   'date': 1491868801,
#   'difficulties': [{'ratingClass': 0,
#     'chartDesigner': 'Toaster',
#     'jacketDesigner': 'Khronetic',
#     'rating': 2},
#    {'ratingClass': 1,
#     'chartDesigner': 'Toaster',
#     'jacketDesigner': 'Khronetic',
#     'rating': 6},
#    {'ratingClass': 2,
#     'chartDesigner': 'Toaster',
#     'jacketDesigner': 'Khronetic',
#     'rating': 9}]},
#  {'id': 'infinityheaven',
#   'title_localized': {'en': 'Infinity Heaven'},
#   'artist': 'HyuN',
#   'bpm': '160',
#   'bpm_base': 160,
#   'set': 'base',
#   'purchase': '',
#   'audioPreview': 49500,
#   'audioPreviewEnd': 73500,
#   'side': 0,
#   'bg': '',
#   'date': 1491868800,
#   'difficulties': [{'ratingClass': 0,
#     'chartDesigner': 'Nitro',
#     'jacketDesigner': 'Tagtraume',
#     'rating': 1},
#    {'ratingClass': 1,
#     'chartDesigner': 'Nitro',
#     'jacketDesigner': 'Tagtraume',
#     'rating': 5},
#    {'ratingClass': 2,
#     'chartDesigner': 'Nitro',
#     'jacketDesigner': 'Tagtraume',
#     'rating': 7}]},
#  {'id': 'partyvinyl',
#   'title_localized': {'en': 'Party Vinyl'},
#   'artist': 'モリモリあつし',
#   'bpm': '132',
#   'bpm_base': 132,
#   'set': 'shiawase',
#   'purchase': 'shiawase',
#   'audioPreview': 22727,
#   'audioPreviewEnd': 51818,
#   'side': 0,
#   'bg': 'shiawase',
#   'remote_dl': True,
#   'date': 1494547204,
#   'difficulties': [{'ratingClass': 0,
#     'chartDesigner': 'Party Toaster',
#     'jacketDesigner': 'アサヤ',
#     'rating': 4},
#    {'ratingClass': 1,
#     'chartDesigner': 'Party Toaster',
#     'jacketDesigner': 'アサヤ',
#     'rating': 7},
#    {'ratingClass': 2,
#     'chartDesigner': 'Party Toaster',
#     'jacketDesigner': 'アサヤ',
#     'rating': 9}]},
#  {'id': 'flashback',
#   'title_localized': {'en': 'Flashback'},
#   'artist': 'ARForest',
#   'bpm': '195',
#   'bpm_base': 195,
#   'set': 'shiawase',
#   'purchase': 'shiawase',
#   'audioPreview': 88967,
#   'audioPreviewEnd': 108967,
#   'side': 0,
#   'bg': 'shiawase',
#   'remote_dl': True,
#   'date': 1494547202,
#   'difficulties': [{'ratingClass': 0,
#     'chartDesigner': 'Nitro',
#     'jacketDesigner': 'yoshimo',
#     'rating': 2},
#    {'ratingClass': 1,
#     'chartDesigner': 'Nitro',
#     'jacketDesigner': 'yoshimo',
#     'rating': 5},
#    {'ratingClass': 2,
#     'chartDesigner': 'Nitro',
#     'jacketDesigner': 'yoshimo',
#     'rating': 8}]},
#  {'id': 'flyburg',
#   'title_localized': {'en': 'Flyburg and Endroll', 'ja': 'フライブルクとエンドロウル'},
#   'artist': 'アリスシャッハと魔法の楽団',
#   'bpm': '180',
#   'bpm_base': 180,
#   'set': 'shiawase',
#   'purchase': 'shiawase',
#   'audioPreview': 49334,
#   'audioPreviewEnd': 75081,
#   'side': 0,
#   'bg': 'shiawase',
#   'remote_dl': True,
#   'date': 1494547203,
#   'difficulties': [{'ratingClass': 0,
#     'chartDesigner': 'N',
#     'jacketDesigner': 'アリスシャッハと魔法の楽団',
#     'rating': 3},
#    {'ratingClass': 1,
#     'chartDesigner': 'N',
#     'jacketDesigner': 'アリスシャッハと魔法の楽団',
#     'rating': 6},
#    {'ratingClass': 2,
#     'chartDesigner': 'NーHelix',
#     'jacketDesigner': 'アリスシャッハと魔法の楽団',
#     'rating': 9}]},
#  {'id': 'nirvluce',
#   'title_localized': {'en': 'Nirv lucE'},
#   'artist': 'しーけー',
#   'bpm': '260',
#   'bpm_base': 260,
#   'set': 'shiawase',
#   'purchase': 'shiawase',
#   'audioPreview': 37216,
#   'audioPreviewEnd': 59370,
#   'side': 0,
#   'bg': 'nirvluce',
#   'remote_dl': True,
#   'date': 1494547205,
#   'difficulties': [{'ratingClass': 0,
#     'chartDesigner': '東星※紅空',
#     'jacketDesigner': 'シエラ',
#     'rating': 2},
#    {'ratingClass': 1,
#     'chartDesigner': '東星※紅空',
#     'jacketDesigner': 'シエラ',
#     'rating': 7},
#    {'ratingClass': 2,
#     'chartDesigner': '東星※紅空',
#     'jacketDesigner': 'シエラ',
#     'rating': 10}]},
#  {'id': 'paradise',
#   'title_localized': {'en': 'Paradise'},
#   'artist': 'Sound Souler',
#   'bpm': '126',
#   'bpm_base': 126,
#   'set': 'shiawase',
#   'purchase': 'shiawase',
#   'audioPreview': 78095,
#   'audioPreviewEnd': 108571,
#   'side': 0,
#   'bg': 'shiawase',
#   'remote_dl': True,
#   'date': 1494547201,
#   'difficulties': [{'ratingClass': 0,
#     'chartDesigner': 'Nitro',
#     'jacketDesigner': 'ましろみ のあ',
#     'rating': 1},
#    {'ratingClass': 1,
#     'chartDesigner': 'Nitro',
#     'jacketDesigner': 'ましろみ のあ',
#     'rating': 4},
#    {'ratingClass': 2,
#     'chartDesigner': 'Nitro',
#     'jacketDesigner': 'ましろみ のあ',
#     'rating': 7}]},
#  {'id': 'brandnewworld',
#   'title_localized': {'en': 'Brand new world'},
#   'artist': 'U-ske',
#   'bpm': '160',
#   'bpm_base': 160,
#   'set': 'base',
#   'purchase': '',
#   'audioPreview': 54401,
#   'audioPreviewEnd': 79050,
#   'side': 0,
#   'bg': 'shiawase',
#   'date': 1494547200,
#   'difficulties': [{'ratingClass': 0,
#     'chartDesigner': 'Nitro 2.0',
#     'jacketDesigner': '',
#     'rating': 2},
#    {'ratingClass': 1,
#     'chartDesigner': 'Nitro 2.0',
#     'jacketDesigner': '',
#     'rating': 4},
#    {'ratingClass': 2,
#     'chartDesigner': 'Nitro 2.0',
#     'jacketDesigner': '',
#     'rating': 7}]},
#  {'id': 'dataerror',
#   'title_localized': {'en': 'DataErr0r'},
#   'artist': 'Lunatic Sounds',
#   'bpm': '180',
#   'bpm_base': 180,
#   'set': 'single',
#   'purchase': 'dataerror',
#   'audioPreview': 53730,
#   'audioPreviewEnd': 85730,
#   'side': 1,
#   'remote_dl': True,
#   'bg': 'single_conflict',
#   'date': 1496188802,
#   'difficulties': [{'ratingClass': 0,
#     'chartDesigner': 'ToastErr0r',
#     'jacketDesigner': '',
#     'rating': 3},
#    {'ratingClass': 1,
#     'chartDesigner': 'ToastErr0r',
#     'jacketDesigner': '',
#     'rating': 7},
#    {'ratingClass': 2,
#     'chartDesigner': 'ToastErr0r',
#     'jacketDesigner': '',
#     'rating': 9,
#     'plusFingers': True}]},
#  {'id': 'crosssoul',
#   'title_localized': {'en': 'CROSS†SOUL'},
#   'artist': 'HyuN feat. Syepias',
#   'bpm': '200',
#   'bpm_base': 200,
#   'set': 'single',
#   'purchase': 'crosssoul',
#   'audioPreview': 51392,
#   'audioPreviewEnd': 80192,
#   'side': 1,
#   'remote_dl': True,
#   'bg': 'single_conflict',
#   'date': 1496188803,
#   'difficulties': [{'ratingClass': 0,
#     'chartDesigner': 'k//eternal',
#     'jacketDesigner': 'Khronetic',
#     'rating': 4},
#    {'ratingClass': 1,
#     'chartDesigner': 'k//eternal',
#     'jacketDesigner': 'Khronetic',
#     'rating': 7},
#    {'ratingClass': 2,
#     'chartDesigner': 'k//eternal',
#     'jacketDesigner': 'Khronetic',
#     'rating': 9}]},
#  {'id': 'yourvoiceso',
#   'title_localized': {'en': 'Your voice so... feat. Such'},
#   'artist': 'PSYQUI',
#   'bpm': '176',
#   'bpm_base': 176,
#   'set': 'single',
#   'purchase': 'yourvoiceso',
#   'audioPreview': 20850,
#   'audioPreviewEnd': 46759,
#   'side': 0,
#   'remote_dl': True,
#   'bg': 'single_light',
#   'date': 1496188804,
#   'difficulties': [{'ratingClass': 0,
#     'chartDesigner': 'Nitro',
#     'jacketDesigner': 'DJ Poyoshi',
#     'rating': 3},
#    {'ratingClass': 1,
#     'chartDesigner': 'Nitro',
#     'jacketDesigner': 'DJ Poyoshi',
#     'rating': 6},
#    {'ratingClass': 2,
#     'chartDesigner': 'Nitro',
#     'jacketDesigner': 'DJ Poyoshi',
#     'rating': 9}]},
#  {'id': 'chronostasis',
#   'title_localized': {'en': 'Chronostasis'},
#   'artist': '黒皇帝',
#   'bpm': '196',
#   'bpm_base': 196,
#   'set': 'base',
#   'purchase': '',
#   'audioPreview': 79500,
#   'audioPreviewEnd': 100000,
#   'side': 1,
#   'bg': '',
#   'date': 1496188800,
#   'difficulties': [{'ratingClass': 0,
#     'chartDesigner': 'Kurorak',
#     'jacketDesigner': '',
#     'rating': 3},
#    {'ratingClass': 1,
#     'chartDesigner': 'Kurorak',
#     'jacketDesigner': '',
#     'rating': 7},
#    {'ratingClass': 2,
#     'chartDesigner': 'Kurorak',
#     'jacketDesigner': '',
#     'rating': 9}]},
#  {'id': 'kanagawa',
#   'title_localized': {'en': 'Kanagawa Cyber Culvert', 'ja': '神奈川電脳暗渠'},
#   'artist': '南ゆに',
#   'bpm': '180',
#   'bpm_base': 180,
#   'set': 'base',
#   'purchase': '',
#   'audioPreview': 67000,
#   'audioPreviewEnd': 101667,
#   'side': 0,
#   'world_unlock': True,
#   'bg': '',
#   'date': 1496188801,
#   'difficulties': [{'ratingClass': 0,
#     'chartDesigner': 'Nitro',
#     'jacketDesigner': '白鳥怜',
#     'rating': 1},
#    {'ratingClass': 1,
#     'chartDesigner': 'Nitro',
#     'jacketDesigner': '白鳥怜',
#     'rating': 5},
#    {'ratingClass': 2,
#     'chartDesigner': 'Nitro',
#     'jacketDesigner': '白鳥怜',
#     'rating': 9}]},
#  {'id': 'moonlightofsandcastle',
#   'title_localized': {'en': 'Moonlight of Sand Castle'},
#   'artist': '旅人E',
#   'bpm': '160',
#   'bpm_base': 160,
#   'set': 'dynamix',
#   'purchase': 'dynamix',
#   'audioPreview': 55500,
#   'audioPreviewEnd': 82500,
#   'side': 0,
#   'bg': 'dynamix_light',
#   'remote_dl': True,
#   'source_localized': {'en': 'Dynamix'},
#   'source_copyright': '',
#   'date': 1498176001,
#   'difficulties': [{'ratingClass': 0,
#     'chartDesigner': 'Kurorak',
#     'jacketDesigner': '',
#     'rating': 1},
#    {'ratingClass': 1,
#     'chartDesigner': 'Kurorak',
#     'jacketDesigner': '',
#     'rating': 5},
#    {'ratingClass': 2,
#     'chartDesigner': 'Kurorak',
#     'jacketDesigner': '',
#     'rating': 7}]},
#  {'id': 'reconstruction',
#   'title_localized': {'en': 'REconstruction'},
#   'artist': 'Ryazan',
#   'bpm': '180',
#   'bpm_base': 180,
#   'set': 'dynamix',
#   'purchase': 'dynamix',
#   'audioPreview': 45413,
#   'audioPreviewEnd': 77413,
#   'side': 0,
#   'bg': 'dynamix_light',
#   'remote_dl': True,
#   'source_localized': {'en': 'Dynamix'},
#   'source_copyright': '',
#   'date': 1498176002,
#   'difficulties': [{'ratingClass': 0,
#     'chartDesigner': 'Nitro',
#     'jacketDesigner': '',
#     'rating': 2},
#    {'ratingClass': 1,
#     'chartDesigner': 'Nitro',
#     'jacketDesigner': '',
#     'rating': 6},
#    {'ratingClass': 2,
#     'chartDesigner': 'Nitro',
#     'jacketDesigner': '',
#     'rating': 8}]},
#  {'id': 'evoltex',
#   'title_localized': {'en': "Evoltex (poppi'n mix)"},
#   'artist': 'Arch vs n3pu',
#   'bpm': '205',
#   'bpm_base': 205,
#   'set': 'dynamix',
#   'purchase': 'dynamix',
#   'audioPreview': 63219,
#   'audioPreviewEnd': 92487,
#   'side': 0,
#   'bg': 'dynamix_light',
#   'remote_dl': True,
#   'source_localized': {'en': 'Dynamix'},
#   'date': 1498176003,
#   'difficulties': [{'ratingClass': 0,
#     'chartDesigner': 'k//eternal',
#     'jacketDesigner': '',
#     'rating': 2},
#    {'ratingClass': 1,
#     'chartDesigner': 'k//eternal',
#     'jacketDesigner': '',
#     'rating': 7},
#    {'ratingClass': 2,
#     'chartDesigner': 'k//eternal',
#     'jacketDesigner': '',
#     'rating': 8}]},
#  {'id': 'oracle',
#   'title_localized': {'en': 'Oracle'},
#   'artist': 'TQ☆',
#   'bpm': '152',
#   'bpm_base': 152,
#   'set': 'dynamix',
#   'purchase': 'dynamix',
#   'audioPreview': 42509,
#   'audioPreviewEnd': 69351,
#   'side': 1,
#   'bg': 'dynamix_conflict',
#   'remote_dl': True,
#   'source_localized': {'en': 'Dynamix'},
#   'source_copyright': '',
#   'date': 1498176004,
#   'difficulties': [{'ratingClass': 0,
#     'chartDesigner': 'Nitro',
#     'jacketDesigner': '',
#     'rating': 3},
#    {'ratingClass': 1,
#     'chartDesigner': 'Nitro',
#     'jacketDesigner': '',
#     'rating': 5},
#    {'ratingClass': 2,
#     'chartDesigner': 'Nitro',
#     'jacketDesigner': '',
#     'rating': 9}]},
#  {'id': 'aterlbus',
#   'title_localized': {'en': 'αterlβus',
#    'zh-Hant': 'aterlbus',
#    'zh-Hans': 'aterlbus'},
#   'artist': 'Aoi',
#   'bpm': '202',
#   'bpm_base': 202,
#   'set': 'dynamix',
#   'purchase': 'dynamix',
#   'audioPreview': 29102,
#   'audioPreviewEnd': 59405,
#   'side': 1,
#   'bg': 'dynamix_conflict',
#   'remote_dl': True,
#   'source_localized': {'en': 'Dynamix'},
#   'date': 1498176005,
#   'difficulties': [{'ratingClass': 0,
#     'chartDesigner': 'τoastεr',
#     'jacketDesigner': '',
#     'rating': 4},
#    {'ratingClass': 1,
#     'chartDesigner': 'τoastεr',
#     'jacketDesigner': '',
#     'rating': 7},
#    {'ratingClass': 2,
#     'chartDesigner': 'τoastεr',
#     'jacketDesigner': '',
#     'rating': 10,
#     'bg': 'aterlbus'}]},
#  {'id': 'clotho',
#   'title_localized': {'en': 'Clotho and the stargazer', 'ja': 'クロートーと星の観測者'},
#   'artist': 'しーけー',
#   'bpm': '230',
#   'bpm_base': 230,
#   'set': 'base',
#   'purchase': '',
#   'audioPreview': 38399,
#   'audioPreviewEnd': 63443,
#   'side': 0,
#   'bg': 'shiawase',
#   'date': 1498176000,
#   'difficulties': [{'ratingClass': 0,
#     'chartDesigner': '小東星',
#     'jacketDesigner': 'yoshimo',
#     'rating': 2},
#    {'ratingClass': 1,
#     'chartDesigner': '小東星',
#     'jacketDesigner': 'yoshimo',
#     'rating': 5},
#    {'ratingClass': 2,
#     'chartDesigner': '小東星',
#     'jacketDesigner': 'yoshimo',
#     'rating': 7}]},
#  {'id': 'impurebird',
#   'title_localized': {'en': 'Impure Bird', 'ja': '不浄な白い鳥'},
#   'artist': 'MIssionary',
#   'bpm': '184',
#   'bpm_base': 184,
#   'set': 'single',
#   'purchase': 'impurebird',
#   'audioPreview': 19565,
#   'audioPreviewEnd': 41739,
#   'side': 0,
#   'remote_dl': True,
#   'bg': 'single_light',
#   'date': 1500163201,
#   'difficulties': [{'ratingClass': 0,
#     'chartDesigner': 'Kurorak',
#     'jacketDesigner': 'Nano Kun',
#     'rating': 2},
#    {'ratingClass': 1,
#     'chartDesigner': 'Kurorak',
#     'jacketDesigner': 'Nano Kun',
#     'rating': 5},
#    {'ratingClass': 2,
#     'chartDesigner': 'Kurorak',
#     'jacketDesigner': 'Nano Kun',
#     'rating': 9}]},
#  {'id': 'ignotus',
#   'title_localized': {'en': 'Ignotus'},
#   'artist': 'ak+q',
#   'bpm': '170',
#   'bpm_base': 170,
#   'set': 'base',
#   'purchase': '',
#   'audioPreview': 87176,
#   'audioPreviewEnd': 115764,
#   'side': 1,
#   'world_unlock': True,
#   'bg': '',
#   'date': 1500163200,
#   'difficulties': [{'ratingClass': 0,
#     'chartDesigner': 'Toaster',
#     'jacketDesigner': 'Khronetic',
#     'rating': 3},
#    {'ratingClass': 1,
#     'chartDesigner': 'Toaster',
#     'jacketDesigner': 'Khronetic',
#     'rating': 6},
#    {'ratingClass': 2,
#     'chartDesigner': 'Toaster',
#     'jacketDesigner': 'Khronetic',
#     'rating': 9}]},
#  {'id': 'lethaeus',
#   'title_localized': {'en': 'Lethaeus'},
#   'artist': 'Silentroom',
#   'bpm': '155',
#   'bpm_base': 155,
#   'set': 'mirai',
#   'purchase': 'mirai',
#   'audioPreview': 89806,
#   'audioPreviewEnd': 114580,
#   'side': 1,
#   'bg': 'lethaeus',
#   'remote_dl': True,
#   'date': 1502323205,
#   'difficulties': [{'ratingClass': 0,
#     'chartDesigner': '夜浪',
#     'jacketDesigner': 'softmode',
#     'rating': 3},
#    {'ratingClass': 1,
#     'chartDesigner': '夜浪',
#     'jacketDesigner': 'softmode',
#     'rating': 6},
#    {'ratingClass': 2,
#     'chartDesigner': '夜浪',
#     'jacketDesigner': 'softmode',
#     'rating': 9}]},
#  {'id': 'romancewars',
#   'title_localized': {'en': 'Romance Wars', 'ja': 'vsキミ戦争'},
#   'artist': 'U-ske (feat. lueur)',
#   'bpm': '187',
#   'bpm_base': 187,
#   'set': 'mirai',
#   'purchase': 'mirai',
#   'audioPreview': 51974,
#   'audioPreviewEnd': 73151,
#   'side': 0,
#   'bg': 'mirai_light',
#   'remote_dl': True,
#   'date': 1502323202,
#   'difficulties': [{'ratingClass': 0,
#     'chartDesigner': 'Kurorak',
#     'jacketDesigner': '橙乃遥',
#     'rating': 1},
#    {'ratingClass': 1,
#     'chartDesigner': 'Kurorak',
#     'jacketDesigner': '橙乃遥',
#     'rating': 4},
#    {'ratingClass': 2,
#     'chartDesigner': 'Kurorak',
#     'jacketDesigner': '橙乃遥',
#     'rating': 7}]},
#  {'id': 'blossoms',
#   'title_localized': {'en': 'Blossoms'},
#   'artist': 'T2Kazuya',
#   'bpm': '138',
#   'bpm_base': 138,
#   'set': 'mirai',
#   'purchase': 'mirai',
#   'audioPreview': 70430,
#   'audioPreviewEnd': 98256,
#   'side': 0,
#   'bg': 'mirai_light',
#   'remote_dl': True,
#   'date': 1502323201,
#   'difficulties': [{'ratingClass': 0,
#     'chartDesigner': 'Nitro',
#     'jacketDesigner': 'T2Kazuya',
#     'rating': 1},
#    {'ratingClass': 1,
#     'chartDesigner': 'Nitro',
#     'jacketDesigner': 'T2Kazuya',
#     'rating': 4},
#    {'ratingClass': 2,
#     'chartDesigner': 'Nitro',
#     'jacketDesigner': 'T2Kazuya',
#     'rating': 7}]},
#  {'id': 'moonheart',
#   'title_localized': {'en': 'Moonheart'},
#   'artist': '翡乃イスカ',
#   'bpm': '180',
#   'bpm_base': 180,
#   'set': 'mirai',
#   'purchase': 'mirai',
#   'audioPreview': 66000,
#   'audioPreviewEnd': 85333,
#   'side': 0,
#   'bg': 'mirai_light',
#   'remote_dl': True,
#   'date': 1502323203,
#   'difficulties': [{'ratingClass': 0,
#     'chartDesigner': 'Toaster',
#     'jacketDesigner': 'VMWT',
#     'rating': 2},
#    {'ratingClass': 1,
#     'chartDesigner': 'Toaster',
#     'jacketDesigner': 'VMWT',
#     'rating': 5},
#    {'ratingClass': 2,
#     'chartDesigner': 'Toaster',
#     'jacketDesigner': 'VMWT',
#     'rating': 8}]},
#  {'id': 'genesis',
#   'title_localized': {'en': 'Genesis'},
#   'artist': 'Iris',
#   'bpm': '132',
#   'bpm_base': 132,
#   'set': 'mirai',
#   'purchase': 'mirai',
#   'audioPreview': 61818,
#   'audioPreviewEnd': 90909,
#   'side': 1,
#   'bg': 'mirai_conflict',
#   'remote_dl': True,
#   'date': 1502323204,
#   'difficulties': [{'ratingClass': 0,
#     'chartDesigner': 'Haruba',
#     'jacketDesigner': 'RiceGnat',
#     'rating': 2},
#    {'ratingClass': 1,
#     'chartDesigner': 'Haruba',
#     'jacketDesigner': 'RiceGnat',
#     'rating': 5},
#    {'ratingClass': 2,
#     'chartDesigner': 'Haruba',
#     'jacketDesigner': 'RiceGnat',
#     'rating': 8}]},
#  {'id': 'harutopia',
#   'title_localized': {'ja': 'ハルトピア ~Utopia of Spring~',
#    'en': 'Harutopia ~Utopia of Spring~'},
#   'artist': 'A-zu-ra',
#   'bpm': '185',
#   'bpm_base': 185,
#   'set': 'base',
#   'purchase': '',
#   'audioPreview': 83191,
#   'audioPreviewEnd': 103948,
#   'side': 0,
#   'world_unlock': True,
#   'bg': 'shiawase',
#   'date': 1502323200,
#   'difficulties': [{'ratingClass': 0,
#     'chartDesigner': 'トーストピア  ~Utopia of Toast~',
#     'jacketDesigner': '',
#     'rating': 1},
#    {'ratingClass': 1,
#     'chartDesigner': 'トーストピア  ~Utopia of Toast~',
#     'jacketDesigner': '',
#     'rating': 4},
#    {'ratingClass': 2,
#     'chartDesigner': 'トーストピア  ~Utopia of Toast~',
#     'jacketDesigner': '',
#     'rating': 8}]},
#  {'id': 'auxesia',
#   'title_localized': {'en': 'Auxesia'},
#   'artist': 'ginkiha',
#   'bpm': '183',
#   'bpm_base': 183,
#   'set': 'single',
#   'purchase': 'auxesia',
#   'audioPreview': 0,
#   'audioPreviewEnd': 0,
#   'side': 0,
#   'bg': 'auxesia',
#   'date': 1502323206,
#   'remote_dl': True,
#   'difficulties': [{'ratingClass': 0,
#     'chartDesigner': 'Nitroだー！！',
#     'jacketDesigner': 'シエラ',
#     'rating': 3},
#    {'ratingClass': 1,
#     'chartDesigner': 'Nitroだー！',
#     'jacketDesigner': 'シエラ',
#     'rating': 6},
#    {'ratingClass': 2,
#     'chartDesigner': 'Nitroだー！',
#     'jacketDesigner': 'シエラ',
#     'rating': 9}]},
#  {'id': 'rabbitintheblackroom',
#   'title_localized': {'en': 'Rabbit In The Black Room'},
#   'artist': 'Rabbit House',
#   'bpm': '270',
#   'bpm_base': 270,
#   'set': 'base',
#   'purchase': '',
#   'audioPreview': 14665,
#   'audioPreviewEnd': 43110,
#   'side': 1,
#   'world_unlock': True,
#   'bg': '',
#   'date': 1505520000,
#   'difficulties': [{'ratingClass': 0,
#     'chartDesigner': 'Toaster',
#     'jacketDesigner': 'YEONIE',
#     'rating': 2},
#    {'ratingClass': 1,
#     'chartDesigner': 'Toaster',
#     'jacketDesigner': 'YEONIE',
#     'rating': 5},
#    {'ratingClass': 2,
#     'chartDesigner': 'Toaster',
#     'jacketDesigner': 'YEONIE',
#     'rating': 8}]},
#  {'id': 'modelista',
#   'title_localized': {'en': 'Modelista'},
#   'artist': 'HiTECH NINJA',
#   'bpm': '165',
#   'bpm_base': 165,
#   'set': 'single',
#   'purchase': 'modelista',
#   'audioPreview': 26181,
#   'audioPreviewEnd': 52363,
#   'side': 0,
#   'remote_dl': True,
#   'bg': 'modelista',
#   'date': 1505520001,
#   'difficulties': [{'ratingClass': 0,
#     'chartDesigner': 'NITRO',
#     'jacketDesigner': 'yusi.',
#     'rating': 3},
#    {'ratingClass': 1,
#     'chartDesigner': 'NITRO',
#     'jacketDesigner': 'yusi.',
#     'rating': 7},
#    {'ratingClass': 2,
#     'chartDesigner': 'NITRO',
#     'jacketDesigner': 'yusi.',
#     'rating': 9}]},
#  {'id': 'soundwitch',
#   'title_localized': {'en': 'SOUNDWiTCH'},
#   'artist': 'HATE',
#   'bpm': '170',
#   'bpm_base': 170,
#   'set': 'yugamu',
#   'purchase': 'yugamu',
#   'audioPreview': 52941,
#   'audioPreviewEnd': 79764,
#   'side': 1,
#   'bg': 'yugamu',
#   'remote_dl': True,
#   'date': 1509667204,
#   'difficulties': [{'ratingClass': 0,
#     'chartDesigner': 'NiTRO',
#     'jacketDesigner': 'スズカミ',
#     'rating': 3},
#    {'ratingClass': 1,
#     'chartDesigner': 'NiTRO',
#     'jacketDesigner': 'スズカミ',
#     'rating': 6},
#    {'ratingClass': 2,
#     'chartDesigner': 'NiTRO',
#     'jacketDesigner': 'スズカミ',
#     'rating': 9}]},
#  {'id': 'trappola',
#   'title_localized': {'en': 'trappola bewitching',
#    'ja': '妖艶魔女 -trappola bewitching-'},
#   'artist': 'gmtn.',
#   'bpm': '190',
#   'bpm_base': 190,
#   'set': 'yugamu',
#   'purchase': 'yugamu',
#   'audioPreview': 36680,
#   'audioPreviewEnd': 66996,
#   'side': 1,
#   'bg': 'yugamu',
#   'remote_dl': True,
#   'date': 1509667205,
#   'difficulties': [{'ratingClass': 0,
#     'chartDesigner': 'Kurorak',
#     'jacketDesigner': 'Shionty',
#     'rating': 3},
#    {'ratingClass': 1,
#     'chartDesigner': 'Kurorak',
#     'jacketDesigner': 'Shionty',
#     'rating': 6},
#    {'ratingClass': 2,
#     'chartDesigner': 'k//urorak',
#     'jacketDesigner': 'Shionty',
#     'rating': 9}]},
#  {'id': 'iconoclast',
#   'title_localized': {'en': 'Iconoclast'},
#   'artist': 'Yamajet',
#   'bpm': '140',
#   'bpm_base': 140,
#   'set': 'yugamu',
#   'purchase': 'yugamu',
#   'audioPreview': 35996,
#   'audioPreviewEnd': 63425,
#   'side': 1,
#   'bg': 'yugamu',
#   'remote_dl': True,
#   'date': 1509667203,
#   'difficulties': [{'ratingClass': 0,
#     'chartDesigner': 'Toaster',
#     'jacketDesigner': 'SKT',
#     'rating': 4},
#    {'ratingClass': 1,
#     'chartDesigner': 'Toaster',
#     'jacketDesigner': 'SKT',
#     'rating': 7},
#    {'ratingClass': 2,
#     'chartDesigner': 'Toaster',
#     'jacketDesigner': 'SKT',
#     'rating': 9}]},
#  {'id': 'conflict',
#   'title_localized': {'en': 'conflict'},
#   'artist': 'siromaru + cranky',
#   'bpm': '160',
#   'bpm_base': 160,
#   'set': 'yugamu',
#   'purchase': 'yugamu',
#   'audioPreview': 12750,
#   'audioPreviewEnd': 37500,
#   'side': 1,
#   'bg': 'yugamu',
#   'remote_dl': True,
#   'date': 1509667206,
#   'difficulties': [{'ratingClass': 0,
#     'chartDesigner': 'Toaster',
#     'jacketDesigner': 'horte',
#     'rating': 4},
#    {'ratingClass': 1,
#     'chartDesigner': 'Nitro',
#     'jacketDesigner': 'horte',
#     'rating': 7},
#    {'ratingClass': 2,
#     'chartDesigner': 'toaster + nitro',
#     'jacketDesigner': 'horte',
#     'rating': 10}]},
#  {'id': 'axiumcrisis',
#   'title_localized': {'en': 'Axium Crisis'},
#   'artist': 'ak+q',
#   'bpm': '170',
#   'bpm_base': 170,
#   'set': 'yugamu',
#   'purchase': 'yugamu',
#   'audioPreview': 51291,
#   'audioPreviewEnd': 78820,
#   'side': 1,
#   'world_unlock': True,
#   'bg': 'axiumcrisis',
#   'remote_dl': True,
#   'date': 1509667207,
#   'difficulties': [{'ratingClass': 0,
#     'chartDesigner': 'The Monolith',
#     'jacketDesigner': 'シエラ',
#     'rating': 5},
#    {'ratingClass': 1,
#     'chartDesigner': 'The Monolith',
#     'jacketDesigner': 'シエラ',
#     'rating': 8},
#    {'ratingClass': 2,
#     'chartDesigner': 'The Monolith',
#     'jacketDesigner': 'シエラ',
#     'rating': 10}]},
#  {'id': 'grievouslady',
#   'title_localized': {'en': 'Grievous Lady'},
#   'artist': 'Team Grimoire vs Laur',
#   'bpm': '210',
#   'bpm_base': 210,
#   'set': 'yugamu',
#   'purchase': 'yugamu',
#   'audioPreview': 0,
#   'audioPreviewEnd': 18285,
#   'side': 1,
#   'bg': 'grievouslady',
#   'remote_dl': True,
#   'date': 1509667208,
#   'difficulties': [{'ratingClass': 0,
#     'chartDesigner': '迷路第一層',
#     'jacketDesigner': 'シエラ',
#     'rating': 6},
#    {'ratingClass': 1,
#     'chartDesigner': '迷路第二層',
#     'jacketDesigner': 'シエラ',
#     'rating': 9,
#     'plusFingers': True},
#    {'ratingClass': 2,
#     'chartDesigner': '迷路深層',
#     'jacketDesigner': 'シエラ',
#     'rating': 11,
#     'plusFingers': True}]},
#  {'id': 'dreaminattraction',
#   'title_localized': {'en': "Dreamin' Attraction!!"},
#   'artist': '翡乃イスカ',
#   'bpm': '205',
#   'bpm_base': 205,
#   'set': 'base',
#   'purchase': '',
#   'audioPreview': 39804,
#   'audioPreviewEnd': 60878,
#   'side': 0,
#   'world_unlock': True,
#   'bg': '',
#   'date': 1509667201,
#   'difficulties': [{'ratingClass': 0,
#     'chartDesigner': 'Nitro',
#     'jacketDesigner': '',
#     'rating': 4},
#    {'ratingClass': 1,
#     'chartDesigner': 'Nitro',
#     'jacketDesigner': '',
#     'rating': 7},
#    {'ratingClass': 2,
#     'chartDesigner': 'Nitro',
#     'jacketDesigner': '',
#     'rating': 9}]},
#  {'id': 'redandblue',
#   'title_localized': {'en': 'Red and Blue'},
#   'artist': 'Silentroom',
#   'bpm': '150',
#   'bpm_base': 150,
#   'set': 'base',
#   'purchase': '',
#   'audioPreview': 14396,
#   'audioPreviewEnd': 39996,
#   'side': 1,
#   'world_unlock': True,
#   'bg': '',
#   'date': 1509667202,
#   'difficulties': [{'ratingClass': 0,
#     'chartDesigner': '-chartaesthesia- RED side',
#     'jacketDesigner': 'Khronetic',
#     'rating': 4},
#    {'ratingClass': 1,
#     'chartDesigner': 'side BLUE -chartaesthesia-',
#     'jacketDesigner': 'Khronetic',
#     'rating': 7},
#    {'ratingClass': 2,
#     'chartDesigner': '-chartaesthesia-\nLEFT=BLUE RED=RIGHT ',
#     'jacketDesigner': 'Khronetic',
#     'rating': 9}]},
#  {'id': 'onelastdrive',
#   'title_localized': {'en': 'One Last Drive'},
#   'artist': 'REDSHiFT',
#   'bpm': '154 - 175',
#   'bpm_base': 175,
#   'set': 'base',
#   'purchase': '',
#   'audioPreview': 49870,
#   'audioPreviewEnd': 74805,
#   'side': 0,
#   'bg': '',
#   'date': 1509667200,
#   'difficulties': [{'ratingClass': 0,
#     'chartDesigner': 'Toaster',
#     'jacketDesigner': '',
#     'rating': 2},
#    {'ratingClass': 1,
#     'chartDesigner': 'Toaster',
#     'jacketDesigner': '',
#     'rating': 5},
#    {'ratingClass': 2,
#     'chartDesigner': 'Toaster',
#     'jacketDesigner': '',
#     'rating': 8}]},
#  {'id': 'surrender',
#   'title_localized': {'en': 'Surrender'},
#   'artist': 'void',
#   'bpm': '152',
#   'bpm_base': 152,
#   'set': 'stellights',
#   'purchase': 'surrender',
#   'audioPreview': 0,
#   'audioPreviewEnd': 0,
#   'side': 0,
#   'remote_dl': True,
#   'bg': '',
#   'source_localized': {'en': 'STELLIGHTS'},
#   'source_copyright': '',
#   'date': 1511481600,
#   'difficulties': [{'ratingClass': 0,
#     'chartDesigner': 'Nitro',
#     'jacketDesigner': 'softmode',
#     'rating': 3},
#    {'ratingClass': 1,
#     'chartDesigner': 'Nitro',
#     'jacketDesigner': 'softmode',
#     'rating': 6},
#    {'ratingClass': 2,
#     'chartDesigner': 'Nitro',
#     'jacketDesigner': 'softmode',
#     'rating': 8}]},
#  {'id': 'yozakurafubuki',
#   'title_localized': {'en': 'Yosakura Fubuki', 'ja': '夜桜吹雪'},
#   'artist': 'A.SAKA',
#   'bpm': '172',
#   'bpm_base': 172,
#   'set': 'stellights',
#   'purchase': 'yozakurafubuki',
#   'audioPreview': 0,
#   'audioPreviewEnd': 0,
#   'side': 0,
#   'remote_dl': True,
#   'bg': '',
#   'date': 1511481601,
#   'difficulties': [{'ratingClass': 0,
#     'chartDesigner': 'k//eternal',
#     'jacketDesigner': 'シエラ',
#     'rating': 4},
#    {'ratingClass': 1,
#     'chartDesigner': 'k//eternal',
#     'jacketDesigner': 'シエラ',
#     'rating': 7},
#    {'ratingClass': 2,
#     'chartDesigner': 'k//eternal',
#     'jacketDesigner': 'シエラ',
#     'rating': 9}]},
#  {'id': 'cyanine',
#   'title_localized': {'en': 'cyanine'},
#   'artist': 'jioyi',
#   'bpm': '182',
#   'bpm_base': 182,
#   'set': 'lanota',
#   'purchase': 'lanota',
#   'audioPreview': 25542,
#   'audioPreviewEnd': 49938,
#   'side': 1,
#   'bg': 'lanota-conflict',
#   'remote_dl': True,
#   'source_localized': {'en': 'Lanota'},
#   'source_copyright': '',
#   'date': 1517443204,
#   'difficulties': [{'ratingClass': 0,
#     'chartDesigner': '夜浪 - Apocalypse',
#     'jacketDesigner': '',
#     'rating': 4},
#    {'ratingClass': 1,
#     'chartDesigner': '夜浪',
#     'jacketDesigner': '',
#     'rating': 7},
#    {'ratingClass': 2,
#     'chartDesigner': '夜浪',
#     'jacketDesigner': '',
#     'rating': 10}]},
#  {'id': 'dreamgoeson',
#   'title_localized': {'en': 'Dream goes on'},
#   'artist': 'Tiny Minim',
#   'bpm': '174',
#   'bpm_base': 174,
#   'set': 'lanota',
#   'purchase': 'lanota',
#   'audioPreview': 70000,
#   'audioPreviewEnd': 103448,
#   'side': 0,
#   'bg': 'lanota-light',
#   'remote_dl': True,
#   'source_localized': {'en': 'Lanota'},
#   'source_copyright': '',
#   'date': 1517443200,
#   'difficulties': [{'ratingClass': 0,
#     'chartDesigner': 'k//eternal',
#     'jacketDesigner': '',
#     'rating': 1},
#    {'ratingClass': 1,
#     'chartDesigner': 'k//eternal',
#     'jacketDesigner': '',
#     'rating': 5},
#    {'ratingClass': 2,
#     'chartDesigner': 'k//eternal',
#     'jacketDesigner': '',
#     'rating': 7}]},
#  {'id': 'journey',
#   'title_localized': {'en': 'Journey'},
#   'artist': 'ARForest',
#   'bpm': '200',
#   'bpm_base': 200,
#   'set': 'lanota',
#   'purchase': 'lanota',
#   'audioPreview': 76800,
#   'audioPreviewEnd': 96000,
#   'side': 0,
#   'bg': 'lanota-light',
#   'remote_dl': True,
#   'source_localized': {'en': 'Lanota'},
#   'source_copyright': '',
#   'date': 1517443202,
#   'difficulties': [{'ratingClass': 0,
#     'chartDesigner': 'Kurorak',
#     'jacketDesigner': '',
#     'rating': 3},
#    {'ratingClass': 1,
#     'chartDesigner': 'Kurorak',
#     'jacketDesigner': '',
#     'rating': 6},
#    {'ratingClass': 2,
#     'chartDesigner': 'Kurorak',
#     'jacketDesigner': '',
#     'rating': 8}]},
#  {'id': 'specta',
#   'title_localized': {'en': 'Specta'},
#   'artist': 'Junk',
#   'bpm': '179',
#   'bpm_base': 179,
#   'set': 'lanota',
#   'purchase': 'lanota',
#   'audioPreview': 97932,
#   'audioPreviewEnd': 119385,
#   'side': 0,
#   'bg': 'lanota-light',
#   'remote_dl': True,
#   'source_localized': {'en': 'Lanota'},
#   'source_copyright': '',
#   'date': 1517443202,
#   'difficulties': [{'ratingClass': 0,
#     'chartDesigner': 'Toaster',
#     'jacketDesigner': '',
#     'rating': 3},
#    {'ratingClass': 1,
#     'chartDesigner': 'Toaster',
#     'jacketDesigner': '',
#     'rating': 6},
#    {'ratingClass': 2,
#     'chartDesigner': 'Toaster',
#     'jacketDesigner': '',
#     'rating': 9}]},
#  {'id': 'quon',
#   'title_localized': {'en': 'Quon'},
#   'artist': 'Feryquitous',
#   'bpm': '189',
#   'bpm_base': 189,
#   'set': 'lanota',
#   'purchase': 'lanota',
#   'audioPreview': 86520,
#   'audioPreviewEnd': 111917,
#   'side': 0,
#   'bg': 'quon',
#   'remote_dl': True,
#   'date': 1517443203,
#   'difficulties': [{'ratingClass': 0,
#     'chartDesigner': 'Nitro',
#     'jacketDesigner': 'シエラ',
#     'rating': 4},
#    {'ratingClass': 1,
#     'chartDesigner': 'Nitro',
#     'jacketDesigner': 'シエラ',
#     'rating': 6},
#    {'ratingClass': 2,
#     'chartDesigner': 'Nitro',
#     'jacketDesigner': 'シエラ',
#     'rating': 9}]},
#  {'id': 'syro',
#   'title_localized': {'en': 'Syro'},
#   'artist': 'Mitomoro',
#   'bpm': '178',
#   'bpm_base': 178,
#   'set': 'base',
#   'purchase': '',
#   'audioPreview': 26968,
#   'audioPreviewEnd': 48541,
#   'side': 0,
#   'world_unlock': True,
#   'bg': 'mirai_light',
#   'date': 1513814401,
#   'difficulties': [{'ratingClass': 0,
#     'chartDesigner': 'Toaster',
#     'jacketDesigner': 'RiceGnat',
#     'rating': 3},
#    {'ratingClass': 1,
#     'chartDesigner': 'Toaster',
#     'jacketDesigner': 'RiceGnat',
#     'rating': 6},
#    {'ratingClass': 2,
#     'chartDesigner': 'Toaster',
#     'jacketDesigner': 'RiceGnat',
#     'rating': 9}]},
#  {'id': 'reinvent',
#   'title_localized': {'en': 'Reinvent'},
#   'artist': 'Sound Souler',
#   'bpm': '174',
#   'bpm_base': 174,
#   'set': 'base',
#   'purchase': '',
#   'audioPreview': 89655,
#   'audioPreviewEnd': 122758,
#   'side': 0,
#   'bg': '',
#   'date': 1513814400,
#   'difficulties': [{'ratingClass': 0,
#     'chartDesigner': 'k//eternal',
#     'jacketDesigner': 'Khronetic',
#     'rating': 2},
#    {'ratingClass': 1,
#     'chartDesigner': 'k//eternal',
#     'jacketDesigner': 'Khronetic',
#     'rating': 6},
#    {'ratingClass': 2,
#     'chartDesigner': 'k//eternal + nitro',
#     'jacketDesigner': 'Khronetic',
#     'rating': 8}]},
#  {'id': 'silentrush',
#   'title_localized': {'en': 'Silent Rush'},
#   'artist': 'Soleily',
#   'bpm': '158',
#   'bpm_base': 158,
#   'set': 'nijuusei',
#   'purchase': 'nijuusei',
#   'audioPreview': 24446,
#   'audioPreviewEnd': 48750,
#   'side': 1,
#   'bg': 'nijuusei-conflict-b',
#   'remote_dl': True,
#   'date': 1521763201,
#   'difficulties': [{'ratingClass': 0,
#     'chartDesigner': 'TaroNuke',
#     'jacketDesigner': 'CinEraLiA',
#     'rating': 2},
#    {'ratingClass': 1,
#     'chartDesigner': 'TaroNuke',
#     'jacketDesigner': 'CinEraLiA',
#     'rating': 5},
#    {'ratingClass': 2,
#     'chartDesigner': 'TaroNuke',
#     'jacketDesigner': 'CinEraLiA',
#     'rating': 8}]},
#  {'id': 'singularity',
#   'title_localized': {'en': 'Singularity'},
#   'artist': 'ETIA.',
#   'bpm': '175',
#   'bpm_base': 175,
#   'set': 'nijuusei',
#   'purchase': 'nijuusei',
#   'audioPreview': 12342,
#   'audioPreviewEnd': 38400,
#   'side': 1,
#   'bg': 'nijuusei-conflict-b',
#   'remote_dl': True,
#   'date': 1521763204,
#   'difficulties': [{'ratingClass': 0,
#     'chartDesigner': '東星',
#     'jacketDesigner': 'シエラ',
#     'rating': 4},
#    {'ratingClass': 1,
#     'chartDesigner': '東星',
#     'jacketDesigner': 'シエラ',
#     'rating': 7},
#    {'ratingClass': 2,
#     'chartDesigner': '東星※コラプサー',
#     'jacketDesigner': 'シエラ',
#     'rating': 10}]},
#  {'id': 'memoryforest',
#   'title_localized': {'en': 'Memory Forest'},
#   'artist': 'ETIA.',
#   'bpm': '178',
#   'bpm_base': 178,
#   'set': 'nijuusei',
#   'purchase': 'nijuusei',
#   'audioPreview': 21584,
#   'audioPreviewEnd': 53944,
#   'side': 0,
#   'bg': 'nijuusei-light-b',
#   'remote_dl': True,
#   'date': 1521763203,
#   'difficulties': [{'ratingClass': 0,
#     'chartDesigner': 'Kurorak',
#     'jacketDesigner': 'シエラ',
#     'rating': 3},
#    {'ratingClass': 1,
#     'chartDesigner': 'Kurorak',
#     'jacketDesigner': 'シエラ',
#     'rating': 6},
#    {'ratingClass': 2,
#     'chartDesigner': 'Kurorak',
#     'jacketDesigner': 'シエラ',
#     'rating': 9}]},
#  {'id': 'strongholds',
#   'title_localized': {'en': 'Strongholds'},
#   'artist': 'Yooh',
#   'bpm': '105',
#   'bpm_base': 210,
#   'set': 'nijuusei',
#   'purchase': 'nijuusei',
#   'audioPreview': 38851,
#   'audioPreviewEnd': 66280,
#   'side': 1,
#   'bg': 'nijuusei-conflict-b',
#   'remote_dl': True,
#   'date': 1521763202,
#   'difficulties': [{'ratingClass': 0,
#     'chartDesigner': 'TaroNuke',
#     'jacketDesigner': '八葉',
#     'rating': 2},
#    {'ratingClass': 1,
#     'chartDesigner': 'TaroNukeΔ',
#     'jacketDesigner': '八葉',
#     'rating': 5},
#    {'ratingClass': 2,
#     'chartDesigner': 'TΔroNuke',
#     'jacketDesigner': '八葉',
#     'rating': 9}]},
#  {'id': 'nexttoyou',
#   'title_localized': {'en': 'next to you'},
#   'artist': 'uma feat. 橘花音',
#   'bpm': '165',
#   'bpm_base': 165,
#   'set': 'nijuusei',
#   'purchase': 'nijuusei',
#   'audioPreview': 51636,
#   'audioPreviewEnd': 78545,
#   'side': 0,
#   'bg': 'nijuusei-light-b',
#   'remote_dl': True,
#   'date': 1521763200,
#   'difficulties': [{'ratingClass': 0,
#     'chartDesigner': 'Nitro',
#     'jacketDesigner': 'mins',
#     'rating': 4},
#    {'ratingClass': 1,
#     'chartDesigner': 'Nitro',
#     'jacketDesigner': 'mins',
#     'rating': 7},
#    {'ratingClass': 2,
#     'chartDesigner': 'Nitro',
#     'jacketDesigner': 'mins',
#     'rating': 8}]},
#  {'id': 'metallicpunisher',
#   'title_localized': {'en': 'Metallic Punisher'},
#   'artist': 'INNOCENT NOIZE',
#   'bpm': '165',
#   'bpm_base': 165,
#   'set': 'single',
#   'purchase': 'metallicpunisher',
#   'audioPreview': 0,
#   'audioPreviewEnd': 0,
#   'side': 1,
#   'bg': 'yugamu',
#   'remote_dl': True,
#   'date': 1518480000,
#   'difficulties': [{'ratingClass': 0,
#     'chartDesigner': 'Kurorak',
#     'jacketDesigner': 'nonokuro',
#     'rating': 3},
#    {'ratingClass': 1,
#     'chartDesigner': 'Kurorak',
#     'jacketDesigner': 'nonokuro',
#     'rating': 7},
#    {'ratingClass': 2,
#     'chartDesigner': 'Black Tea',
#     'jacketDesigner': 'nonokuro',
#     'rating': 10}]},
#  {'id': 'blaster',
#   'title_localized': {'en': 'Blaster'},
#   'artist': 'Massive New Krew',
#   'bpm': '180',
#   'bpm_base': 180,
#   'set': 'base',
#   'purchase': '',
#   'audioPreview': 23999,
#   'audioPreviewEnd': 55999,
#   'side': 1,
#   'bg': 'yugamu',
#   'remote_dl': False,
#   'world_unlock': True,
#   'date': 1520553600,
#   'difficulties': [{'ratingClass': 0,
#     'chartDesigner': 'k//urorak',
#     'jacketDesigner': 'LAM',
#     'rating': 4},
#    {'ratingClass': 1,
#     'chartDesigner': 'k//urorak',
#     'jacketDesigner': 'LAM',
#     'rating': 7},
#    {'ratingClass': 2,
#     'chartDesigner': 'k//urorak',
#     'jacketDesigner': 'LAM',
#     'rating': 9}]},
#  {'id': 'guardina',
# ...
#     'chartDesigner': 'OptoNuke',
#     'jacketDesigner': '',
#     'rating': 6},
#    {'ratingClass': 2,
#     'chartDesigner': 'OptoNuke',
#     'jacketDesigner': '',
#     'rating': 8}]},
#  {'id': 'stager',
#   'title_localized': {'en': 'STAGER (ALL STAGE CLEAR)'},
#   'artist': 'Ras',
#   'bpm': '145',
#   'bpm_base': 145,
#   'set': 'tonesphere',
#   'purchase': 'tonesphere',
#   'audioPreview': 105087,
#   'audioPreviewEnd': 132398,
#   'side': 0,
#   'bg': 'tonesphere-solarsphere',
#   'remote_dl': True,
#   'source_localized': {'en': 'Tone Sphere'},
#   'date': 1538870402,
#   'difficulties': [{'ratingClass': 0,
#     'chartDesigner': 'KURORAK',
#     'jacketDesigner': '',
#     'rating': 3,
#     'jacketOverride': True},
#    {'ratingClass': 1,
#     'chartDesigner': 'KURORAK',
#     'jacketDesigner': '',
#     'rating': 6,
#     'jacketOverride': True},
#    {'ratingClass': 2,
#     'chartDesigner': 'KURORAK',
#     'jacketDesigner': '',
#     'rating': 9}]},
#  {'id': 'hallofmirrors',
#   'title_localized': {'en': 'Hall of Mirrors'},
#   'artist': 'Sta',
#   'bpm': '147',
#   'bpm_base': 147.01,
#   'set': 'tonesphere',
#   'purchase': 'tonesphere',
#   'audioPreview': 79908,
#   'audioPreviewEnd': 112160,
#   'side': 1,
#   'bg': 'tonesphere-darksphere',
#   'remote_dl': True,
#   'source_localized': {'en': 'Tone Sphere'},
#   'date': 1538870401,
#   'difficulties': [{'ratingClass': 0,
#     'chartDesigner': 'Toaster',
#     'jacketDesigner': '',
#     'rating': 3},
#    {'ratingClass': 1,
#     'chartDesigner': 'Toaster',
#     'jacketDesigner': '',
#     'rating': 5},
#    {'ratingClass': 2,
#     'chartDesigner': 'Toaster',
#     'jacketDesigner': '',
#     'rating': 8}]},
#  {'id': 'linearaccelerator',
#   'title_localized': {'en': 'Linear Accelerator'},
#   'artist': 'THE SHAFT',
#   'bpm': '200 - 211.9',
#   'bpm_base': 200,
#   'set': 'tonesphere',
#   'purchase': 'tonesphere',
#   'audioPreview': 41979,
#   'audioPreviewEnd': 76279,
#   'side': 0,
#   'bg': 'tonesphere-solarsphere',
#   'remote_dl': True,
#   'source_localized': {'en': 'Tone Sphere'},
#   'date': 1538870403,
#   'difficulties': [{'ratingClass': 0,
#     'chartDesigner': 'THE TOAST',
#     'jacketDesigner': '',
#     'rating': 2},
#    {'ratingClass': 1,
#     'chartDesigner': 'THE TOAST',
#     'jacketDesigner': '',
#     'rating': 6},
#    {'ratingClass': 2,
#     'chartDesigner': 'THE TOAST',
#     'jacketDesigner': '',
#     'rating': 9}]},
#  {'id': 'tiferet',
#   'title_localized': {'en': 'Tiferet'},
#   'artist': 'xi + Sta',
#   'bpm': '140?',
#   'bpm_base': 140,
#   'set': 'tonesphere',
#   'purchase': 'tonesphere',
#   'audioPreview': 32644,
#   'audioPreviewEnd': 58358,
#   'side': 1,
#   'bg': 'tiferet',
#   'remote_dl': True,
#   'source_localized': {'en': 'Tone Sphere'},
#   'date': 1538870404,
#   'difficulties': [{'ratingClass': 0,
#     'chartDesigner': '夜浪[Spherical]',
#     'jacketDesigner': '',
#     'rating': 4},
#    {'ratingClass': 1,
#     'chartDesigner': '夜浪[Spherical]',
#     'jacketDesigner': '',
#     'rating': 7},
#    {'ratingClass': 2,
#     'chartDesigner': '夜浪[Spherical]',
#     'jacketDesigner': '',
#     'rating': 10}]},
#  {'id': 'alexandrite',
#   'title_localized': {'en': 'Alexandrite'},
#   'artist': 'WAiKURO',
#   'bpm': '146',
#   'bpm_base': 146,
#   'set': 'single',
#   'purchase': 'alexandrite',
#   'audioPreview': 0,
#   'audioPreviewEnd': 0,
#   'side': 1,
#   'remote_dl': True,
#   'bg': 'alexandrite',
#   'date': 1537142401,
#   'difficulties': [{'ratingClass': 0,
#     'chartDesigner': '東星※空の宝石',
#     'jacketDesigner': 'シエラ',
#     'rating': 4},
#    {'ratingClass': 1,
#     'chartDesigner': '東星※空の宝石',
#     'jacketDesigner': 'シエラ',
#     'rating': 7},
#    {'ratingClass': 2,
#     'chartDesigner': '東星※空の宝石',
#     'jacketDesigner': 'シエラ',
#     'rating': 9}]},
#  {'id': 'rugie',
#   'title_localized': {'en': 'Rugie'},
#   'artist': 'Feryquitous feat.Sennzai',
#   'bpm': '191',
#   'bpm_base': 191,
#   'set': 'base',
#   'purchase': '',
#   'audioPreview': 96606,
#   'audioPreviewEnd': 126920,
#   'side': 1,
#   'bg': '',
#   'world_unlock': True,
#   'date': 1541635200,
#   'difficulties': [{'ratingClass': 0,
#     'chartDesigner': 'k//urorak',
#     'jacketDesigner': '',
#     'rating': 3},
#    {'ratingClass': 1,
#     'chartDesigner': 'k//urorak',
#     'jacketDesigner': '',
#     'rating': 6},
#    {'ratingClass': 2,
#     'chartDesigner': 'k//urorak',
#     'jacketDesigner': '',
#     'rating': 9}]},
#  {'id': 'astraltale',
#   'title_localized': {'en': 'Astral tale'},
#   'artist': 'Noah',
#   'bpm': '134',
#   'bpm_base': 134,
#   'set': 'single',
#   'purchase': 'astraltale',
#   'audioPreview': 0,
#   'audioPreviewEnd': 0,
#   'side': 1,
#   'bg': 'nijuusei-conflict-b',
#   'remote_dl': True,
#   'world_unlock': False,
#   'date': 1541635201,
#   'difficulties': [{'ratingClass': 0,
#     'chartDesigner': 'Nitro',
#     'jacketDesigner': '岩十',
#     'rating': 4},
#    {'ratingClass': 1,
#     'chartDesigner': 'Nitro',
#     'jacketDesigner': '岩十',
#     'rating': 7},
#    {'ratingClass': 2,
#     'chartDesigner': 'Nitro',
#     'jacketDesigner': '岩十',
#     'rating': 9}]},
#  {'id': 'phantasia',
#   'title_localized': {'en': 'Phantasia'},
#   'artist': 'Yunosuke',
#   'bpm': '153',
#   'bpm_base': 153,
#   'set': 'single',
#   'purchase': 'phantasia',
#   'audioPreview': 0,
#   'audioPreviewEnd': 30000,
#   'side': 0,
#   'bg': 'rei',
#   'remote_dl': True,
#   'world_unlock': False,
#   'date': 1543449600,
#   'difficulties': [{'ratingClass': 0,
#     'chartDesigner': 'Toaster',
#     'jacketDesigner': 'そゐち',
#     'rating': 4},
#    {'ratingClass': 1,
#     'chartDesigner': 'Toaster',
#     'jacketDesigner': 'そゐち',
#     'rating': 5},
#    {'ratingClass': 2,
#     'chartDesigner': 'Toaster',
#     'jacketDesigner': 'そゐち',
#     'rating': 9}]},
#  {'id': 'empireofwinter',
#   'title_localized': {'en': 'Empire of Winter'},
#   'artist': 'Street',
#   'bpm': '175',
#   'bpm_base': 175,
#   'set': 'single',
#   'purchase': 'empireofwinter',
#   'audioPreview': 0,
#   'audioPreviewEnd': 0,
#   'side': 0,
#   'bg': 'nijuusei-light-b',
#   'remote_dl': True,
#   'world_unlock': False,
#   'date': 1545523200,
#   'difficulties': [{'ratingClass': 0,
#     'chartDesigner': '0°Nitro',
#     'jacketDesigner': 'シエラ + Khronetic',
#     'rating': 3},
#    {'ratingClass': 1,
#     'chartDesigner': '0°Nitro',
#     'jacketDesigner': 'シエラ + Khronetic',
#     'rating': 6},
#    {'ratingClass': 2,
#     'chartDesigner': '0°Nitro',
#     'jacketDesigner': 'シエラ + Khronetic',
#     'rating': 9}]},
#  {'id': 'merlin',
#   'title_localized': {'en': 'MERLIN'},
#   'artist': 'REDALiCE',
#   'bpm': '180',
#   'bpm_base': 180,
#   'set': 'groovecoaster',
#   'purchase': 'groovecoaster',
#   'audioPreview': 66166,
#   'audioPreviewEnd': 88000,
#   'side': 0,
#   'source_localized': {'en': 'Groove Coaster', 'ja': 'グルーヴコースター'},
#   'source_copyright': '© TAITO CORP. 1978, 2019',
#   'bg': 'gc_light',
#   'remote_dl': True,
#   'world_unlock': False,
#   'date': 1546992000,
#   'difficulties': [{'ratingClass': 0,
#     'chartDesigner': 'Got More Taro?',
#     'jacketDesigner': '',
#     'rating': 3},
#    {'ratingClass': 1,
#     'chartDesigner': 'Got More Taro?',
#     'jacketDesigner': '',
#     'rating': 5},
#    {'ratingClass': 2,
#     'chartDesigner': 'Got More Taro?',
#     'jacketDesigner': '',
#     'rating': 8}]},
#  {'id': 'dxfullmetal',
#   'title_localized': {'ja': 'DX超性能フルメタル少女',
#    'en': 'DX Choseinou Full Metal Shojo'},
#   'artist': 'IOSYS TRAX (uno with.ちよこ)',
#   'bpm': '160',
#   'bpm_base': 160,
#   'set': 'groovecoaster',
#   'purchase': 'groovecoaster',
#   'audioPreview': 15603,
#   'audioPreviewEnd': 39603,
#   'side': 0,
#   'source_localized': {'en': 'Groove Coaster', 'ja': 'グルーヴコースター'},
#   'source_copyright': '© TAITO CORP. 1978, 2019',
#   'world_unlock': False,
#   'bg': 'gc_light',
#   'remote_dl': True,
#   'date': 1546992001,
#   'difficulties': [{'ratingClass': 0,
#     'chartDesigner': 'DX譜面作者フルメタルNitro',
#     'jacketDesigner': '',
#     'rating': 3},
#    {'ratingClass': 1,
#     'chartDesigner': 'DX譜面作者フルメタルNitro',
#     'jacketDesigner': '',
#     'rating': 6},
#    {'ratingClass': 2,
#     'chartDesigner': 'DX譜面作者フルメタルNitro',
#     'jacketDesigner': '',
#     'rating': 9}]},
#  {'id': 'omakeno',
#   'title_localized': {'en': 'OMAKENO Stroke'},
#   'artist': 't+pazolite',
#   'bpm': '240',
#   'bpm_base': 240,
#   'set': 'groovecoaster',
#   'purchase': 'groovecoaster',
#   'audioPreview': 2701,
#   'audioPreviewEnd': 17701,
#   'side': 1,
#   'source_localized': {'en': 'Groove Coaster', 'ja': 'グルーヴコースター'},
#   'source_copyright': '© TAITO CORP. 1978, 2019',
#   'world_unlock': False,
#   'bg': 'gc_conflict',
#   'remote_dl': True,
#   'date': 1546992002,
#   'difficulties': [{'ratingClass': 0,
#     'chartDesigner': 'Kurorak',
#     'jacketDesigner': '',
#     'rating': 3},
#    {'ratingClass': 1,
#     'chartDesigner': 'Kurorak',
#     'jacketDesigner': '',
#     'rating': 6},
#    {'ratingClass': 2,
#     'chartDesigner': 'Kurorak',
#     'jacketDesigner': '',
#     'rating': 9}]},
#  {'id': 'scarletlance',
#   'title_localized': {'en': 'Scarlet Lance'},
#   'artist': 'MASAKI (ZUNTATA)',
#   'bpm': '185',
#   'bpm_base': 185,
#   'set': 'groovecoaster',
#   'purchase': 'groovecoaster',
#   'audioPreview': 9081,
#   'audioPreviewEnd': 35027,
#   'side': 0,
#   'source_localized': {'en': 'Groove Coaster', 'ja': 'グルーヴコースター'},
#   'source_copyright': '© TAITO CORP. 1978, 2019',
#   'world_unlock': False,
#   'bg': 'gc_lance',
#   'remote_dl': True,
#   'date': 1546992003,
#   'difficulties': [{'ratingClass': 0,
#     'chartDesigner': '闇運',
#     'jacketDesigner': '',
#     'rating': 4},
#    {'ratingClass': 1,
#     'chartDesigner': '闇運',
#     'jacketDesigner': '',
#     'rating': 7},
#    {'ratingClass': 2,
#     'chartDesigner': '闇運',
#     'jacketDesigner': '',
#     'rating': 10}]},
#  {'id': 'ouroboros',
#   'title_localized': {'en': 'ouroboros -twin stroke of the end-'},
#   'artist': 'Cranky VS MASAKI',
#   'bpm': '188',
#   'bpm_base': 188,
#   'set': 'groovecoaster',
#   'purchase': 'groovecoaster',
#   'audioPreview': 79389,
#   'audioPreviewEnd': 110028,
#   'side': 1,
#   'source_localized': {'en': 'Groove Coaster', 'ja': 'グルーヴコースター'},
#   'source_copyright': '© TAITO CORP. 1978, 2019',
#   'world_unlock': False,
#   'bg': 'gc_ouroboros',
#   'remote_dl': True,
#   'date': 1546992004,
#   'difficulties': [{'ratingClass': 0,
#     'chartDesigner': 'Groove 東星',
#     'jacketDesigner': '',
#     'rating': 4},
#    {'ratingClass': 1,
#     'chartDesigner': 'Groove 東星',
#     'jacketDesigner': '',
#     'rating': 7},
#    {'ratingClass': 2,
#     'chartDesigner': 'Groove 東星',
#     'jacketDesigner': '',
#     'rating': 10}]},
#  {'id': 'libertas',
#   'title_localized': {'en': 'Libertas'},
#   'artist': 'Zekk',
#   'bpm': '160',
#   'bpm_base': 160,
#   'set': 'single',
#   'purchase': 'libertas',
#   'audioPreview': 0,
#   'audioPreviewEnd': 0,
#   'side': 0,
#   'bg': 'single_light',
#   'remote_dl': True,
#   'world_unlock': False,
#   'date': 1549843200,
#   'difficulties': [{'ratingClass': 0,
#     'chartDesigner': 'Kurorak',
#     'jacketDesigner': 'wacca',
#     'rating': 3},
#    {'ratingClass': 1,
#     'chartDesigner': 'Kurorak',
#     'jacketDesigner': 'wacca',
#     'rating': 5},
#    {'ratingClass': 2,
#     'chartDesigner': 'Kurorak + Nitro',
#     'jacketDesigner': 'wacca',
#     'rating': 9}]},
#  {'id': 'solitarydream',
#   'title_localized': {'en': 'Solitary Dream', 'ja': '虚空の夢'},
#   'jacket_localized': {'ja': True},
#   'artist': 'ak+q feat. Sennzai',
#   'bpm': '162',
#   'bpm_base': 162,
#   'set': 'core',
#   'purchase': 'core',
#   'audioPreview': 49629,
#   'audioPreviewEnd': 68148,
#   'side': 0,
#   'bg': 'solitarydream',
#   'remote_dl': True,
#   'world_unlock': True,
#   'date': 1552089600,
#   'difficulties': [{'ratingClass': 0,
#     'chartDesigner': '',
#     'jacketDesigner': 'シエラ',
#     'rating': 4},
#    {'ratingClass': 1,
#     'chartDesigner': '',
#     'jacketDesigner': 'シエラ',
#     'rating': 7},
#    {'ratingClass': 2,
#     'chartDesigner': '',
#     'jacketDesigner': 'シエラ',
#     'rating': 8}]},
#  {'id': 'antithese',
#   'title_localized': {'en': 'Antithese'},
#   'artist': 'Blacklolita',
#   'bpm': '172',
#   'bpm_base': 172,
#   'set': 'zettai',
#   'purchase': 'zettai',
#   'audioPreview': 0,
#   'audioPreviewEnd': 0,
#   'side': 1,
#   'bg': 'zettai',
#   'remote_dl': True,
#   'world_unlock': False,
#   'date': 1553126402,
#   'difficulties': [{'ratingClass': 0,
#     'chartDesigner': 'chaos//engine',
#     'jacketDesigner': '釜飯轟々丸 + Khronetic',
#     'rating': 2},
#    {'ratingClass': 1,
#     'chartDesigner': 'chaos//engine',
#     'jacketDesigner': '釜飯轟々丸 + Khronetic',
#     'rating': 5},
#    {'ratingClass': 2,
#     'chartDesigner': 'chaos//engine',
#     'jacketDesigner': '釜飯轟々丸 + Khronetic',
#     'rating': 8}]},
#  {'id': 'corruption',
#   'title_localized': {'en': 'Corruption'},
#   'artist': '3R2',
#   'bpm': '170',
#   'bpm_base': 170,
#   'set': 'zettai',
#   'purchase': 'zettai',
#   'audioPreview': 0,
#   'audioPreviewEnd': 0,
#   'side': 1,
#   'bg': 'zettai',
#   'remote_dl': True,
#   'world_unlock': False,
#   'date': 1553126404,
#   'difficulties': [{'ratingClass': 0,
#     'chartDesigner': '₸öα$†ε₹',
#     'jacketDesigner': 'BerryVerrine',
#     'rating': 3},
#    {'ratingClass': 1,
#     'chartDesigner': '₸öα$†ε₹',
#     'jacketDesigner': 'BerryVerrine',
#     'rating': 6},
#    {'ratingClass': 2,
#     'chartDesigner': '₸öα$†ε₹',
#     'jacketDesigner': 'BerryVerrine',
#     'rating': 9}]},
#  {'id': 'blackterritory',
#   'title_localized': {'en': 'Black Territory'},
#   'artist': 'DJ Myosuke',
#   'bpm': '200',
#   'bpm_base': 200,
#   'set': 'zettai',
#   'purchase': 'zettai',
#   'audioPreview': 0,
#   'audioPreviewEnd': 0,
#   'side': 1,
#   'bg': 'zettai',
#   'remote_dl': True,
#   'world_unlock': False,
#   'date': 1553126403,
#   'difficulties': [{'ratingClass': 0,
#     'chartDesigner': 'NitroNukeδ',
#     'jacketDesigner': 'トロ3',
#     'rating': 3},
#    {'ratingClass': 1,
#     'chartDesigner': 'NitroNukeδ',
#     'jacketDesigner': 'トロ3',
#     'rating': 7},
#    {'ratingClass': 2,
#     'chartDesigner': 'NitroNukeδ',
#     'jacketDesigner': 'トロ3',
#     'rating': 9}]},
#  {'id': 'viciousheroism',
#   'title_localized': {'en': 'Vicious Heroism'},
#   'artist': 'Kobaryo',
#   'bpm': '256',
#   'bpm_base': 256,
#   'set': 'zettai',
#   'purchase': 'zettai',
#   'audioPreview': 0,
#   'audioPreviewEnd': 0,
#   'side': 1,
#   'bg': 'zettai',
#   'remote_dl': True,
#   'world_unlock': False,
#   'date': 1553126405,
#   'difficulties': [{'ratingClass': 0,
#     'chartDesigner': 'Nitro vanquish Toaster.',
#     'jacketDesigner': '吠L',
#     'rating': 4},
#    {'ratingClass': 1,
#     'chartDesigner': 'Nitro vanquish Toaster.',
#     'jacketDesigner': '吠L',
#     'rating': 7},
#    {'ratingClass': 2,
#     'chartDesigner': 'Nitro vanquish Toaster.',
#     'jacketDesigner': '吠L',
#     'rating': 9}]},
#  {'id': 'cyaegha',
#   'title_localized': {'en': 'Cyaegha'},
#   'artist': 'USAO',
#   'bpm': '200',
#   'bpm_base': 200,
#   'set': 'zettai',
#   'purchase': 'zettai',
#   'audioPreview': 0,
#   'audioPreviewEnd': 0,
#   'side': 1,
#   'bg': 'cyaegha',
#   'remote_dl': True,
#   'world_unlock': False,
#   'date': 1553126406,
#   'difficulties': [{'ratingClass': 0,
#     'chartDesigner': '夜浪、旧支配者',
#     'jacketDesigner': 'シエラ',
#     'rating': 5},
#    {'ratingClass': 1,
#     'chartDesigner': '夜浪、旧支配者',
#     'jacketDesigner': 'シエラ',
#     'rating': 8},
#    {'ratingClass': 2,
#     'chartDesigner': '夜浪、旧支配者',
#     'jacketDesigner': 'シエラ',
#     'rating': 10}]},
#  {'id': 'revixy',
#   'title_localized': {'en': 'ReviXy'},
#   'artist': 'ikaruga_nex',
#   'bpm': '115-185',
#   'bpm_base': 185,
#   'set': 'base',
#   'purchase': '',
#   'audioPreview': 33333,
#   'audioPreviewEnd': 54666,
#   'side': 1,
#   'bg': '',
#   'world_unlock': True,
#   'date': 1553126401,
#   'difficulties': [{'ratingClass': 0,
#     'chartDesigner': 'Revoke Kurorak',
#     'jacketDesigner': '出前',
#     'rating': 3},
#    {'ratingClass': 1,
#     'chartDesigner': 'Revoke Kurorak',
#     'jacketDesigner': '出前',
#     'rating': 6},
#    {'ratingClass': 2,
#     'chartDesigner': 'Revoke Kurorak',
#     'jacketDesigner': '出前',
#     'rating': 8}]},
#  {'id': 'grimheart',
#   'title_localized': {'en': 'Grimheart'},
#   'artist': 'Puru',
#   'bpm': '170',
#   'bpm_base': 170,
#   'set': 'base',
#   'purchase': '',
#   'audioPreview': 103761,
#   'audioPreviewEnd': 127055,
#   'side': 0,
#   'bg': 'rei',
#   'world_unlock': True,
#   'date': 1553126400,
#   'difficulties': [{'ratingClass': 0,
#     'chartDesigner': 'Toaster',
#     'jacketDesigner': '',
#     'rating': 2},
#    {'ratingClass': 1,
#     'chartDesigner': 'Toaster',
#     'jacketDesigner': '',
#     'rating': 5},
#    {'ratingClass': 2,
#     'chartDesigner': 'Toaster',
#     'jacketDesigner': '',
#     'rating': 8}]}]

# %%
song_id = []
for song in songlist:
    song_id.append({'id':song['id'],'name':song['title_localized']['en'], 'level':[diff['rating'] for diff in song['difficulties']]})

# %%
song_id
# Out:
# [{'id': 'sayonarahatsukoi', 'name': 'Sayonara Hatsukoi', 'level': [1, 4, 6]},
#  {'id': 'lostcivilization', 'name': 'Lost Civilization', 'level': [4, 7, 9]},
#  {'id': 'goodtek', 'name': 'GOODTEK (Arcaea Edit)', 'level': [4, 6, 9]},
#  {'id': 'viyella', 'name': 'cry of viyella', 'level': [3, 6, 8]},
#  {'id': 'rise', 'name': 'Rise', 'level': [2, 4, 7]},
#  {'id': 'lucifer', 'name': 'Lucifer', 'level': [3, 5, 8]},
#  {'id': 'fairytale', 'name': 'Fairytale', 'level': [1, 3, 7]},
#  {'id': 'hearditsaid', 'name': "I've heard it said", 'level': [3, 6, 8]},
#  {'id': 'babaroque', 'name': 'Babaroque', 'level': [3, 6, 8]},
#  {'id': 'memoryfactory', 'name': 'memoryfactory.lzh', 'level': [2, 5, 8]},
#  {'id': 'snowwhite', 'name': 'Snow White', 'level': [2, 5, 8]},
#  {'id': 'relentless', 'name': 'Relentless', 'level': [4, 6, 8]},
#  {'id': 'shadesoflight',
#   'name': 'Shades of Light in a Transcendent Realm',
#   'level': [3, 6, 8]},
#  {'id': 'vexaria', 'name': 'Vexaria', 'level': [2, 5, 7]},
#  {'id': 'essenceoftwilight',
#   'name': 'Essence of Twilight',
#   'level': [4, 7, 9]},
#  {'id': 'qualia', 'name': 'qualia -ideaesthesia-', 'level': [5, 7, 9]},
#  {'id': 'pragmatism', 'name': 'PRAGMATISM', 'level': [4, 8, 10]},
#  {'id': 'sheriruth', 'name': 'Sheriruth', 'level': [5, 7, 10]},
#  {'id': 'lumia', 'name': 'Lumia', 'level': [2, 6, 8]},
#  {'id': 'dement', 'name': 'Dement ~after legend~', 'level': [3, 6, 7]},
#  {'id': 'dandelion', 'name': 'Dandelion', 'level': [2, 6, 8]},
#  {'id': 'anokumene', 'name': 'Anökumene', 'level': [2, 6, 9]},
#  {'id': 'infinityheaven', 'name': 'Infinity Heaven', 'level': [1, 5, 7]},
#  {'id': 'partyvinyl', 'name': 'Party Vinyl', 'level': [4, 7, 9]},
#  {'id': 'flashback', 'name': 'Flashback', 'level': [2, 5, 8]},
#  {'id': 'flyburg', 'name': 'Flyburg and Endroll', 'level': [3, 6, 9]},
#  {'id': 'nirvluce', 'name': 'Nirv lucE', 'level': [2, 7, 10]},
#  {'id': 'paradise', 'name': 'Paradise', 'level': [1, 4, 7]},
#  {'id': 'brandnewworld', 'name': 'Brand new world', 'level': [2, 4, 7]},
#  {'id': 'dataerror', 'name': 'DataErr0r', 'level': [3, 7, 9]},
#  {'id': 'crosssoul', 'name': 'CROSS†SOUL', 'level': [4, 7, 9]},
#  {'id': 'yourvoiceso',
#   'name': 'Your voice so... feat. Such',
#   'level': [3, 6, 9]},
#  {'id': 'chronostasis', 'name': 'Chronostasis', 'level': [3, 7, 9]},
#  {'id': 'kanagawa', 'name': 'Kanagawa Cyber Culvert', 'level': [1, 5, 9]},
#  {'id': 'moonlightofsandcastle',
#   'name': 'Moonlight of Sand Castle',
#   'level': [1, 5, 7]},
#  {'id': 'reconstruction', 'name': 'REconstruction', 'level': [2, 6, 8]},
#  {'id': 'evoltex', 'name': "Evoltex (poppi'n mix)", 'level': [2, 7, 8]},
#  {'id': 'oracle', 'name': 'Oracle', 'level': [3, 5, 9]},
#  {'id': 'aterlbus', 'name': 'αterlβus', 'level': [4, 7, 10]},
#  {'id': 'clotho', 'name': 'Clotho and the stargazer', 'level': [2, 5, 7]},
#  {'id': 'impurebird', 'name': 'Impure Bird', 'level': [2, 5, 9]},
#  {'id': 'ignotus', 'name': 'Ignotus', 'level': [3, 6, 9]},
#  {'id': 'lethaeus', 'name': 'Lethaeus', 'level': [3, 6, 9]},
#  {'id': 'romancewars', 'name': 'Romance Wars', 'level': [1, 4, 7]},
#  {'id': 'blossoms', 'name': 'Blossoms', 'level': [1, 4, 7]},
#  {'id': 'moonheart', 'name': 'Moonheart', 'level': [2, 5, 8]},
#  {'id': 'genesis', 'name': 'Genesis', 'level': [2, 5, 8]},
#  {'id': 'harutopia',
#   'name': 'Harutopia ~Utopia of Spring~',
#   'level': [1, 4, 8]},
#  {'id': 'auxesia', 'name': 'Auxesia', 'level': [3, 6, 9]},
#  {'id': 'rabbitintheblackroom',
#   'name': 'Rabbit In The Black Room',
#   'level': [2, 5, 8]},
#  {'id': 'modelista', 'name': 'Modelista', 'level': [3, 7, 9]},
#  {'id': 'soundwitch', 'name': 'SOUNDWiTCH', 'level': [3, 6, 9]},
#  {'id': 'trappola', 'name': 'trappola bewitching', 'level': [3, 6, 9]},
#  {'id': 'iconoclast', 'name': 'Iconoclast', 'level': [4, 7, 9]},
#  {'id': 'conflict', 'name': 'conflict', 'level': [4, 7, 10]},
#  {'id': 'axiumcrisis', 'name': 'Axium Crisis', 'level': [5, 8, 10]},
#  {'id': 'grievouslady', 'name': 'Grievous Lady', 'level': [6, 9, 11]},
#  {'id': 'dreaminattraction',
#   'name': "Dreamin' Attraction!!",
#   'level': [4, 7, 9]},
#  {'id': 'redandblue', 'name': 'Red and Blue', 'level': [4, 7, 9]},
#  {'id': 'onelastdrive', 'name': 'One Last Drive', 'level': [2, 5, 8]},
#  {'id': 'surrender', 'name': 'Surrender', 'level': [3, 6, 8]},
#  {'id': 'yozakurafubuki', 'name': 'Yosakura Fubuki', 'level': [4, 7, 9]},
#  {'id': 'cyanine', 'name': 'cyanine', 'level': [4, 7, 10]},
#  {'id': 'dreamgoeson', 'name': 'Dream goes on', 'level': [1, 5, 7]},
#  {'id': 'journey', 'name': 'Journey', 'level': [3, 6, 8]},
#  {'id': 'specta', 'name': 'Specta', 'level': [3, 6, 9]},
#  {'id': 'quon', 'name': 'Quon', 'level': [4, 6, 9]},
#  {'id': 'syro', 'name': 'Syro', 'level': [3, 6, 9]},
#  {'id': 'reinvent', 'name': 'Reinvent', 'level': [2, 6, 8]},
#  {'id': 'silentrush', 'name': 'Silent Rush', 'level': [2, 5, 8]},
#  {'id': 'singularity', 'name': 'Singularity', 'level': [4, 7, 10]},
#  {'id': 'memoryforest', 'name': 'Memory Forest', 'level': [3, 6, 9]},
#  {'id': 'strongholds', 'name': 'Strongholds', 'level': [2, 5, 9]},
#  {'id': 'nexttoyou', 'name': 'next to you', 'level': [4, 7, 8]},
#  {'id': 'metallicpunisher', 'name': 'Metallic Punisher', 'level': [3, 7, 10]},
#  {'id': 'blaster', 'name': 'Blaster', 'level': [4, 7, 9]},
#  {'id': 'guardina', 'name': 'γuarδina', 'level': [4, 7, 10]},
#  {'id': 'carminescythe', 'name': 'carmine:scythe', 'level': [4, 7, 9]},
#  {'id': 'bethere', 'name': 'Be There', 'level': [4, 7, 9]},
#  {'id': 'cyberneciacatharsis',
#   'name': 'Cybernecia Catharsis',
#   'level': [4, 7, 9]},
#  {'id': 'callmyname',
#   'name': 'Call My Name feat. Yukacco',
#   'level': [3, 6, 8]},
#  {'id': 'inkarusi', 'name': 'inkar-usi', 'level': [2, 4, 7]},
#  {'id': 'mazenine', 'name': 'Maze No.9', 'level': [3, 3, 8]},
#  {'id': 'themessage', 'name': 'The Message', 'level': [3, 6, 9]},
#  {'id': 'sulfur', 'name': 'Sulfur', 'level': [4, 6, 9]},
#  {'id': 'halcyon', 'name': 'Halcyon', 'level': [5, 8, 10]},
#  {'id': 'etherstrike', 'name': 'Ether Strike', 'level': [5, 8, 10]},
#  {'id': 'fractureray', 'name': 'Fracture Ray', 'level': [6, 9, 11]},
#  {'id': 'suomi', 'name': 'Suomi', 'level': [2, 5, 7]},
#  {'id': 'bookmaker', 'name': 'Bookmaker (2D Version)', 'level': [4, 6, 8]},
#  {'id': 'darakunosono', 'name': 'Illegal Paradise', 'level': [2, 7, 9]},
#  {'id': 'dropdead', 'name': 'dropdead', 'level': [1, 9, 8]},
#  {'id': 'fallensquare', 'name': 'Fallensquare', 'level': [3, 7, 9]},
#  {'id': 'nhelv', 'name': 'Nhelv', 'level': [3, 6, 9]},
#  {'id': 'espebranch',
#   'name': 'LunarOrbit -believe in the Espebranch road-',
#   'level': [3, 6, 9]},
#  {'id': 'purgatorium', 'name': 'Purgatorium', 'level': [2, 6, 8]},
#  {'id': 'hikari', 'name': 'Hikari', 'level': [2, 6, 8]},
#  {'id': 'stager', 'name': 'STAGER (ALL STAGE CLEAR)', 'level': [3, 6, 9]},
#  {'id': 'hallofmirrors', 'name': 'Hall of Mirrors', 'level': [3, 5, 8]},
#  {'id': 'linearaccelerator', 'name': 'Linear Accelerator', 'level': [2, 6, 9]},
#  {'id': 'tiferet', 'name': 'Tiferet', 'level': [4, 7, 10]},
#  {'id': 'alexandrite', 'name': 'Alexandrite', 'level': [4, 7, 9]},
#  {'id': 'rugie', 'name': 'Rugie', 'level': [3, 6, 9]},
#  {'id': 'astraltale', 'name': 'Astral tale', 'level': [4, 7, 9]},
#  {'id': 'phantasia', 'name': 'Phantasia', 'level': [4, 5, 9]},
#  {'id': 'empireofwinter', 'name': 'Empire of Winter', 'level': [3, 6, 9]},
#  {'id': 'merlin', 'name': 'MERLIN', 'level': [3, 5, 8]},
#  {'id': 'dxfullmetal',
#   'name': 'DX Choseinou Full Metal Shojo',
#   'level': [3, 6, 9]},
#  {'id': 'omakeno', 'name': 'OMAKENO Stroke', 'level': [3, 6, 9]},
#  {'id': 'scarletlance', 'name': 'Scarlet Lance', 'level': [4, 7, 10]},
#  {'id': 'ouroboros',
#   'name': 'ouroboros -twin stroke of the end-',
#   'level': [4, 7, 10]},
#  {'id': 'libertas', 'name': 'Libertas', 'level': [3, 5, 9]},
#  {'id': 'solitarydream', 'name': 'Solitary Dream', 'level': [4, 7, 8]},
#  {'id': 'antithese', 'name': 'Antithese', 'level': [2, 5, 8]},
#  {'id': 'corruption', 'name': 'Corruption', 'level': [3, 6, 9]},
#  {'id': 'blackterritory', 'name': 'Black Territory', 'level': [3, 7, 9]},
#  {'id': 'viciousheroism', 'name': 'Vicious Heroism', 'level': [4, 7, 9]},
#  {'id': 'cyaegha', 'name': 'Cyaegha', 'level': [5, 8, 10]},
#  {'id': 'revixy', 'name': 'ReviXy', 'level': [3, 6, 8]},
#  {'id': 'grimheart', 'name': 'Grimheart', 'level': [2, 5, 8]}]

# %%
song_rlt=[]
diff = ['PAST', 'PRESENT', 'FUTURE']
clear_mode=['Track Lost', 'Track Complete (Normal Gauge)', 'Full Recall', 'Pure Memory', 'Track Complete (Easy Gauge)', 'Track Complete (Hard Gauge)']
for i in range(len(song_id)*3):
    score = arc.rank_me(song_id[i // 3]['id'], i % 3, 0, 0)['value']
    tmp_dic = {"song_name":song_id[i // 3]['name'], "difficulty": diff[i % 3], "level":song_id[i // 3]['level'][i % 3]}
    if len(score) <= 0:
        song_rlt.append(tmp_dic)
    else:
        tmp_dic['best_clear_type'] = clear_mode[score[0]['best_clear_type']]
        row = ['score', 'shiny_perfect_count', 'perfect_count', 'near_count','miss_count','rank']
        for r in row:
            tmp_dic[r] = score[0][r]
        song_rlt.append(tmp_dic)
# Out:
# {
#     "success": true,
#     "value": [
#         {
#             "user_id": 26652,
#             "song_id": "sayonarahatsukoi",
#             "difficulty": 0,
#             "score": 10000202,
#             "shiny_perfect_count": 202,
#             "perfect_count": 205,
#             "near_count": 0,
#             "miss_count": 0,
#             "health": 100,
#             "modifier": 0,
#             "time_played": 1546313313821,
#             "best_clear_type": 3,
#             "clear_type": 3,
#             "name": "k3id",
#             "character": 7,
#             "is_skill_sealed": false,
#             "is_char_uncapped": false,
#             "rank": 491
#         }
#     ]
# }
# {
#     "success": true,
#     "value": [
#         {
#             "user_id": 26652,
#             "song_id": "sayonarahatsukoi",
#             "difficulty": 1,
#             "score": 10000301,
#             "shiny_perfect_count": 301,
#             "perfect_count": 305,
#             "near_count": 0,
#             "miss_count": 0,
#             "health": 100,
#             "modifier": 0,
#             "time_played": 1549098837800,
#             "best_clear_type": 3,
#             "clear_type": 3,
#             "name": "k3id",
#             "character": 7,
#             "is_skill_sealed": false,
#             "is_char_uncapped": false,
#             "rank": 104
#         }
#     ]
# }
# {
#     "success": true,
#     "value": [
#         {
#             "user_id": 26652,
#             "song_id": "sayonarahatsukoi",
#             "difficulty": 2,
#             "score": 10000629,
#             "shiny_perfect_count": 629,
#             "perfect_count": 666,
#             "near_count": 0,
#             "miss_count": 0,
#             "health": 100,
#             "modifier": 0,
#             "time_played": 1546315216234,
#             "best_clear_type": 3,
#             "clear_type": 3,
#             "name": "k3id",
#             "character": 7,
#             "is_skill_sealed": false,
#             "is_char_uncapped": false,
#             "rank": 7421
#         }
#     ]
# }
# {
#     "success": true,
#     "value": [
#         {
#             "user_id": 26652,
#             "song_id": "lostcivilization",
#             "difficulty": 0,
#             "score": 10000453,
#             "shiny_perfect_count": 453,
#             "perfect_count": 462,
#             "near_count": 0,
#             "miss_count": 0,
#             "health": 100,
#             "modifier": 0,
#             "time_played": 1548946833004,
#             "best_clear_type": 3,
#             "clear_type": 3,
#             "name": "k3id",
#             "character": 7,
#             "is_skill_sealed": false,
#             "is_char_uncapped": false,
#             "rank": 440
#         }
#     ]
# }
# {
#     "success": true,
#     "value": [
#         {
#             "user_id": 26652,
#             "song_id": "lostcivilization",
#             "difficulty": 1,
#             "score": 10000669,
#             "shiny_perfect_count": 669,
#             "perfect_count": 690,
#             "near_count": 0,
#             "miss_count": 0,
#             "health": 100,
#             "modifier": 0,
#             "time_played": 1548826250473,
#             "best_clear_type": 3,
#             "clear_type": 3,
#             "name": "k3id",
#             "character": 7,
#             "is_skill_sealed": false,
#             "is_char_uncapped": false,
#             "rank": 328
#         }
#     ]
# }
# {
#     "success": true,
#     "value": [
#         {
#             "user_id": 26652,
#             "song_id": "lostcivilization",
#             "difficulty": 2,
#             "score": 9950177,
#             "shiny_perfect_count": 887,
#             "perfect_count": 977,
#             "near_count": 8,
#             "miss_count": 1,
#             "health": 100,
#             "modifier": 2,
#             "time_played": 1554557353144,
#             "best_clear_type": 5,
#             "clear_type": 5,
#             "name": "k3id",
#             "character": 7,
#             "is_skill_sealed": false,
#             "is_char_uncapped": false,
#             "rank": 4948
#         }
#     ]
# }
# {
#     "success": true,
#     "value": [
#         {
#             "user_id": 26652,
#             "song_id": "goodtek",
#             "difficulty": 0,
#             "score": 10000440,
#             "shiny_perfect_count": 440,
#             "perfect_count": 449,
#             "near_count": 0,
#             "miss_count": 0,
#             "health": 100,
#             "modifier": 0,
#             "time_played": 1546314329050,
#             "best_clear_type": 3,
#             "clear_type": 3,
#             "name": "k3id",
#             "character": 7,
#             "is_skill_sealed": false,
#             "is_char_uncapped": false,
#             "rank": 632
#         }
#     ]
# }
# {
#     "success": true,
#     "value": [
#         {
#             "user_id": 26652,
#             "song_id": "goodtek",
#             "difficulty": 1,
#             "score": 10000609,
#             "shiny_perfect_count": 609,
#             "perfect_count": 632,
#             "near_count": 0,
#             "miss_count": 0,
#             "health": 100,
#             "modifier": 0,
#             "time_played": 1549016961211,
#             "best_clear_type": 3,
#             "clear_type": 3,
#             "name": "k3id",
#             "character": 7,
#             "is_skill_sealed": false,
#             "is_char_uncapped": false,
#             "rank": 748
#         }
#     ]
# }
# {
#     "success": true,
#     "value": [
#         {
#             "user_id": 26652,
#             "song_id": "goodtek",
#             "difficulty": 2,
#             "score": 9856203,
#             "shiny_perfect_count": 832,
#             "perfect_count": 948,
#             "near_count": 12,
#             "miss_count": 8,
#             "health": 100,
#             "modifier": 0,
#             "time_played": 1550678618920,
#             "best_clear_type": 5,
#             "clear_type": 1,
#             "name": "k3id",
#             "character": 7,
#             "is_skill_sealed": false,
#             "is_char_uncapped": false,
#             "rank": 11409
#         }
#     ]
# }
# {
#     "success": true,
#     "value": [
#         {
#             "user_id": 26652,
#             "song_id": "viyella",
#             "difficulty": 0,
#             "score": 10000408,
#             "shiny_perfect_count": 408,
#             "perfect_count": 414,
#             "near_count": 0,
#             "miss_count": 0,
#             "health": 100,
#             "modifier": 1,
#             "time_played": 1550043927300,
#             "best_clear_type": 3,
#             "clear_type": 3,
#             "name": "k3id",
#             "character": 7,
#             "is_skill_sealed": false,
#             "is_char_uncapped": false,
#             "rank": 77
#         }
#     ]
# }
# {
#     "success": true,
#     "value": [
#         {
#             "user_id": 26652,
#             "song_id": "viyella",
#             "difficulty": 1,
#             "score": 10000465,
#             "shiny_perfect_count": 465,
#             "perfect_count": 492,
#             "near_count": 0,
#             "miss_count": 0,
#             "health": 100,
#             "modifier": 1,
#             "time_played": 1550047819863,
#             "best_clear_type": 3,
#             "clear_type": 3,
#             "name": "k3id",
#             "character": 7,
#             "is_skill_sealed": false,
#             "is_char_uncapped": false,
#             "rank": 340
#         }
#     ]
# }
# {
#     "success": true,
#     "value": [
#         {
#             "user_id": 26652,
#             "song_id": "viyella",
#             "difficulty": 2,
#             "score": 9962758,
#             "shiny_perfect_count": 685,
#             "perfect_count": 785,
#             "near_count": 6,
#             "miss_count": 0,
#             "health": 100,
#             "modifier": 1,
#             "time_played": 1550209434380,
#             "best_clear_type": 2,
#             "clear_type": 2,
#             "name": "k3id",
#             "character": 7,
#             "is_skill_sealed": false,
#             "is_char_uncapped": false,
#             "rank": 3137
#         }
#     ]
# }
# {
#     "success": true,
#     "value": [
#         {
#             "user_id": 26652,
#             "song_id": "rise",
#             "difficulty": 0,
#             "score": 10000321,
#             "shiny_perfect_count": 321,
#             "perfect_count": 322,
#             "near_count": 0,
#             "miss_count": 0,
#             "health": 100,
#             "modifier": 0,
#             "time_played": 1546698492785,
#             "best_clear_type": 3,
#             "clear_type": 3,
#             "name": "k3id",
#             "character": 7,
#             "is_skill_sealed": false,
#             "is_char_uncapped": false,
#             "rank": 63
#         }
#     ]
# }
# {
#     "success": true,
#     "value": [
#         {
#             "user_id": 26652,
#             "song_id": "rise",
#             "difficulty": 1,
#             "score": 10000593,
#             "shiny_perfect_count": 593,
#             "perfect_count": 599,
#             "near_count": 0,
#             "miss_count": 0,
#             "health": 100,
#             "modifier": 0,
#             "time_played": 1549015195504,
#             "best_clear_type": 3,
#             "clear_type": 3,
#             "name": "k3id",
#             "character": 7,
#             "is_skill_sealed": false,
#             "is_char_uncapped": false,
#             "rank": 268
#         }
#     ]
# }
# {
#     "success": true,
#     "value": [
#         {
#             "user_id": 26652,
#             "song_id": "rise",
#             "difficulty": 2,
#             "score": 10000760,
#             "shiny_perfect_count": 760,
#             "perfect_count": 788,
#             "near_count": 0,
#             "miss_count": 0,
#             "health": 100,
#             "modifier": 0,
#             "time_played": 1548825405989,
#             "best_clear_type": 3,
#             "clear_type": 3,
#             "name": "k3id",
#             "character": 7,
#             "is_skill_sealed": false,
#             "is_char_uncapped": false,
#             "rank": 1830
#         }
#     ]
# }
# {
#     "success": true,
#     "value": [
#         {
#             "user_id": 26652,
#             "song_id": "lucifer",
#             "difficulty": 0,
#             "score": 10000420,
#             "shiny_perfect_count": 420,
#             "perfect_count": 424,
#             "near_count": 0,
#             "miss_count": 0,
#             "health": 100,
#             "modifier": 0,
#             "time_played": 1548948166901,
#             "best_clear_type": 3,
#             "clear_type": 3,
#             "name": "k3id",
#             "character": 7,
#             "is_skill_sealed": false,
#             "is_char_uncapped": false,
#             "rank": 189
#         }
#     ]
# }
# {
#     "success": true,
#     "value": [
#         {
#             "user_id": 26652,
#             "song_id": "lucifer",
#             "difficulty": 1,
#             "score": 10000493,
#             "shiny_perfect_count": 493,
#             "perfect_count": 506,
#             "near_count": 0,
#             "miss_count": 0,
#             "health": 100,
#             "modifier": 0,
#             "time_played": 1538909829840,
#             "best_clear_type": 3,
#             "clear_type": 3,
#             "name": "k3id",
#             "character": 7,
#             "is_skill_sealed": false,
#             "is_char_uncapped": false,
#             "rank": 369
#         }
#     ]
# }
# {
#     "success": true,
#     "value": [
#         {
#             "user_id": 26652,
#             "song_id": "lucifer",
#             "difficulty": 2,
#             "score": 9983390,
#             "shiny_perfect_count": 812,
#             "perfect_count": 858,
#             "near_count": 3,
#             "miss_count": 0,
#             "health": 100,
#             "modifier": 0,
#             "time_played": 1557502365950,
#             "best_clear_type": 2,
#             "clear_type": 2,
#             "name": "k3id",
#             "character": 7,
#             "is_skill_sealed": false,
#             "is_char_uncapped": false,
#             "rank": 4376
#         }
#     ]
# }
# {
#     "success": true,
#     "value": [
#         {
#             "user_id": 26652,
#             "song_id": "fairytale",
#             "difficulty": 0,
#             "score": 10000336,
#             "shiny_perfect_count": 336,
#             "perfect_count": 336,
#             "near_count": 0,
#             "miss_count": 0,
#             "health": 100,
#             "modifier": 0,
#             "time_played": 1548988733839,
#             "best_clear_type": 3,
#             "clear_type": 3,
#             "name": "k3id",
#             "character": 7,
#             "is_skill_sealed": false,
#             "is_char_uncapped": false,
#             "rank": 169
#         }
#     ]
# }
# {
#     "success": true,
#     "value": [
#         {
#             "user_id": 26652,
#             "song_id": "fairytale",
#             "difficulty": 1,
#             "score": 10000504,
#             "shiny_perfect_count": 504,
#             "perfect_count": 511,
#             "near_count": 0,
#             "miss_count": 0,
#             "health": 100,
#             "modifier": 1,
#             "time_played": 1550721547128,
#             "best_clear_type": 3,
#             "clear_type": 3,
#             "name": "k3id",
#             "character": 7,
#             "is_skill_sealed": false,
#             "is_char_uncapped": false,
#             "rank": 273
#         }
#     ]
# }
# {
#     "success": true,
#     "value": [
#         {
#             "user_id": 26652,
#             "song_id": "fairytale",
#             "difficulty": 2,
#             "score": 10000753,
#             "shiny_perfect_count": 753,
#             "perfect_count": 782,
#             "near_count": 0,
#             "miss_count": 0,
#             "health": 100,
#             "modifier": 0,
#             "time_played": 1548825027131,
#             "best_clear_type": 3,
#             "clear_type": 3,
#             "name": "k3id",
#             "character": 7,
#             "is_skill_sealed": false,
#             "is_char_uncapped": false,
#             "rank": 2773
#         }
#     ]
# }
# {
#     "success": true,
#     "value": [
#         {
#             "user_id": 26652,
#             "song_id": "hearditsaid",
#             "difficulty": 0,
#             "score": 10000508,
#             "shiny_perfect_count": 508,
#             "perfect_count": 510,
#             "near_count": 0,
#             "miss_count": 0,
#             "health": 100,
#             "modifier": 1,
#             "time_played": 1550044385050,
#             "best_clear_type": 3,
#             "clear_type": 3,
#             "name": "k3id",
#             "character": 7,
#             "is_skill_sealed": false,
#             "is_char_uncapped": false,
#             "rank": 46
#         }
#     ]
# }
# {
#     "success": true,
#     "value": [
#         {
#             "user_id": 26652,
#             "song_id": "hearditsaid",
#             "difficulty": 1,
#             "score": 10000644,
#             "shiny_perfect_count": 644,
#             "perfect_count": 664,
#             "near_count": 0,
#             "miss_count": 0,
#             "health": 100,
#             "modifier": 1,
#             "time_played": 1550064845506,
#             "best_clear_type": 3,
#             "clear_type": 3,
#             "name": "k3id",
#             "character": 7,
#             "is_skill_sealed": false,
#             "is_char_uncapped": false,
#             "rank": 158
#         }
#     ]
# }
# {
#     "success": true,
#     "value": [
#         {
#             "user_id": 26652,
#             "song_id": "hearditsaid",
#             "difficulty": 2,
#             "score": 10000845,
#             "shiny_perfect_count": 845,
#             "perfect_count": 864,
#             "near_count": 0,
#             "miss_count": 0,
#             "health": 100,
#             "modifier": 1,
#             "time_played": 1550149157098,
#             "best_clear_type": 3,
#             "clear_type": 3,
#             "name": "k3id",
#             "character": 7,
#             "is_skill_sealed": false,
#             "is_char_uncapped": false,
#             "rank": 423
#         }
#     ]
# }
# {
#     "success": true,
#     "value": [
#         {
#             "user_id": 26652,
#             "song_id": "babaroque",
#             "difficulty": 0,
#             "score": 10000397,
#             "shiny_perfect_count": 397,
#             "perfect_count": 402,
#             "near_count": 0,
#             "miss_count": 0,
#             "health": 100,
#             "modifier": 0,
#             "time_played": 1548865789714,
#             "best_clear_type": 3,
#             "clear_type": 3,
#             "name": "k3id",
#             "character": 7,
#             "is_skill_sealed": false,
#             "is_char_uncapped": false,
#             "rank": 120
#         }
#     ]
# }
# {
#     "success": true,
#     "value": [
#         {
#             "user_id": 26652,
#             "song_id": "babaroque",
#             "difficulty": 1,
#             "score": 10000615,
#             "shiny_perfect_count": 615,
#             "perfect_count": 645,
#             "near_count": 0,
#             "miss_count": 0,
#             "health": 100,
#             "modifier": 0,
#             "time_played": 1546700480155,
#             "best_clear_type": 3,
#             "clear_type": 3,
#             "name": "k3id",
#             "character": 7,
#             "is_skill_sealed": false,
#             "is_char_uncapped": false,
#             "rank": 373
#         }
#     ]
# }
# {
#     "success": true,
#     "value": [
#         {
#             "user_id": 26652,
#             "song_id": "babaroque",
#             "difficulty": 2,
#             "score": 9945045,
#             "shiny_perfect_count": 739,
#             "perfect_count": 801,
#             "near_count": 5,
#             "miss_count": 2,
#             "health": 100,
#             "modifier": 0,
#             "time_played": 1554474987706,
#             "best_clear_type": 2,
#             "clear_type": 1,
#             "name": "k3id",
#             "character": 7,
#             "is_skill_sealed": false,
#             "is_char_uncapped": false,
#             "rank": 3857
#         }
#     ]
# }
# {
#     "success": true,
#     "value": [
#         {
#             "user_id": 26652,
#             "song_id": "memoryfactory",
#             "difficulty": 0,
#             "score": 10000300,
#             "shiny_perfect_count": 300,
#             "perfect_count": 308,
#             "near_count": 0,
#             "miss_count": 0,
#             "health": 100,
#             "modifier": 1,
#             "time_played": 1550045738519,
#             "best_clear_type": 3,
#             "clear_type": 3,
#             "name": "k3id",
#             "character": 7,
#             "is_skill_sealed": false,
#             "is_char_uncapped": false,
#             "rank": 202
#         }
#     ]
# }
# {
#     "success": true,
#     "value": [
#         {
#             "user_id": 26652,
#             "song_id": "memoryfactory",
#             "difficulty": 1,
#             "score": 10000416,
#             "shiny_perfect_count": 416,
#             "perfect_count": 448,
#             "near_count": 0,
#             "miss_count": 0,
#             "health": 100,
#             "modifier": 1,
#             "time_played": 1550046370192,
#             "best_clear_type": 3,
#             "clear_type": 3,
#             "name": "k3id",
#             "character": 7,
#             "is_skill_sealed": false,
#             "is_char_uncapped": false,
#             "rank": 440
#         }
#     ]
# }
# {
#     "success": true,
#     "value": [
#         {
#             "user_id": 26652,
#             "song_id": "memoryfactory",
#             "difficulty": 2,
#             "score": 9926166,
#             "shiny_perfect_count": 571,
#             "perfect_count": 662,
#             "near_count": 10,
#             "miss_count": 0,
#             "health": 100,
#             "modifier": 1,
#             "time_played": 1553307651365,
#             "best_clear_type": 2,
#             "clear_type": 2,
#             "name": "k3id",
#             "character": 7,
#             "is_skill_sealed": false,
#             "is_char_uncapped": false,
#             "rank": 3243
#         }
#     ]
# }
# {
#     "success": true,
#     "value": [
#         {
#             "user_id": 26652,
#             "song_id": "snowwhite",
#             "difficulty": 0,
#             "score": 10000478,
#             "shiny_perfect_count": 478,
#             "perfect_count": 486,
#             "near_count": 0,
#             "miss_count": 0,
#             "health": 100,
#             "modifier": 0,
#             "time_played": 1546699000281,
#             "best_clear_type": 3,
#             "clear_type": 3,
#             "name": "k3id",
#             "character": 7,
#             "is_skill_sealed": false,
#             "is_char_uncapped": false,
#             "rank": 649
#         }
#     ]
# }
# {
#     "success": true,
#     "value": [
#         {
#             "user_id": 26652,
#             "song_id": "snowwhite",
#             "difficulty": 1,
#             "score": 10000645,
#             "shiny_perfect_count": 645,
#             "perfect_count": 672,
#             "near_count": 0,
#             "miss_count": 0,
#             "health": 100,
#             "modifier": 0,
#             "time_played": 1539496291884,
#             "best_clear_type": 3,
#             "clear_type": 3,
#             "name": "k3id",
#             "character": 7,
#             "is_skill_sealed": false,
#             "is_char_uncapped": false,
#             "rank": 1225
#         }
#     ]
# }
# {
#     "success": true,
#     "value": [
#         {
#             "user_id": 26652,
#             "song_id": "snowwhite",
#             "difficulty": 2,
#             "score": 9975324,
#             "shiny_perfect_count": 887,
#             "perfect_count": 973,
#             "near_count": 5,
#             "miss_count": 0,
#             "health": 100,
#             "modifier": 0,
#             "time_played": 1548765731361,
#             "best_clear_type": 2,
#             "clear_type": 2,
#             "name": "k3id",
#             "character": 7,
#             "is_skill_sealed": false,
#             "is_char_uncapped": false,
#             "rank": 3255
#         }
#     ]
# }
# {
#     "success": true,
#     "value": [
#         {
#             "user_id": 26652,
#             "song_id": "relentless",
#             "difficulty": 0,
#             "score": 10000602,
#             "shiny_perfect_count": 602,
#             "perfect_count": 607,
#             "near_count": 0,
#             "miss_count": 0,
#             "health": 100,
#             "modifier": 1,
#             "time_played": 1550045495720,
#             "best_clear_type": 3,
#             "clear_type": 3,
#             "name": "k3id",
#             "character": 7,
#             "is_skill_sealed": false,
#             "is_char_uncapped": false,
#             "rank": 408
#         }
#     ]
# }
# {
#     "success": true,
#     "value": [
#         {
#             "user_id": 26652,
#             "song_id": "relentless",
#             "difficulty": 1,
#             "score": 10000715,
#             "shiny_perfect_count": 715,
#             "perfect_count": 722,
#             "near_count": 0,
#             "miss_count": 0,
#             "health": 100,
#             "modifier": 1,
#             "time_played": 1550065293768,
#             "best_clear_type": 3,
#             "clear_type": 3,
#             "name": "k3id",
#             "character": 7,
#             "is_skill_sealed": false,
#             "is_char_uncapped": false,
#             "rank": 694
#         }
#     ]
# }
# {
#     "success": true,
#     "value": [
#         {
#             "user_id": 26652,
#             "song_id": "relentless",
#             "difficulty": 2,
#             "score": 10000985,
#             "shiny_perfect_count": 985,
#             "perfect_count": 1015,
#             "near_count": 0,
#             "miss_count": 0,
#             "health": 100,
#             "modifier": 2,
#             "time_played": 1550211798470,
#             "best_clear_type": 3,
#             "clear_type": 3,
#             "name": "k3id",
#             "character": 7,
#             "is_skill_sealed": false,
#             "is_char_uncapped": false,
#             "rank": 862
#         }
#     ]
# }
# {
#     "success": true,
#     "value": [
#         {
#             "user_id": 26652,
#             "song_id": "shadesoflight",
#             "difficulty": 0,
#             "score": 10000511,
#             "shiny_perfect_count": 511,
#             "perfect_count": 517,
#             "near_count": 0,
#             "miss_count": 0,
#             "health": 100,
#             "modifier": 0,
#             "time_played": 1548985654199,
#             "best_clear_type": 3,
#             "clear_type": 3,
#             "name": "k3id",
#             "character": 7,
#             "is_skill_sealed": false,
#             "is_char_uncapped": false,
#             "rank": 487
#         }
#     ]
# }
# {
#     "success": true,
#     "value": [
#         {
#             "user_id": 26652,
#             "song_id": "shadesoflight",
#             "difficulty": 1,
#             "score": 10000780,
#             "shiny_perfect_count": 780,
#             "perfect_count": 789,
#             "near_count": 0,
#             "miss_count": 0,
#             "health": 100,
#             "modifier": 0,
#             "time_played": 1549018140450,
#             "best_clear_type": 3,
#             "clear_type": 3,
#             "name": "k3id",
#             "character": 7,
#             "is_skill_sealed": false,
#             "is_char_uncapped": false,
#             "rank": 285
#         }
#     ]
# }
# {
#     "success": true,
#     "value": [
#         {
#             "user_id": 26652,
#             "song_id": "shadesoflight",
#             "difficulty": 2,
#             "score": 10001038,
#             "shiny_perfect_count": 1038,
#             "perfect_count": 1067,
#             "near_count": 0,
#             "miss_count": 0,
#             "health": 100,
#             "modifier": 0,
#             "time_played": 1557499421303,
#             "best_clear_type": 3,
#             "clear_type": 3,
#             "name": "k3id",
#             "character": 7,
#             "is_skill_sealed": false,
#             "is_char_uncapped": false,
#             "rank": 1490
#         }
#     ]
# }
# {
#     "success": true,
#     "value": [
#         {
#             "user_id": 26652,
#             "song_id": "vexaria",
#             "difficulty": 0,
#             "score": 10000367,
#             "shiny_perfect_count": 367,
#             "perfect_count": 369,
#             "near_count": 0,
#             "miss_count": 0,
#             "health": 100,
#             "modifier": 0,
#             "time_played": 1546699231222,
#             "best_clear_type": 3,
#             "clear_type": 3,
#             "name": "k3id",
#             "character": 7,
#             "is_skill_sealed": false,
#             "is_char_uncapped": false,
#             "rank": 71
#         }
#     ]
# }
# {
#     "success": true,
#     "value": [
#         {
#             "user_id": 26652,
#             "song_id": "vexaria",
#             "difficulty": 1,
#             "score": 10000510,
#             "shiny_perfect_count": 510,
#             "perfect_count": 534,
#             "near_count": 0,
#             "miss_count": 0,
#             "health": 100,
#             "modifier": 0,
#             "time_played": 1539496456835,
#             "best_clear_type": 3,
#             "clear_type": 3,
#             "name": "k3id",
#             "character": 7,
#             "is_skill_sealed": false,
#             "is_char_uncapped": false,
#             "rank": 1203
#         }
#     ]
# }
# {
#     "success": true,
#     "value": [
#         {
#             "user_id": 26652,
#             "song_id": "vexaria",
#             "difficulty": 2,
#             "score": 10000690,
#             "shiny_perfect_count": 690,
#             "perfect_count": 734,
#             "near_count": 0,
#             "miss_count": 0,
#             "health": 100,
#             "modifier": 0,
#             "time_played": 1546317909654,
#             "best_clear_type": 3,
#             "clear_type": 3,
#             "name": "k3id",
#             "character": 7,
#             "is_skill_sealed": false,
#             "is_char_uncapped": false,
#             "rank": 4502
#         }
#     ]
# }
# {
#     "success": true,
#     "value": [
#         {
#             "user_id": 26652,
#             "song_id": "essenceoftwilight",
#             "difficulty": 0,
#             "score": 10000551,
#             "shiny_perfect_count": 551,
#             "perfect_count": 556,
#             "near_count": 0,
#             "miss_count": 0,
#             "health": 100,
#             "modifier": 2,
#             "time_played": 1550212802089,
#             "best_clear_type": 3,
#             "clear_type": 3,
#             "name": "k3id",
#             "character": 7,
#             "is_skill_sealed": false,
#             "is_char_uncapped": false,
#             "rank": 141
#         }
#     ]
# }
# {
#     "success": true,
#     "value": [
#         {
#             "user_id": 26652,
#             "song_id": "essenceoftwilight",
#             "difficulty": 1,
#             "score": 10000753,
#             "shiny_perfect_count": 753,
#             "perfect_count": 767,
#             "near_count": 0,
#             "miss_count": 0,
#             "health": 100,
#             "modifier": 2,
#             "time_played": 1550212987175,
#             "best_clear_type": 3,
#             "clear_type": 3,
#             "name": "k3id",
#             "character": 7,
#             "is_skill_sealed": false,
#             "is_char_uncapped": false,
#             "rank": 164
#         }
#     ]
# }
# {
#     "success": true,
#     "value": [
#         {
#             "user_id": 26652,
#             "song_id": "essenceoftwilight",
#             "difficulty": 2,
#             "score": 9976200,
#             "shiny_perfect_count": 1117,
#             "perfect_count": 1199,
#             "near_count": 4,
#             "miss_count": 1,
#             "health": 100,
#             "modifier": 1,
#             "time_played": 1550213965548,
#             "best_clear_type": 2,
#             "clear_type": 4,
#             "name": "k3id",
#             "character": 7,
#             "is_skill_sealed": false,
#             "is_char_uncapped": false,
#             "rank": 3283
#         }
#     ]
# }
# {
#     "success": true,
#     "value": [
#         {
#             "user_id": 26652,
#             "song_id": "qualia",
#             "difficulty": 0,
#             "score": 10000540,
#             "shiny_perfect_count": 540,
#             "perfect_count": 550,
#             "near_count": 0,
#             "miss_count": 0,
#             "health": 100,
#             "modifier": 0,
#             "time_played": 1548866092634,
#             "best_clear_type": 3,
#             "clear_type": 3,
#             "name": "k3id",
#             "character": 7,
#             "is_skill_sealed": false,
#             "is_char_uncapped": false,
#             "rank": 197
#         }
#     ]
# }
# {
#     "success": true,
#     "value": [
#         {
#             "user_id": 26652,
#             "song_id": "qualia",
#             "difficulty": 1,
#             "score": 10000871,
#             "shiny_perfect_count": 871,
#             "perfect_count": 875,
#             "near_count": 0,
#             "miss_count": 0,
#             "health": 100,
#             "modifier": 0,
#             "time_played": 1549101013330,
#             "best_clear_type": 3,
#             "clear_type": 3,
#             "name": "k3id",
#             "character": 7,
#             "is_skill_sealed": false,
#             "is_char_uncapped": false,
#             "rank": 934
#         }
#     ]
# }
# {
#     "success": true,
#     "value": [
#         {
#             "user_id": 26652,
#             "song_id": "qualia",
#             "difficulty": 2,
#             "score": 9947132,
#             "shiny_perfect_count": 949,
#             "perfect_count": 1014,
#             "near_count": 5,
#             "miss_count": 3,
#             "health": 100,
#             "modifier": 2,
#             "time_played": 1549628434359,
#             "best_clear_type": 5,
#             "clear_type": 5,
#             "name": "k3id",
#             "character": 7,
#             "is_skill_sealed": false,
#             "is_char_uncapped": false,
#             "rank": 3709
#         }
#     ]
# }
# {
#     "success": true,
#     "value": [
#         {
#             "user_id": 26652,
#             "song_id": "pragmatism",
#             "difficulty": 0,
#             "score": 10000467,
#             "shiny_perfect_count": 467,
#             "perfect_count": 476,
#             "near_count": 0,
#             "miss_count": 0,
#             "health": 100,
#             "modifier": 2,
#             "time_played": 1550240830906,
#             "best_clear_type": 3,
#             "clear_type": 3,
#             "name": "k3id",
#             "character": 7,
#             "is_skill_sealed": false,
#             "is_char_uncapped": false,
#             "rank": 239
#         }
#     ]
# }
# {
#     "success": true,
#     "value": [
#         {
#             "user_id": 26652,
#             "song_id": "pragmatism",
#             "difficulty": 1,
#             "score": 9983277,
#             "shiny_perfect_count": 821,
#             "perfect_count": 852,
#             "near_count": 3,
#             "miss_count": 0,
#             "health": 100,
#             "modifier": 2,
#             "time_played": 1550297494584,
#             "best_clear_type": 2,
#             "clear_type": 2,
#             "name": "k3id",
#             "character": 7,
#             "is_skill_sealed": false,
#             "is_char_uncapped": false,
#             "rank": 985
#         }
#     ]
# }
# {
#     "success": true,
#     "value": [
#         {
#             "user_id": 26652,
#             "song_id": "pragmatism",
#             "difficulty": 2,
#             "score": 9331914,
#             "shiny_perfect_count": 704,
#             "perfect_count": 858,
#             "near_count": 42,
#             "miss_count": 42,
#             "health": 75,
#             "modifier": 0,
#             "time_played": 1555844689751,
#             "best_clear_type": 1,
#             "clear_type": 1,
#             "name": "k3id",
#             "character": 7,
#             "is_skill_sealed": false,
#             "is_char_uncapped": false,
#             "rank": 12735
#         }
#     ]
# }
# {
#     "success": true,
#     "value": [
#         {
#             "user_id": 26652,
#             "song_id": "sheriruth",
#             "difficulty": 0,
#             "score": 10000606,
#             "shiny_perfect_count": 606,
#             "perfect_count": 611,
#             "near_count": 0,
#             "miss_count": 0,
#             "health": 100,
#             "modifier": 2,
#             "time_played": 1550296976141,
#             "best_clear_type": 3,
#             "clear_type": 3,
#             "name": "k3id",
#             "character": 7,
#             "is_skill_sealed": false,
#             "is_char_uncapped": false,
#             "rank": 53
#         }
#     ]
# }
# {
#     "success": true,
#     "value": [
#         {
#             "user_id": 26652,
#             "song_id": "sheriruth",
#             "difficulty": 1,
#             "score": 10000802,
#             "shiny_perfect_count": 802,
#             "perfect_count": 832,
#             "near_count": 0,
#             "miss_count": 0,
#             "health": 100,
#             "modifier": 1,
#             "time_played": 1550298666189,
#             "best_clear_type": 3,
#             "clear_type": 3,
#             "name": "k3id",
#             "character": 7,
#             "is_skill_sealed": false,
#             "is_char_uncapped": false,
#             "rank": 295
#         }
#     ]
# }
# {
#     "success": true,
#     "value": [
#         {
#             "user_id": 26652,
#             "song_id": "sheriruth",
#             "difficulty": 2,
#             "score": 9696806,
#             "shiny_perfect_count": 890,
#             "perfect_count": 1096,
#             "near_count": 40,
#             "miss_count": 15,
#             "health": 100,
#             "modifier": 0,
#             "time_played": 1556376140428,
#             "best_clear_type": 5,
#             "clear_type": 1,
#             "name": "k3id",
#             "character": 7,
#             "is_skill_sealed": false,
#             "is_char_uncapped": false,
#             "rank": 8465
#         }
#     ]
# }
# {
#     "success": true,
#     "value": [
#         {
#             "user_id": 26652,
#             "song_id": "lumia",
#             "difficulty": 0,
#             "score": 10000465,
#             "shiny_perfect_count": 465,
#             "perfect_count": 469,
#             "near_count": 0,
#             "miss_count": 0,
#             "health": 100,
#             "modifier": 1,
#             "time_played": 1550044697000,
#             "best_clear_type": 3,
#             "clear_type": 3,
#             "name": "k3id",
#             "character": 7,
#             "is_skill_sealed": false,
#             "is_char_uncapped": false,
#             "rank": 95
#         }
#     ]
# }
# {
#     "success": true,
#     "value": [
#         {
#             "user_id": 26652,
#             "song_id": "lumia",
#             "difficulty": 1,
#             "score": 10000422,
#             "shiny_perfect_count": 422,
#             "perfect_count": 438,
#             "near_count": 0,
#             "miss_count": 0,
#             "health": 100,
#             "modifier": 1,
#             "time_played": 1550065115924,
#             "best_clear_type": 3,
#             "clear_type": 3,
#             "name": "k3id",
#             "character": 7,
#             "is_skill_sealed": false,
#             "is_char_uncapped": false,
#             "rank": 106
#         }
#     ]
# }
# {
#     "success": true,
#     "value": [
#         {
#             "user_id": 26652,
#             "song_id": "lumia",
#             "difficulty": 2,
#             "score": 10000906,
#             "shiny_perfect_count": 906,
#             "perfect_count": 961,
#             "near_count": 0,
#             "miss_count": 0,
#             "health": 100,
#             "modifier": 1,
#             "time_played": 1550203724616,
#             "best_clear_type": 3,
#             "clear_type": 3,
#             "name": "k3id",
#             "character": 7,
#             "is_skill_sealed": false,
#             "is_char_uncapped": false,
#             "rank": 2320
#         }
#     ]
# }
# {
#     "success": true,
#     "value": [
#         {
#             "user_id": 26652,
#             "song_id": "dement",
#             "difficulty": 0,
#             "score": 10000541,
#             "shiny_perfect_count": 541,
#             "perfect_count": 548,
#             "near_count": 0,
#             "miss_count": 0,
#             "health": 100,
#             "modifier": 0,
#             "time_played": 1548947587991,
#             "best_clear_type": 3,
#             "clear_type": 3,
#             "name": "k3id",
#             "character": 7,
#             "is_skill_sealed": false,
#             "is_char_uncapped": false,
#             "rank": 171
#         }
#     ]
# }
# {
#     "success": true,
#     "value": [
#         {
#             "user_id": 26652,
#             "song_id": "dement",
#             "difficulty": 1,
#             "score": 10000723,
#             "shiny_perfect_count": 723,
#             "perfect_count": 756,
#             "near_count": 0,
#             "miss_count": 0,
#             "health": 100,
#             "modifier": 0,
#             "time_played": 1526970729522,
#             "best_clear_type": 3,
#             "clear_type": 3,
#             "name": "k3id",
#             "character": 7,
#             "is_skill_sealed": false,
#             "is_char_uncapped": false,
#             "rank": 1749
#         }
#     ]
# }
# {
#     "success": true,
#     "value": [
#         {
#             "user_id": 26652,
#             "song_id": "dement",
#             "difficulty": 2,
#             "score": 10000940,
#             "shiny_perfect_count": 940,
#             "perfect_count": 970,
#             "near_count": 0,
#             "miss_count": 0,
#             "health": 100,
#             "modifier": 1,
#             "time_played": 1549109955441,
#             "best_clear_type": 3,
#             "clear_type": 3,
#             "name": "k3id",
#             "character": 7,
#             "is_skill_sealed": false,
#             "is_char_uncapped": false,
#             "rank": 2449
#         }
#     ]
# }
# {
#     "success": true,
#     "value": [
#         {
#             "user_id": 26652,
#             "song_id": "dandelion",
#             "difficulty": 0,
#             "score": 10000382,
#             "shiny_perfect_count": 382,
#             "perfect_count": 391,
#             "near_count": 0,
#             "miss_count": 0,
#             "health": 100,
#             "modifier": 0,
#             "time_played": 1548987215596,
#             "best_clear_type": 3,
#             "clear_type": 3,
#             "name": "k3id",
#             "character": 7,
#             "is_skill_sealed": false,
#             "is_char_uncapped": false,
#             "rank": 340
#         }
#     ]
# }
# {
#     "success": true,
#     "value": [
#         {
#             "user_id": 26652,
#             "song_id": "dandelion",
#             "difficulty": 1,
#             "score": 10000676,
#             "shiny_perfect_count": 676,
#             "perfect_count": 698,
#             "near_count": 0,
#             "miss_count": 0,
#             "health": 100,
#             "modifier": 0,
#             "time_played": 1549097537494,
#             "best_clear_type": 3,
#             "clear_type": 3,
#             "name": "k3id",
#             "character": 7,
#             "is_skill_sealed": false,
#             "is_char_uncapped": false,
#             "rank": 337
#         }
#     ]
# }
# {
#     "success": true,
#     "value": [
#         {
#             "user_id": 26652,
#             "song_id": "dandelion",
#             "difficulty": 2,
#             "score": 9968271,
#             "shiny_perfect_count": 845,
#             "perfect_count": 915,
#             "near_count": 6,
#             "miss_count": 0,
#             "health": 100,
#             "modifier": 0,
#             "time_played": 1557502770686,
#             "best_clear_type": 2,
#             "clear_type": 2,
#             "name": "k3id",
#             "character": 7,
#             "is_skill_sealed": false,
#             "is_char_uncapped": false,
#             "rank": 3138
#         }
#     ]
# }
# {
#     "success": true,
#     "value": [
#         {
#             "user_id": 26652,
#             "song_id": "anokumene",
#             "difficulty": 0,
#             "score": 10000410,
#             "shiny_perfect_count": 410,
#             "perfect_count": 412,
#             "near_count": 0,
#             "miss_count": 0,
#             "health": 100,
#             "modifier": 0,
#             "time_played": 1546612427767,
#             "best_clear_type": 3,
#             "clear_type": 3,
#             "name": "k3id",
#             "character": 7,
#             "is_skill_sealed": false,
#             "is_char_uncapped": false,
#             "rank": 208
#         }
#     ]
# }
# {
#     "success": true,
#     "value": [
#         {
#             "user_id": 26652,
#             "song_id": "anokumene",
#             "difficulty": 1,
#             "score": 10000564,
#             "shiny_perfect_count": 564,
#             "perfect_count": 588,
#             "near_count": 0,
#             "miss_count": 0,
#             "health": 100,
#             "modifier": 0,
#             "time_played": 1539497026975,
#             "best_clear_type": 3,
#             "clear_type": 3,
#             "name": "k3id",
#             "character": 7,
#             "is_skill_sealed": false,
#             "is_char_uncapped": false,
#             "rank": 513
#         }
#     ]
# }
# {
#     "success": true,
#     "value": [
#         {
#             "user_id": 26652,
#             "song_id": "anokumene",
#             "difficulty": 2,
#             "score": 9924344,
#             "shiny_perfect_count": 725,
#             "perfect_count": 840,
#             "near_count": 9,
#             "miss_count": 2,
#             "health": 100,
#             "modifier": 0,
#             "time_played": 1557580515464,
#             "best_clear_type": 5,
#             "clear_type": 1,
#             "name": "k3id",
#             "character": 7,
#             "is_skill_sealed": false,
#             "is_char_uncapped": false,
#             "rank": 6955
#         }
#     ]
# }
# {
#     "success": true,
#     "value": [
#         {
#             "user_id": 26652,
#             "song_id": "infinityheaven",
#             "difficulty": 0,
#             "score": 10000334,
#             "shiny_perfect_count": 334,
#             "perfect_count": 336,
#             "near_count": 0,
#             "miss_count": 0,
#             "health": 100,
#             "modifier": 0,
#             "time_played": 1546313621194,
#             "best_clear_type": 3,
#             "clear_type": 3,
#             "name": "k3id",
#             "character": 7,
#             "is_skill_sealed": false,
#             "is_char_uncapped": false,
#             "rank": 652
#         }
#     ]
# }
# {
#     "success": true,
#     "value": [
#         {
#             "user_id": 26652,
#             "song_id": "infinityheaven",
#             "difficulty": 1,
#             "score": 10000530,
#             "shiny_perfect_count": 530,
#             "perfect_count": 545,
#             "near_count": 0,
#             "miss_count": 0,
#             "health": 100,
#             "modifier": 1,
#             "time_played": 1550721748205,
#             "best_clear_type": 3,
#             "clear_type": 3,
#             "name": "k3id",
#             "character": 7,
#             "is_skill_sealed": false,
#             "is_char_uncapped": false,
#             "rank": 256
#         }
#     ]
# }
# {
#     "success": true,
#     "value": [
#         {
#             "user_id": 26652,
#             "song_id": "infinityheaven",
#             "difficulty": 2,
#             "score": 10000806,
#             "shiny_perfect_count": 806,
#             "perfect_count": 853,
#             "near_count": 0,
#             "miss_count": 0,
#             "health": 100,
#             "modifier": 0,
#             "time_played": 1546316961015,
#             "best_clear_type": 3,
#             "clear_type": 3,
#             "name": "k3id",
#             "character": 7,
#             "is_skill_sealed": false,
#             "is_char_uncapped": false,
#             "rank": 4471
#         }
#     ]
# }
# {
#     "success": true,
#     "value": []
# }
# {
#     "success": true,
#     "value": []
# }
# {
#     "success": true,
#     "value": []
# }
# {
#     "success": true,
#     "value": []
# }
# {
#     "success": true,
#     "value": []
# }
# {
#     "success": true,
#     "value": []
# }
# {
#     "success": true,
#     "value": []
# }
# {
#     "success": true,
#     "value": []
# }
# {
#     "success": true,
#     "value": []
# }
# {
#     "success": true,
#     "value": []
# }
# {
#     "success": true,
#     "value": []
# }
# {
#     "success": true,
#     "value": []
# }
# {
#     "success": true,
#     "value": []
# }
# {
#     "success": true,
#     "value": []
# }
# {
#     "success": true,
#     "value": []
# }
# {
#     "success": true,
#     "value": [
#         {
#             "user_id": 26652,
#             "song_id": "brandnewworld",
#             "difficulty": 0,
#             "score": 10000321,
#             "shiny_perfect_count": 321,
#             "perfect_count": 322,
#             "near_count": 0,
#             "miss_count": 0,
#             "health": 100,
#             "modifier": 0,
#             "time_played": 1548990161945,
#             "best_clear_type": 3,
#             "clear_type": 3,
#             "name": "k3id",
#             "character": 7,
#             "is_skill_sealed": false,
#             "is_char_uncapped": false,
#             "rank": 153
#         }
#     ]
# }
# {
#     "success": true,
#     "value": [
#         {
#             "user_id": 26652,
#             "song_id": "brandnewworld",
#             "difficulty": 1,
#             "score": 10000425,
#             "shiny_perfect_count": 425,
#             "perfect_count": 432,
#             "near_count": 0,
#             "miss_count": 0,
#             "health": 100,
#             "modifier": 0,
#             "time_played": 1549014650783,
#             "best_clear_type": 3,
#             "clear_type": 3,
#             "name": "k3id",
#             "character": 7,
#             "is_skill_sealed": false,
#             "is_char_uncapped": false,
#             "rank": 253
#         }
#     ]
# }
# {
#     "success": true,
#     "value": [
#         {
#             "user_id": 26652,
#             "song_id": "brandnewworld",
#             "difficulty": 2,
#             "score": 10000733,
#             "shiny_perfect_count": 733,
#             "perfect_count": 787,
#             "near_count": 0,
#             "miss_count": 0,
#             "health": 100,
#             "modifier": 0,
#             "time_played": 1546315598092,
#             "best_clear_type": 3,
#             "clear_type": 3,
#             "name": "k3id",
#             "character": 7,
#             "is_skill_sealed": false,
#             "is_char_uncapped": false,
#             "rank": 4379
#         }
#     ]
# }
# {
#     "success": true,
#     "value": [
#         {
#             "user_id": 26652,
#             "song_id": "dataerror",
#             "difficulty": 0,
#             "score": 10000498,
#             "shiny_perfect_count": 498,
#             "perfect_count": 502,
#             "near_count": 0,
#             "miss_count": 0,
#             "health": 100,
#             "modifier": 0,
#             "time_played": 1552810024433,
#             "best_clear_type": 3,
#             "clear_type": 3,
#             "name": "k3id",
#             "character": 7,
#             "is_skill_sealed": false,
#             "is_char_uncapped": false,
#             "rank": 331
#         }
#     ]
# }
# {
#     "success": true,
#     "value": [
#         {
#             "user_id": 26652,
#             "song_id": "dataerror",
#             "difficulty": 1,
#             "score": 10000771,
#             "shiny_perfect_count": 771,
#             "perfect_count": 785,
#             "near_count": 0,
#             "miss_count": 0,
#             "health": 100,
#             "modifier": 0,
#             "time_played": 1552810209022,
#             "best_clear_type": 3,
#             "clear_type": 3,
#             "name": "k3id",
#             "character": 7,
#             "is_skill_sealed": false,
# ...
#             "modifier": 1,
#             "time_played": 1551277468024,
#             "best_clear_type": 5,
#             "clear_type": 4,
#             "name": "k3id",
#             "character": 7,
#             "is_skill_sealed": false,
#             "is_char_uncapped": false,
#             "rank": 4742
#         }
#     ]
# }
# {
#     "success": true,
#     "value": [
#         {
#             "user_id": 26652,
#             "song_id": "purgatorium",
#             "difficulty": 0,
#             "score": 10000605,
#             "shiny_perfect_count": 605,
#             "perfect_count": 609,
#             "near_count": 0,
#             "miss_count": 0,
#             "health": 100,
#             "modifier": 0,
#             "time_played": 1548986933316,
#             "best_clear_type": 3,
#             "clear_type": 3,
#             "name": "k3id",
#             "character": 7,
#             "is_skill_sealed": false,
#             "is_char_uncapped": false,
#             "rank": 409
#         }
#     ]
# }
# {
#     "success": true,
#     "value": [
#         {
#             "user_id": 26652,
#             "song_id": "purgatorium",
#             "difficulty": 1,
#             "score": 10000621,
#             "shiny_perfect_count": 621,
#             "perfect_count": 641,
#             "near_count": 0,
#             "miss_count": 0,
#             "health": 100,
#             "modifier": 0,
#             "time_played": 1538908996866,
#             "best_clear_type": 3,
#             "clear_type": 3,
#             "name": "k3id",
#             "character": 7,
#             "is_skill_sealed": false,
#             "is_char_uncapped": false,
#             "rank": 460
#         }
#     ]
# }
# {
#     "success": true,
#     "value": [
#         {
#             "user_id": 26652,
#             "song_id": "purgatorium",
#             "difficulty": 2,
#             "score": 9975493,
#             "shiny_perfect_count": 926,
#             "perfect_count": 978,
#             "near_count": 5,
#             "miss_count": 0,
#             "health": 100,
#             "modifier": 0,
#             "time_played": 1557501997855,
#             "best_clear_type": 2,
#             "clear_type": 2,
#             "name": "k3id",
#             "character": 7,
#             "is_skill_sealed": false,
#             "is_char_uncapped": false,
#             "rank": 5377
#         }
#     ]
# }
# {
#     "success": true,
#     "value": []
# }
# {
#     "success": true,
#     "value": []
# }
# {
#     "success": true,
#     "value": []
# }
# {
#     "success": true,
#     "value": []
# }
# {
#     "success": true,
#     "value": []
# }
# {
#     "success": true,
#     "value": []
# }
# {
#     "success": true,
#     "value": []
# }
# {
#     "success": true,
#     "value": []
# }
# {
#     "success": true,
#     "value": []
# }
# {
#     "success": true,
#     "value": []
# }
# {
#     "success": true,
#     "value": []
# }
# {
#     "success": true,
#     "value": []
# }
# {
#     "success": true,
#     "value": []
# }
# {
#     "success": true,
#     "value": []
# }
# {
#     "success": true,
#     "value": []
# }
# {
#     "success": true,
#     "value": [
#         {
#             "user_id": 26652,
#             "song_id": "alexandrite",
#             "difficulty": 0,
#             "score": 10000498,
#             "shiny_perfect_count": 498,
#             "perfect_count": 507,
#             "near_count": 0,
#             "miss_count": 0,
#             "health": 100,
#             "modifier": 0,
#             "time_played": 1548991603144,
#             "best_clear_type": 3,
#             "clear_type": 3,
#             "name": "k3id",
#             "character": 7,
#             "is_skill_sealed": false,
#             "is_char_uncapped": false,
#             "rank": 190
#         }
#     ]
# }
# {
#     "success": true,
#     "value": [
#         {
#             "user_id": 26652,
#             "song_id": "alexandrite",
#             "difficulty": 1,
#             "score": 10000666,
#             "shiny_perfect_count": 666,
#             "perfect_count": 699,
#             "near_count": 0,
#             "miss_count": 0,
#             "health": 100,
#             "modifier": 0,
#             "time_played": 1549098201664,
#             "best_clear_type": 3,
#             "clear_type": 3,
#             "name": "k3id",
#             "character": 7,
#             "is_skill_sealed": false,
#             "is_char_uncapped": false,
#             "rank": 250
#         }
#     ]
# }
# {
#     "success": true,
#     "value": [
#         {
#             "user_id": 26652,
#             "song_id": "alexandrite",
#             "difficulty": 2,
#             "score": 9635435,
#             "shiny_perfect_count": 820,
#             "perfect_count": 982,
#             "near_count": 40,
#             "miss_count": 18,
#             "health": 100,
#             "modifier": 0,
#             "time_played": 1557494362780,
#             "best_clear_type": 5,
#             "clear_type": 1,
#             "name": "k3id",
#             "character": 7,
#             "is_skill_sealed": false,
#             "is_char_uncapped": false,
#             "rank": 6889
#         }
#     ]
# }
# {
#     "success": true,
#     "value": [
#         {
#             "user_id": 26652,
#             "song_id": "rugie",
#             "difficulty": 0,
#             "score": 10000561,
#             "shiny_perfect_count": 561,
#             "perfect_count": 566,
#             "near_count": 0,
#             "miss_count": 0,
#             "health": 100,
#             "modifier": 0,
#             "time_played": 1546219401103,
#             "best_clear_type": 3,
#             "clear_type": 3,
#             "name": "k3id",
#             "character": 7,
#             "is_skill_sealed": false,
#             "is_char_uncapped": false,
#             "rank": 413
#         }
#     ]
# }
# {
#     "success": true,
#     "value": [
#         {
#             "user_id": 26652,
#             "song_id": "rugie",
#             "difficulty": 1,
#             "score": 10000739,
#             "shiny_perfect_count": 739,
#             "perfect_count": 754,
#             "near_count": 0,
#             "miss_count": 0,
#             "health": 100,
#             "modifier": 0,
#             "time_played": 1549019563708,
#             "best_clear_type": 3,
#             "clear_type": 3,
#             "name": "k3id",
#             "character": 7,
#             "is_skill_sealed": false,
#             "is_char_uncapped": false,
#             "rank": 224
#         }
#     ]
# }
# {
#     "success": true,
#     "value": [
#         {
#             "user_id": 26652,
#             "song_id": "rugie",
#             "difficulty": 2,
#             "score": 9923987,
#             "shiny_perfect_count": 911,
#             "perfect_count": 964,
#             "near_count": 7,
#             "miss_count": 4,
#             "health": 100,
#             "modifier": 2,
#             "time_played": 1549628878285,
#             "best_clear_type": 5,
#             "clear_type": 5,
#             "name": "k3id",
#             "character": 7,
#             "is_skill_sealed": false,
#             "is_char_uncapped": false,
#             "rank": 5328
#         }
#     ]
# }
# {
#     "success": true,
#     "value": []
# }
# {
#     "success": true,
#     "value": []
# }
# {
#     "success": true,
#     "value": []
# }
# {
#     "success": true,
#     "value": []
# }
# {
#     "success": true,
#     "value": []
# }
# {
#     "success": true,
#     "value": []
# }
# {
#     "success": true,
#     "value": [
#         {
#             "user_id": 26652,
#             "song_id": "empireofwinter",
#             "difficulty": 0,
#             "score": 10000475,
#             "shiny_perfect_count": 475,
#             "perfect_count": 484,
#             "near_count": 0,
#             "miss_count": 0,
#             "health": 100,
#             "modifier": 0,
#             "time_played": 1545573928378,
#             "best_clear_type": 3,
#             "clear_type": 3,
#             "name": "k3id",
#             "character": 7,
#             "is_skill_sealed": false,
#             "is_char_uncapped": false,
#             "rank": 529
#         }
#     ]
# }
# {
#     "success": true,
#     "value": [
#         {
#             "user_id": 26652,
#             "song_id": "empireofwinter",
#             "difficulty": 1,
#             "score": 10000640,
#             "shiny_perfect_count": 640,
#             "perfect_count": 662,
#             "near_count": 0,
#             "miss_count": 0,
#             "health": 100,
#             "modifier": 0,
#             "time_played": 1548770615986,
#             "best_clear_type": 3,
#             "clear_type": 3,
#             "name": "k3id",
#             "character": 7,
#             "is_skill_sealed": false,
#             "is_char_uncapped": false,
#             "rank": 319
#         }
#     ]
# }
# {
#     "success": true,
#     "value": [
#         {
#             "user_id": 26652,
#             "song_id": "empireofwinter",
#             "difficulty": 2,
#             "score": 9995448,
#             "shiny_perfect_count": 883,
#             "perfect_count": 919,
#             "near_count": 1,
#             "miss_count": 0,
#             "health": 100,
#             "modifier": 0,
#             "time_played": 1545563846914,
#             "best_clear_type": 2,
#             "clear_type": 2,
#             "name": "k3id",
#             "character": 7,
#             "is_skill_sealed": false,
#             "is_char_uncapped": false,
#             "rank": 1850
#         }
#     ]
# }
# {
#     "success": true,
#     "value": []
# }
# {
#     "success": true,
#     "value": []
# }
# {
#     "success": true,
#     "value": []
# }
# {
#     "success": true,
#     "value": []
# }
# {
#     "success": true,
#     "value": []
# }
# {
#     "success": true,
#     "value": []
# }
# {
#     "success": true,
#     "value": []
# }
# {
#     "success": true,
#     "value": []
# }
# {
#     "success": true,
#     "value": []
# }
# {
#     "success": true,
#     "value": []
# }
# {
#     "success": true,
#     "value": []
# }
# {
#     "success": true,
#     "value": []
# }
# {
#     "success": true,
#     "value": []
# }
# {
#     "success": true,
#     "value": []
# }
# {
#     "success": true,
#     "value": []
# }
# {
#     "success": true,
#     "value": []
# }
# {
#     "success": true,
#     "value": []
# }
# {
#     "success": true,
#     "value": []
# }
# {
#     "success": true,
#     "value": [
#         {
#             "user_id": 26652,
#             "song_id": "solitarydream",
#             "difficulty": 0,
#             "score": 10000706,
#             "shiny_perfect_count": 706,
#             "perfect_count": 712,
#             "near_count": 0,
#             "miss_count": 0,
#             "health": 100,
#             "modifier": 0,
#             "time_played": 1552205625529,
#             "best_clear_type": 3,
#             "clear_type": 3,
#             "name": "k3id",
#             "character": 7,
#             "is_skill_sealed": false,
#             "is_char_uncapped": false,
#             "rank": 275
#         }
#     ]
# }
# {
#     "success": true,
#     "value": [
#         {
#             "user_id": 26652,
#             "song_id": "solitarydream",
#             "difficulty": 1,
#             "score": 10000834,
#             "shiny_perfect_count": 834,
#             "perfect_count": 854,
#             "near_count": 0,
#             "miss_count": 0,
#             "health": 100,
#             "modifier": 0,
#             "time_played": 1552206662165,
#             "best_clear_type": 3,
#             "clear_type": 3,
#             "name": "k3id",
#             "character": 7,
#             "is_skill_sealed": false,
#             "is_char_uncapped": false,
#             "rank": 322
#         }
#     ]
# }
# {
#     "success": true,
#     "value": [
#         {
#             "user_id": 26652,
#             "song_id": "solitarydream",
#             "difficulty": 2,
#             "score": 9975186,
#             "shiny_perfect_count": 907,
#             "perfect_count": 967,
#             "near_count": 5,
#             "miss_count": 0,
#             "health": 100,
#             "modifier": 0,
#             "time_played": 1555770731127,
#             "best_clear_type": 2,
#             "clear_type": 2,
#             "name": "k3id",
#             "character": 7,
#             "is_skill_sealed": false,
#             "is_char_uncapped": false,
#             "rank": 2867
#         }
#     ]
# }
# {
#     "success": true,
#     "value": []
# }
# {
#     "success": true,
#     "value": []
# }
# {
#     "success": true,
#     "value": []
# }
# {
#     "success": true,
#     "value": []
# }
# {
#     "success": true,
#     "value": []
# }
# {
#     "success": true,
#     "value": []
# }
# {
#     "success": true,
#     "value": []
# }
# {
#     "success": true,
#     "value": []
# }
# {
#     "success": true,
#     "value": []
# }
# {
#     "success": true,
#     "value": []
# }
# {
#     "success": true,
#     "value": []
# }
# {
#     "success": true,
#     "value": []
# }
# {
#     "success": true,
#     "value": []
# }
# {
#     "success": true,
#     "value": []
# }
# {
#     "success": true,
#     "value": []
# }
# {
#     "success": true,
#     "value": [
#         {
#             "user_id": 26652,
#             "song_id": "revixy",
#             "difficulty": 0,
#             "score": 10000531,
#             "shiny_perfect_count": 531,
#             "perfect_count": 538,
#             "near_count": 0,
#             "miss_count": 0,
#             "health": 100,
#             "modifier": 2,
#             "time_played": 1555145625559,
#             "best_clear_type": 3,
#             "clear_type": 3,
#             "name": "k3id",
#             "character": 7,
#             "is_skill_sealed": false,
#             "is_char_uncapped": false,
#             "rank": 322
#         }
#     ]
# }
# {
#     "success": true,
#     "value": [
#         {
#             "user_id": 26652,
#             "song_id": "revixy",
#             "difficulty": 1,
#             "score": 10000708,
#             "shiny_perfect_count": 708,
#             "perfect_count": 729,
#             "near_count": 0,
#             "miss_count": 0,
#             "health": 100,
#             "modifier": 0,
#             "time_played": 1555237421250,
#             "best_clear_type": 3,
#             "clear_type": 3,
#             "name": "k3id",
#             "character": 7,
#             "is_skill_sealed": false,
#             "is_char_uncapped": false,
#             "rank": 122
#         }
#     ]
# }
# {
#     "success": true,
#     "value": [
#         {
#             "user_id": 26652,
#             "song_id": "revixy",
#             "difficulty": 2,
#             "score": 9977100,
#             "shiny_perfect_count": 978,
#             "perfect_count": 1043,
#             "near_count": 3,
#             "miss_count": 1,
#             "health": 100,
#             "modifier": 0,
#             "time_played": 1556290199938,
#             "best_clear_type": 2,
#             "clear_type": 1,
#             "name": "k3id",
#             "character": 7,
#             "is_skill_sealed": false,
#             "is_char_uncapped": false,
#             "rank": 1486
#         }
#     ]
# }
# {
#     "success": true,
#     "value": [
#         {
#             "user_id": 26652,
#             "song_id": "grimheart",
#             "difficulty": 0,
#             "score": 10000727,
#             "shiny_perfect_count": 727,
#             "perfect_count": 728,
#             "near_count": 0,
#             "miss_count": 0,
#             "health": 100,
#             "modifier": 2,
#             "time_played": 1554561441653,
#             "best_clear_type": 3,
#             "clear_type": 3,
#             "name": "k3id",
#             "character": 7,
#             "is_skill_sealed": false,
#             "is_char_uncapped": false,
#             "rank": 68
#         }
#     ]
# }
# {
#     "success": true,
#     "value": [
#         {
#             "user_id": 26652,
#             "song_id": "grimheart",
#             "difficulty": 1,
#             "score": 10000687,
#             "shiny_perfect_count": 687,
#             "perfect_count": 699,
#             "near_count": 0,
#             "miss_count": 0,
#             "health": 100,
#             "modifier": 2,
#             "time_played": 1554561639947,
#             "best_clear_type": 3,
#             "clear_type": 3,
#             "name": "k3id",
#             "character": 7,
#             "is_skill_sealed": false,
#             "is_char_uncapped": false,
#             "rank": 199
#         }
#     ]
# }
# {
#     "success": true,
#     "value": [
#         {
#             "user_id": 26652,
#             "song_id": "grimheart",
#             "difficulty": 2,
#             "score": 9974835,
#             "shiny_perfect_count": 904,
#             "perfect_count": 956,
#             "near_count": 1,
#             "miss_count": 2,
#             "health": 100,
#             "modifier": 0,
#             "time_played": 1554565972704,
#             "best_clear_type": 2,
#             "clear_type": 1,
#             "name": "k3id",
#             "character": 7,
#             "is_skill_sealed": false,
#             "is_char_uncapped": false,
#             "rank": 2067
#         }
#     ]
# }

# %%
song_rlt
# Out:
# [{'song_name': 'Sayonara Hatsukoi',
#   'difficulty': 'PAST',
#   'level': 1,
#   'best_clear_type': 'Pure Memory',
#   'score': 10000202,
#   'shiny_perfect_count': 202,
#   'perfect_count': 205,
#   'near_count': 0,
#   'miss_count': 0,
#   'rank': 491},
#  {'song_name': 'Sayonara Hatsukoi',
#   'difficulty': 'PRESENT',
#   'level': 4,
#   'best_clear_type': 'Pure Memory',
#   'score': 10000301,
#   'shiny_perfect_count': 301,
#   'perfect_count': 305,
#   'near_count': 0,
#   'miss_count': 0,
#   'rank': 104},
#  {'song_name': 'Sayonara Hatsukoi',
#   'difficulty': 'FUTURE',
#   'level': 6,
#   'best_clear_type': 'Pure Memory',
#   'score': 10000629,
#   'shiny_perfect_count': 629,
#   'perfect_count': 666,
#   'near_count': 0,
#   'miss_count': 0,
#   'rank': 7421},
#  {'song_name': 'Lost Civilization',
#   'difficulty': 'PAST',
#   'level': 4,
#   'best_clear_type': 'Pure Memory',
#   'score': 10000453,
#   'shiny_perfect_count': 453,
#   'perfect_count': 462,
#   'near_count': 0,
#   'miss_count': 0,
#   'rank': 440},
#  {'song_name': 'Lost Civilization',
#   'difficulty': 'PRESENT',
#   'level': 7,
#   'best_clear_type': 'Pure Memory',
#   'score': 10000669,
#   'shiny_perfect_count': 669,
#   'perfect_count': 690,
#   'near_count': 0,
#   'miss_count': 0,
#   'rank': 328},
#  {'song_name': 'Lost Civilization',
#   'difficulty': 'FUTURE',
#   'level': 9,
#   'best_clear_type': 'Track Complete (Hard Gauge)',
#   'score': 9950177,
#   'shiny_perfect_count': 887,
#   'perfect_count': 977,
#   'near_count': 8,
#   'miss_count': 1,
#   'rank': 4948},
#  {'song_name': 'GOODTEK (Arcaea Edit)',
#   'difficulty': 'PAST',
#   'level': 4,
#   'best_clear_type': 'Pure Memory',
#   'score': 10000440,
#   'shiny_perfect_count': 440,
#   'perfect_count': 449,
#   'near_count': 0,
#   'miss_count': 0,
#   'rank': 632},
#  {'song_name': 'GOODTEK (Arcaea Edit)',
#   'difficulty': 'PRESENT',
#   'level': 6,
#   'best_clear_type': 'Pure Memory',
#   'score': 10000609,
#   'shiny_perfect_count': 609,
#   'perfect_count': 632,
#   'near_count': 0,
#   'miss_count': 0,
#   'rank': 748},
#  {'song_name': 'GOODTEK (Arcaea Edit)',
#   'difficulty': 'FUTURE',
#   'level': 9,
#   'best_clear_type': 'Track Complete (Hard Gauge)',
#   'score': 9856203,
#   'shiny_perfect_count': 832,
#   'perfect_count': 948,
#   'near_count': 12,
#   'miss_count': 8,
#   'rank': 11409},
#  {'song_name': 'cry of viyella',
#   'difficulty': 'PAST',
#   'level': 3,
#   'best_clear_type': 'Pure Memory',
#   'score': 10000408,
#   'shiny_perfect_count': 408,
#   'perfect_count': 414,
#   'near_count': 0,
#   'miss_count': 0,
#   'rank': 77},
#  {'song_name': 'cry of viyella',
#   'difficulty': 'PRESENT',
#   'level': 6,
#   'best_clear_type': 'Pure Memory',
#   'score': 10000465,
#   'shiny_perfect_count': 465,
#   'perfect_count': 492,
#   'near_count': 0,
#   'miss_count': 0,
#   'rank': 340},
#  {'song_name': 'cry of viyella',
#   'difficulty': 'FUTURE',
#   'level': 8,
#   'best_clear_type': 'Full Recall',
#   'score': 9962758,
#   'shiny_perfect_count': 685,
#   'perfect_count': 785,
#   'near_count': 6,
#   'miss_count': 0,
#   'rank': 3137},
#  {'song_name': 'Rise',
#   'difficulty': 'PAST',
#   'level': 2,
#   'best_clear_type': 'Pure Memory',
#   'score': 10000321,
#   'shiny_perfect_count': 321,
#   'perfect_count': 322,
#   'near_count': 0,
#   'miss_count': 0,
#   'rank': 63},
#  {'song_name': 'Rise',
#   'difficulty': 'PRESENT',
#   'level': 4,
#   'best_clear_type': 'Pure Memory',
#   'score': 10000593,
#   'shiny_perfect_count': 593,
#   'perfect_count': 599,
#   'near_count': 0,
#   'miss_count': 0,
#   'rank': 268},
#  {'song_name': 'Rise',
#   'difficulty': 'FUTURE',
#   'level': 7,
#   'best_clear_type': 'Pure Memory',
#   'score': 10000760,
#   'shiny_perfect_count': 760,
#   'perfect_count': 788,
#   'near_count': 0,
#   'miss_count': 0,
#   'rank': 1830},
#  {'song_name': 'Lucifer',
#   'difficulty': 'PAST',
#   'level': 3,
#   'best_clear_type': 'Pure Memory',
#   'score': 10000420,
#   'shiny_perfect_count': 420,
#   'perfect_count': 424,
#   'near_count': 0,
#   'miss_count': 0,
#   'rank': 189},
#  {'song_name': 'Lucifer',
#   'difficulty': 'PRESENT',
#   'level': 5,
#   'best_clear_type': 'Pure Memory',
#   'score': 10000493,
#   'shiny_perfect_count': 493,
#   'perfect_count': 506,
#   'near_count': 0,
#   'miss_count': 0,
#   'rank': 369},
#  {'song_name': 'Lucifer',
#   'difficulty': 'FUTURE',
#   'level': 8,
#   'best_clear_type': 'Full Recall',
#   'score': 9983390,
#   'shiny_perfect_count': 812,
#   'perfect_count': 858,
#   'near_count': 3,
#   'miss_count': 0,
#   'rank': 4376},
#  {'song_name': 'Fairytale',
#   'difficulty': 'PAST',
#   'level': 1,
#   'best_clear_type': 'Pure Memory',
#   'score': 10000336,
#   'shiny_perfect_count': 336,
#   'perfect_count': 336,
#   'near_count': 0,
#   'miss_count': 0,
#   'rank': 169},
#  {'song_name': 'Fairytale',
#   'difficulty': 'PRESENT',
#   'level': 3,
#   'best_clear_type': 'Pure Memory',
#   'score': 10000504,
#   'shiny_perfect_count': 504,
#   'perfect_count': 511,
#   'near_count': 0,
#   'miss_count': 0,
#   'rank': 273},
#  {'song_name': 'Fairytale',
#   'difficulty': 'FUTURE',
#   'level': 7,
#   'best_clear_type': 'Pure Memory',
#   'score': 10000753,
#   'shiny_perfect_count': 753,
#   'perfect_count': 782,
#   'near_count': 0,
#   'miss_count': 0,
#   'rank': 2773},
#  {'song_name': "I've heard it said",
#   'difficulty': 'PAST',
#   'level': 3,
#   'best_clear_type': 'Pure Memory',
#   'score': 10000508,
#   'shiny_perfect_count': 508,
#   'perfect_count': 510,
#   'near_count': 0,
#   'miss_count': 0,
#   'rank': 46},
#  {'song_name': "I've heard it said",
#   'difficulty': 'PRESENT',
#   'level': 6,
#   'best_clear_type': 'Pure Memory',
#   'score': 10000644,
#   'shiny_perfect_count': 644,
#   'perfect_count': 664,
#   'near_count': 0,
#   'miss_count': 0,
#   'rank': 158},
#  {'song_name': "I've heard it said",
#   'difficulty': 'FUTURE',
#   'level': 8,
#   'best_clear_type': 'Pure Memory',
#   'score': 10000845,
#   'shiny_perfect_count': 845,
#   'perfect_count': 864,
#   'near_count': 0,
#   'miss_count': 0,
#   'rank': 423},
#  {'song_name': 'Babaroque',
#   'difficulty': 'PAST',
#   'level': 3,
#   'best_clear_type': 'Pure Memory',
#   'score': 10000397,
#   'shiny_perfect_count': 397,
#   'perfect_count': 402,
#   'near_count': 0,
#   'miss_count': 0,
#   'rank': 120},
#  {'song_name': 'Babaroque',
#   'difficulty': 'PRESENT',
#   'level': 6,
#   'best_clear_type': 'Pure Memory',
#   'score': 10000615,
#   'shiny_perfect_count': 615,
#   'perfect_count': 645,
#   'near_count': 0,
#   'miss_count': 0,
#   'rank': 373},
#  {'song_name': 'Babaroque',
#   'difficulty': 'FUTURE',
#   'level': 8,
#   'best_clear_type': 'Full Recall',
#   'score': 9945045,
#   'shiny_perfect_count': 739,
#   'perfect_count': 801,
#   'near_count': 5,
#   'miss_count': 2,
#   'rank': 3857},
#  {'song_name': 'memoryfactory.lzh',
#   'difficulty': 'PAST',
#   'level': 2,
#   'best_clear_type': 'Pure Memory',
#   'score': 10000300,
#   'shiny_perfect_count': 300,
#   'perfect_count': 308,
#   'near_count': 0,
#   'miss_count': 0,
#   'rank': 202},
#  {'song_name': 'memoryfactory.lzh',
#   'difficulty': 'PRESENT',
#   'level': 5,
#   'best_clear_type': 'Pure Memory',
#   'score': 10000416,
#   'shiny_perfect_count': 416,
#   'perfect_count': 448,
#   'near_count': 0,
#   'miss_count': 0,
#   'rank': 440},
#  {'song_name': 'memoryfactory.lzh',
#   'difficulty': 'FUTURE',
#   'level': 8,
#   'best_clear_type': 'Full Recall',
#   'score': 9926166,
#   'shiny_perfect_count': 571,
#   'perfect_count': 662,
#   'near_count': 10,
#   'miss_count': 0,
#   'rank': 3243},
#  {'song_name': 'Snow White',
#   'difficulty': 'PAST',
#   'level': 2,
#   'best_clear_type': 'Pure Memory',
#   'score': 10000478,
#   'shiny_perfect_count': 478,
#   'perfect_count': 486,
#   'near_count': 0,
#   'miss_count': 0,
#   'rank': 649},
#  {'song_name': 'Snow White',
#   'difficulty': 'PRESENT',
#   'level': 5,
#   'best_clear_type': 'Pure Memory',
#   'score': 10000645,
#   'shiny_perfect_count': 645,
#   'perfect_count': 672,
#   'near_count': 0,
#   'miss_count': 0,
#   'rank': 1225},
#  {'song_name': 'Snow White',
#   'difficulty': 'FUTURE',
#   'level': 8,
#   'best_clear_type': 'Full Recall',
#   'score': 9975324,
#   'shiny_perfect_count': 887,
#   'perfect_count': 973,
#   'near_count': 5,
#   'miss_count': 0,
#   'rank': 3255},
#  {'song_name': 'Relentless',
#   'difficulty': 'PAST',
#   'level': 4,
#   'best_clear_type': 'Pure Memory',
#   'score': 10000602,
#   'shiny_perfect_count': 602,
#   'perfect_count': 607,
#   'near_count': 0,
#   'miss_count': 0,
#   'rank': 408},
#  {'song_name': 'Relentless',
#   'difficulty': 'PRESENT',
#   'level': 6,
#   'best_clear_type': 'Pure Memory',
#   'score': 10000715,
#   'shiny_perfect_count': 715,
#   'perfect_count': 722,
#   'near_count': 0,
#   'miss_count': 0,
#   'rank': 694},
#  {'song_name': 'Relentless',
#   'difficulty': 'FUTURE',
#   'level': 8,
#   'best_clear_type': 'Pure Memory',
#   'score': 10000985,
#   'shiny_perfect_count': 985,
#   'perfect_count': 1015,
#   'near_count': 0,
#   'miss_count': 0,
#   'rank': 862},
#  {'song_name': 'Shades of Light in a Transcendent Realm',
#   'difficulty': 'PAST',
#   'level': 3,
#   'best_clear_type': 'Pure Memory',
#   'score': 10000511,
#   'shiny_perfect_count': 511,
#   'perfect_count': 517,
#   'near_count': 0,
#   'miss_count': 0,
#   'rank': 487},
#  {'song_name': 'Shades of Light in a Transcendent Realm',
#   'difficulty': 'PRESENT',
#   'level': 6,
#   'best_clear_type': 'Pure Memory',
#   'score': 10000780,
#   'shiny_perfect_count': 780,
#   'perfect_count': 789,
#   'near_count': 0,
#   'miss_count': 0,
#   'rank': 285},
#  {'song_name': 'Shades of Light in a Transcendent Realm',
#   'difficulty': 'FUTURE',
#   'level': 8,
#   'best_clear_type': 'Pure Memory',
#   'score': 10001038,
#   'shiny_perfect_count': 1038,
#   'perfect_count': 1067,
#   'near_count': 0,
#   'miss_count': 0,
#   'rank': 1490},
#  {'song_name': 'Vexaria',
#   'difficulty': 'PAST',
#   'level': 2,
#   'best_clear_type': 'Pure Memory',
#   'score': 10000367,
#   'shiny_perfect_count': 367,
#   'perfect_count': 369,
#   'near_count': 0,
#   'miss_count': 0,
#   'rank': 71},
#  {'song_name': 'Vexaria',
#   'difficulty': 'PRESENT',
#   'level': 5,
#   'best_clear_type': 'Pure Memory',
#   'score': 10000510,
#   'shiny_perfect_count': 510,
#   'perfect_count': 534,
#   'near_count': 0,
#   'miss_count': 0,
#   'rank': 1203},
#  {'song_name': 'Vexaria',
#   'difficulty': 'FUTURE',
#   'level': 7,
#   'best_clear_type': 'Pure Memory',
#   'score': 10000690,
#   'shiny_perfect_count': 690,
#   'perfect_count': 734,
#   'near_count': 0,
#   'miss_count': 0,
#   'rank': 4502},
#  {'song_name': 'Essence of Twilight',
#   'difficulty': 'PAST',
#   'level': 4,
#   'best_clear_type': 'Pure Memory',
#   'score': 10000551,
#   'shiny_perfect_count': 551,
#   'perfect_count': 556,
#   'near_count': 0,
#   'miss_count': 0,
#   'rank': 141},
#  {'song_name': 'Essence of Twilight',
#   'difficulty': 'PRESENT',
#   'level': 7,
#   'best_clear_type': 'Pure Memory',
#   'score': 10000753,
#   'shiny_perfect_count': 753,
#   'perfect_count': 767,
#   'near_count': 0,
#   'miss_count': 0,
#   'rank': 164},
#  {'song_name': 'Essence of Twilight',
#   'difficulty': 'FUTURE',
#   'level': 9,
#   'best_clear_type': 'Full Recall',
#   'score': 9976200,
#   'shiny_perfect_count': 1117,
#   'perfect_count': 1199,
#   'near_count': 4,
#   'miss_count': 1,
#   'rank': 3283},
#  {'song_name': 'qualia -ideaesthesia-',
#   'difficulty': 'PAST',
#   'level': 5,
#   'best_clear_type': 'Pure Memory',
#   'score': 10000540,
#   'shiny_perfect_count': 540,
#   'perfect_count': 550,
#   'near_count': 0,
#   'miss_count': 0,
#   'rank': 197},
#  {'song_name': 'qualia -ideaesthesia-',
#   'difficulty': 'PRESENT',
#   'level': 7,
#   'best_clear_type': 'Pure Memory',
#   'score': 10000871,
#   'shiny_perfect_count': 871,
#   'perfect_count': 875,
#   'near_count': 0,
#   'miss_count': 0,
#   'rank': 934},
#  {'song_name': 'qualia -ideaesthesia-',
#   'difficulty': 'FUTURE',
#   'level': 9,
#   'best_clear_type': 'Track Complete (Hard Gauge)',
#   'score': 9947132,
#   'shiny_perfect_count': 949,
#   'perfect_count': 1014,
#   'near_count': 5,
#   'miss_count': 3,
#   'rank': 3709},
#  {'song_name': 'PRAGMATISM',
#   'difficulty': 'PAST',
#   'level': 4,
#   'best_clear_type': 'Pure Memory',
#   'score': 10000467,
#   'shiny_perfect_count': 467,
#   'perfect_count': 476,
#   'near_count': 0,
#   'miss_count': 0,
#   'rank': 239},
#  {'song_name': 'PRAGMATISM',
#   'difficulty': 'PRESENT',
#   'level': 8,
#   'best_clear_type': 'Full Recall',
#   'score': 9983277,
#   'shiny_perfect_count': 821,
#   'perfect_count': 852,
#   'near_count': 3,
#   'miss_count': 0,
#   'rank': 985},
#  {'song_name': 'PRAGMATISM',
#   'difficulty': 'FUTURE',
#   'level': 10,
#   'best_clear_type': 'Track Complete (Normal Gauge)',
#   'score': 9331914,
#   'shiny_perfect_count': 704,
#   'perfect_count': 858,
#   'near_count': 42,
#   'miss_count': 42,
#   'rank': 12735},
#  {'song_name': 'Sheriruth',
#   'difficulty': 'PAST',
#   'level': 5,
#   'best_clear_type': 'Pure Memory',
#   'score': 10000606,
#   'shiny_perfect_count': 606,
#   'perfect_count': 611,
#   'near_count': 0,
#   'miss_count': 0,
#   'rank': 53},
#  {'song_name': 'Sheriruth',
#   'difficulty': 'PRESENT',
#   'level': 7,
#   'best_clear_type': 'Pure Memory',
#   'score': 10000802,
#   'shiny_perfect_count': 802,
#   'perfect_count': 832,
#   'near_count': 0,
#   'miss_count': 0,
#   'rank': 295},
#  {'song_name': 'Sheriruth',
#   'difficulty': 'FUTURE',
#   'level': 10,
#   'best_clear_type': 'Track Complete (Hard Gauge)',
#   'score': 9696806,
#   'shiny_perfect_count': 890,
#   'perfect_count': 1096,
#   'near_count': 40,
#   'miss_count': 15,
#   'rank': 8465},
#  {'song_name': 'Lumia',
#   'difficulty': 'PAST',
#   'level': 2,
#   'best_clear_type': 'Pure Memory',
#   'score': 10000465,
#   'shiny_perfect_count': 465,
#   'perfect_count': 469,
#   'near_count': 0,
#   'miss_count': 0,
#   'rank': 95},
#  {'song_name': 'Lumia',
#   'difficulty': 'PRESENT',
#   'level': 6,
#   'best_clear_type': 'Pure Memory',
#   'score': 10000422,
#   'shiny_perfect_count': 422,
#   'perfect_count': 438,
#   'near_count': 0,
#   'miss_count': 0,
#   'rank': 106},
#  {'song_name': 'Lumia',
#   'difficulty': 'FUTURE',
#   'level': 8,
#   'best_clear_type': 'Pure Memory',
#   'score': 10000906,
#   'shiny_perfect_count': 906,
#   'perfect_count': 961,
#   'near_count': 0,
#   'miss_count': 0,
#   'rank': 2320},
#  {'song_name': 'Dement ~after legend~',
#   'difficulty': 'PAST',
#   'level': 3,
#   'best_clear_type': 'Pure Memory',
#   'score': 10000541,
#   'shiny_perfect_count': 541,
#   'perfect_count': 548,
#   'near_count': 0,
#   'miss_count': 0,
#   'rank': 171},
#  {'song_name': 'Dement ~after legend~',
#   'difficulty': 'PRESENT',
#   'level': 6,
#   'best_clear_type': 'Pure Memory',
#   'score': 10000723,
#   'shiny_perfect_count': 723,
#   'perfect_count': 756,
#   'near_count': 0,
#   'miss_count': 0,
#   'rank': 1749},
#  {'song_name': 'Dement ~after legend~',
#   'difficulty': 'FUTURE',
#   'level': 7,
#   'best_clear_type': 'Pure Memory',
#   'score': 10000940,
#   'shiny_perfect_count': 940,
#   'perfect_count': 970,
#   'near_count': 0,
#   'miss_count': 0,
#   'rank': 2449},
#  {'song_name': 'Dandelion',
#   'difficulty': 'PAST',
#   'level': 2,
#   'best_clear_type': 'Pure Memory',
#   'score': 10000382,
#   'shiny_perfect_count': 382,
#   'perfect_count': 391,
#   'near_count': 0,
#   'miss_count': 0,
#   'rank': 340},
#  {'song_name': 'Dandelion',
#   'difficulty': 'PRESENT',
#   'level': 6,
#   'best_clear_type': 'Pure Memory',
#   'score': 10000676,
#   'shiny_perfect_count': 676,
#   'perfect_count': 698,
#   'near_count': 0,
#   'miss_count': 0,
#   'rank': 337},
#  {'song_name': 'Dandelion',
#   'difficulty': 'FUTURE',
#   'level': 8,
#   'best_clear_type': 'Full Recall',
#   'score': 9968271,
#   'shiny_perfect_count': 845,
#   'perfect_count': 915,
#   'near_count': 6,
#   'miss_count': 0,
#   'rank': 3138},
#  {'song_name': 'Anökumene',
#   'difficulty': 'PAST',
#   'level': 2,
#   'best_clear_type': 'Pure Memory',
#   'score': 10000410,
#   'shiny_perfect_count': 410,
#   'perfect_count': 412,
#   'near_count': 0,
#   'miss_count': 0,
#   'rank': 208},
#  {'song_name': 'Anökumene',
#   'difficulty': 'PRESENT',
#   'level': 6,
#   'best_clear_type': 'Pure Memory',
#   'score': 10000564,
#   'shiny_perfect_count': 564,
#   'perfect_count': 588,
#   'near_count': 0,
#   'miss_count': 0,
#   'rank': 513},
#  {'song_name': 'Anökumene',
#   'difficulty': 'FUTURE',
#   'level': 9,
#   'best_clear_type': 'Track Complete (Hard Gauge)',
#   'score': 9924344,
#   'shiny_perfect_count': 725,
#   'perfect_count': 840,
#   'near_count': 9,
#   'miss_count': 2,
#   'rank': 6955},
#  {'song_name': 'Infinity Heaven',
#   'difficulty': 'PAST',
#   'level': 1,
#   'best_clear_type': 'Pure Memory',
#   'score': 10000334,
#   'shiny_perfect_count': 334,
#   'perfect_count': 336,
#   'near_count': 0,
#   'miss_count': 0,
#   'rank': 652},
#  {'song_name': 'Infinity Heaven',
#   'difficulty': 'PRESENT',
#   'level': 5,
#   'best_clear_type': 'Pure Memory',
#   'score': 10000530,
#   'shiny_perfect_count': 530,
#   'perfect_count': 545,
#   'near_count': 0,
#   'miss_count': 0,
#   'rank': 256},
#  {'song_name': 'Infinity Heaven',
#   'difficulty': 'FUTURE',
#   'level': 7,
#   'best_clear_type': 'Pure Memory',
#   'score': 10000806,
#   'shiny_perfect_count': 806,
#   'perfect_count': 853,
#   'near_count': 0,
#   'miss_count': 0,
#   'rank': 4471},
#  {'song_name': 'Party Vinyl', 'difficulty': 'PAST', 'level': 4},
#  {'song_name': 'Party Vinyl', 'difficulty': 'PRESENT', 'level': 7},
#  {'song_name': 'Party Vinyl', 'difficulty': 'FUTURE', 'level': 9},
#  {'song_name': 'Flashback', 'difficulty': 'PAST', 'level': 2},
#  {'song_name': 'Flashback', 'difficulty': 'PRESENT', 'level': 5},
#  {'song_name': 'Flashback', 'difficulty': 'FUTURE', 'level': 8},
#  {'song_name': 'Flyburg and Endroll', 'difficulty': 'PAST', 'level': 3},
#  {'song_name': 'Flyburg and Endroll', 'difficulty': 'PRESENT', 'level': 6},
#  {'song_name': 'Flyburg and Endroll', 'difficulty': 'FUTURE', 'level': 9},
#  {'song_name': 'Nirv lucE', 'difficulty': 'PAST', 'level': 2},
#  {'song_name': 'Nirv lucE', 'difficulty': 'PRESENT', 'level': 7},
#  {'song_name': 'Nirv lucE', 'difficulty': 'FUTURE', 'level': 10},
#  {'song_name': 'Paradise', 'difficulty': 'PAST', 'level': 1},
#  {'song_name': 'Paradise', 'difficulty': 'PRESENT', 'level': 4},
#  {'song_name': 'Paradise', 'difficulty': 'FUTURE', 'level': 7},
#  {'song_name': 'Brand new world',
#   'difficulty': 'PAST',
#   'level': 2,
#   'best_clear_type': 'Pure Memory',
#   'score': 10000321,
#   'shiny_perfect_count': 321,
#   'perfect_count': 322,
#   'near_count': 0,
#   'miss_count': 0,
#   'rank': 153},
#  {'song_name': 'Brand new world',
#   'difficulty': 'PRESENT',
#   'level': 4,
#   'best_clear_type': 'Pure Memory',
#   'score': 10000425,
#   'shiny_perfect_count': 425,
#   'perfect_count': 432,
#   'near_count': 0,
#   'miss_count': 0,
#   'rank': 253},
#  {'song_name': 'Brand new world',
#   'difficulty': 'FUTURE',
#   'level': 7,
#   'best_clear_type': 'Pure Memory',
#   'score': 10000733,
#   'shiny_perfect_count': 733,
#   'perfect_count': 787,
#   'near_count': 0,
#   'miss_count': 0,
#   'rank': 4379},
#  {'song_name': 'DataErr0r',
#   'difficulty': 'PAST',
#   'level': 3,
#   'best_clear_type': 'Pure Memory',
#   'score': 10000498,
#   'shiny_perfect_count': 498,
#   'perfect_count': 502,
#   'near_count': 0,
#   'miss_count': 0,
#   'rank': 331},
#  {'song_name': 'DataErr0r',
#   'difficulty': 'PRESENT',
#   'level': 7,
#   'best_clear_type': 'Pure Memory',
#   'score': 10000771,
#   'shiny_perfect_count': 771,
#   'perfect_count': 785,
#   'near_count': 0,
#   'miss_count': 0,
#   'rank': 217},
#  {'song_name': 'DataErr0r',
#   'difficulty': 'FUTURE',
#   'level': 9,
#   'best_clear_type': 'Track Complete (Hard Gauge)',
#   'score': 9822802,
#   'shiny_perfect_count': 813,
#   'perfect_count': 926,
#   'near_count': 24,
#   'miss_count': 5,
#   'rank': 5900},
#  {'song_name': 'CROSS†SOUL',
#   'difficulty': 'PAST',
#   'level': 4,
#   'best_clear_type': 'Pure Memory',
#   'score': 10000601,
#   'shiny_perfect_count': 601,
#   'perfect_count': 606,
#   'near_count': 0,
#   'miss_count': 0,
#   'rank': 155},
#  {'song_name': 'CROSS†SOUL',
#   'difficulty': 'PRESENT',
#   'level': 7,
#   'best_clear_type': 'Pure Memory',
#   'score': 10000812,
#   'shiny_perfect_count': 812,
#   'perfect_count': 823,
#   'near_count': 0,
#   'miss_count': 0,
#   'rank': 79},
#  {'song_name': 'CROSS†SOUL',
#   'difficulty': 'FUTURE',
#   'level': 9,
#   'best_clear_type': 'Track Complete (Hard Gauge)',
#   'score': 9741929,
#   'shiny_perfect_count': 949,
#   'perfect_count': 1039,
#   'near_count': 28,
#   'miss_count': 14,
#   'rank': 6384},
#  {'song_name': 'Your voice so... feat. Such',
#   'difficulty': 'PAST',
#   'level': 3,
#   'best_clear_type': 'Pure Memory',
#   'score': 10000461,
#   'shiny_perfect_count': 461,
#   'perfect_count': 469,
#   'near_count': 0,
#   'miss_count': 0,
#   'rank': 145},
#  {'song_name': 'Your voice so... feat. Such',
#   'difficulty': 'PRESENT',
#   'level': 6,
#   'best_clear_type': 'Pure Memory',
#   'score': 10000646,
#   'shiny_perfect_count': 646,
#   'perfect_count': 677,
#   'near_count': 0,
#   'miss_count': 0,
#   'rank': 157},
#  {'song_name': 'Your voice so... feat. Such',
#   'difficulty': 'FUTURE',
#   'level': 9,
#   'best_clear_type': 'Track Complete (Hard Gauge)',
#   'score': 9882424,
#   'shiny_perfect_count': 885,
#   'perfect_count': 992,
#   'near_count': 18,
#   'miss_count': 3,
#   'rank': 5291},
#  {'song_name': 'Chronostasis',
#   'difficulty': 'PAST',
#   'level': 3,
#   'best_clear_type': 'Pure Memory',
#   'score': 10000615,
#   'shiny_perfect_count': 615,
#   'perfect_count': 619,
#   'near_count': 0,
#   'miss_count': 0,
#   'rank': 348},
#  {'song_name': 'Chronostasis',
#   'difficulty': 'PRESENT',
#   'level': 7,
#   'best_clear_type': 'Pure Memory',
#   'score': 10000774,
#   'shiny_perfect_count': 774,
#   'perfect_count': 812,
#   'near_count': 0,
#   'miss_count': 0,
#   'rank': 980},
#  {'song_name': 'Chronostasis',
#   'difficulty': 'FUTURE',
#   'level': 9,
#   'best_clear_type': 'Full Recall',
#   'score': 9962605,
#   'shiny_perfect_count': 815,
#   'perfect_count': 909,
#   'near_count': 7,
#   'miss_count': 0,
#   'rank': 5828},
#  {'song_name': 'Kanagawa Cyber Culvert',
#   'difficulty': 'PAST',
#   'level': 1,
#   'best_clear_type': 'Pure Memory',
#   'score': 10000374,
#   'shiny_perfect_count': 374,
#   'perfect_count': 375,
#   'near_count': 0,
#   'miss_count': 0,
#   'rank': 194},
#  {'song_name': 'Kanagawa Cyber Culvert',
#   'difficulty': 'PRESENT',
#   'level': 5,
#   'best_clear_type': 'Pure Memory',
#   'score': 10000679,
#   'shiny_perfect_count': 679,
#   'perfect_count': 707,
#   'near_count': 0,
#   'miss_count': 0,
#   'rank': 904},
#  {'song_name': 'Kanagawa Cyber Culvert',
#   'difficulty': 'FUTURE',
#   'level': 9,
#   'best_clear_type': 'Track Complete (Hard Gauge)',
#   'score': 9960547,
#   'shiny_perfect_count': 1052,
#   'perfect_count': 1104,
#   'near_count': 5,
#   'miss_count': 2,
#   'rank': 7186},
#  {'song_name': 'Moonlight of Sand Castle', 'difficulty': 'PAST', 'level': 1},
#  {'song_name': 'Moonlight of Sand Castle',
#   'difficulty': 'PRESENT',
#   'level': 5},
#  {'song_name': 'Moonlight of Sand Castle', 'difficulty': 'FUTURE', 'level': 7},
#  {'song_name': 'REconstruction', 'difficulty': 'PAST', 'level': 2},
#  {'song_name': 'REconstruction', 'difficulty': 'PRESENT', 'level': 6},
#  {'song_name': 'REconstruction', 'difficulty': 'FUTURE', 'level': 8},
#  {'song_name': "Evoltex (poppi'n mix)", 'difficulty': 'PAST', 'level': 2},
#  {'song_name': "Evoltex (poppi'n mix)", 'difficulty': 'PRESENT', 'level': 7},
#  {'song_name': "Evoltex (poppi'n mix)", 'difficulty': 'FUTURE', 'level': 8},
#  {'song_name': 'Oracle', 'difficulty': 'PAST', 'level': 3},
#  {'song_name': 'Oracle', 'difficulty': 'PRESENT', 'level': 5},
#  {'song_name': 'Oracle', 'difficulty': 'FUTURE', 'level': 9},
#  {'song_name': 'αterlβus', 'difficulty': 'PAST', 'level': 4},
#  {'song_name': 'αterlβus', 'difficulty': 'PRESENT', 'level': 7},
#  {'song_name': 'αterlβus', 'difficulty': 'FUTURE', 'level': 10},
#  {'song_name': 'Clotho and the stargazer',
#   'difficulty': 'PAST',
#   'level': 2,
#   'best_clear_type': 'Pure Memory',
#   'score': 10000516,
#   'shiny_perfect_count': 516,
#   'perfect_count': 519,
#   'near_count': 0,
#   'miss_count': 0,
#   'rank': 259},
#  {'song_name': 'Clotho and the stargazer',
#   'difficulty': 'PRESENT',
#   'level': 5,
#   'best_clear_type': 'Pure Memory',
#   'score': 10000741,
#   'shiny_perfect_count': 741,
#   'perfect_count': 745,
#   'near_count': 0,
#   'miss_count': 0,
#   'rank': 111},
#  {'song_name': 'Clotho and the stargazer',
#   'difficulty': 'FUTURE',
#   'level': 7,
#   'best_clear_type': 'Pure Memory',
#   'score': 10000988,
#   'shiny_perfect_count': 988,
#   'perfect_count': 1021,
#   'near_count': 0,
#   'miss_count': 0,
#   'rank': 2049},
#  {'song_name': 'Impure Bird', 'difficulty': 'PAST', 'level': 2},
#  {'song_name': 'Impure Bird', 'difficulty': 'PRESENT', 'level': 5},
#  {'song_name': 'Impure Bird', 'difficulty': 'FUTURE', 'level': 9},
#  {'song_name': 'Ignotus',
#   'difficulty': 'PAST',
#   'level': 3,
#   'best_clear_type': 'Pure Memory',
#   'score': 10000573,
#   'shiny_perfect_count': 573,
#   'perfect_count': 579,
#   'near_count': 0,
#   'miss_count': 0,
#   'rank': 339},
#  {'song_name': 'Ignotus',
#   'difficulty': 'PRESENT',
#   'level': 6,
#   'best_clear_type': 'Pure Memory',
#   'score': 10000791,
#   'shiny_perfect_count': 791,
#   'perfect_count': 809,
#   'near_count': 0,
#   'miss_count': 0,
#   'rank': 606},
#  {'song_name': 'Ignotus',
#   'difficulty': 'FUTURE',
#   'level': 9,
#   'best_clear_type': 'Track Complete (Hard Gauge)',
#   'score': 9890879,
#   'shiny_perfect_count': 1084,
#   'perfect_count': 1204,
#   'near_count': 15,
#   'miss_count': 6,
#   'rank': 8924},
#  {'song_name': 'Lethaeus', 'difficulty': 'PAST', 'level': 3},
#  {'song_name': 'Lethaeus', 'difficulty': 'PRESENT', 'level': 6},
#  {'song_name': 'Lethaeus', 'difficulty': 'FUTURE', 'level': 9},
#  {'song_name': 'Romance Wars', 'difficulty': 'PAST', 'level': 1},
#  {'song_name': 'Romance Wars', 'difficulty': 'PRESENT', 'level': 4},
#  {'song_name': 'Romance Wars', 'difficulty': 'FUTURE', 'level': 7},
#  {'song_name': 'Blossoms', 'difficulty': 'PAST', 'level': 1},
#  {'song_name': 'Blossoms', 'difficulty': 'PRESENT', 'level': 4},
#  {'song_name': 'Blossoms', 'difficulty': 'FUTURE', 'level': 7},
#  {'song_name': 'Moonheart', 'difficulty': 'PAST', 'level': 2},
#  {'song_name': 'Moonheart', 'difficulty': 'PRESENT', 'level': 5},
#  {'song_name': 'Moonheart', 'difficulty': 'FUTURE', 'level': 8},
#  {'song_name': 'Genesis', 'difficulty': 'PAST', 'level': 2},
#  {'song_name': 'Genesis', 'difficulty': 'PRESENT', 'level': 5},
#  {'song_name': 'Genesis', 'difficulty': 'FUTURE', 'level': 8},
#  {'song_name': 'Harutopia ~Utopia of Spring~',
#   'difficulty': 'PAST',
#   'level': 1,
#   'best_clear_type': 'Pure Memory',
#   'score': 10000444,
#   'shiny_perfect_count': 444,
#   'perfect_count': 444,
#   'near_count': 0,
#   'miss_count': 0,
#   'rank': 120},
#  {'song_name': 'Harutopia ~Utopia of Spring~',
#   'difficulty': 'PRESENT',
#   'level': 4,
#   'best_clear_type': 'Pure Memory',
#   'score': 10000699,
#   'shiny_perfect_count': 699,
#   'perfect_count': 706,
#   'near_count': 0,
#   'miss_count': 0,
#   'rank': 209},
#  {'song_name': 'Harutopia ~Utopia of Spring~',
#   'difficulty': 'FUTURE',
#   'level': 8,
#   'best_clear_type': 'Full Recall',
#   'score': 9982152,
#   'shiny_perfect_count': 1003,
#   'perfect_count': 1057,
#   'near_count': 4,
#   'miss_count': 0,
#   'rank': 3620},
#  {'song_name': 'Auxesia', 'difficulty': 'PAST', 'level': 3},
#  {'song_name': 'Auxesia', 'difficulty': 'PRESENT', 'level': 6},
#  {'song_name': 'Auxesia', 'difficulty': 'FUTURE', 'level': 9},
#  {'song_name': 'Rabbit In The Black Room',
#   'difficulty': 'PAST',
#   'level': 2,
#   'best_clear_type': 'Pure Memory',
#   'score': 10000371,
#   'shiny_perfect_count': 371,
#   'perfect_count': 373,
#   'near_count': 0,
#   'miss_count': 0,
#   'rank': 201},
#  {'song_name': 'Rabbit In The Black Room',
#   'difficulty': 'PRESENT',
#   'level': 5,
#   'best_clear_type': 'Pure Memory',
#   'score': 10000463,
#   'shiny_perfect_count': 463,
#   'perfect_count': 467,
#   'near_count': 0,
#   'miss_count': 0,
#   'rank': 41},
#  {'song_name': 'Rabbit In The Black Room',
#   'difficulty': 'FUTURE',
#   'level': 8,
#   'best_clear_type': 'Full Recall',
#   'score': 9942379,
#   'shiny_perfect_count': 670,
#   'perfect_count': 764,
#   'near_count': 7,
#   'miss_count': 1,
#   'rank': 7346},
#  {'song_name': 'Modelista',
#   'difficulty': 'PAST',
#   'level': 3,
#   'best_clear_type': 'Pure Memory',
#   'score': 10000409,
#   'shiny_perfect_count': 409,
#   'perfect_count': 418,
#   'near_count': 0,
#   'miss_count': 0,
#   'rank': 251},
#  {'song_name': 'Modelista',
#   'difficulty': 'PRESENT',
#   'level': 7,
#   'best_clear_type': 'Pure Memory',
#   'score': 10000662,
#   'shiny_perfect_count': 662,
#   'perfect_count': 691,
#   'near_count': 0,
#   'miss_count': 0,
#   'rank': 337},
#  {'song_name': 'Modelista',
#   'difficulty': 'FUTURE',
#   'level': 9,
#   'best_clear_type': 'Track Complete (Hard Gauge)',
#   'score': 9649318,
#   'shiny_perfect_count': 804,
#   'perfect_count': 959,
#   'near_count': 31,
#   'miss_count': 20,
#   'rank': 6398},
#  {'song_name': 'SOUNDWiTCH',
#   'difficulty': 'PAST',
#   'level': 3,
#   'best_clear_type': 'Pure Memory',
#   'score': 10000311,
#   'shiny_perfect_count': 311,
#   'perfect_count': 315,
#   'near_count': 0,
#   'miss_count': 0,
#   'rank': 170},
#  {'song_name': 'SOUNDWiTCH',
#   'difficulty': 'PRESENT',
#   'level': 6,
#   'best_clear_type': 'Pure Memory',
#   'score': 10000475,
#   'shiny_perfect_count': 475,
#   'perfect_count': 488,
#   'near_count': 0,
#   'miss_count': 0,
#   'rank': 225},
#  {'song_name': 'SOUNDWiTCH',
#   'difficulty': 'FUTURE',
#   'level': 9,
#   'best_clear_type': 'Track Complete (Hard Gauge)',
#   'score': 9631204,
#   'shiny_perfect_count': 631,
#   'perfect_count': 742,
#   'near_count': 28,
#   'miss_count': 15,
#   'rank': 9915},
#  {'song_name': 'trappola bewitching',
#   'difficulty': 'PAST',
#   'level': 3,
#   'best_clear_type': 'Pure Memory',
#   'score': 10000410,
#   'shiny_perfect_count': 410,
#   'perfect_count': 415,
#   'near_count': 0,
#   'miss_count': 0,
#   'rank': 560},
#  {'song_name': 'trappola bewitching',
#   'difficulty': 'PRESENT',
#   'level': 6,
#   'best_clear_type': 'Pure Memory',
#   'score': 10000530,
#   'shiny_perfect_count': 530,
#   'perfect_count': 541,
#   'near_count': 0,
#   'miss_count': 0,
#   'rank': 620},
#  {'song_name': 'trappola bewitching',
#   'difficulty': 'FUTURE',
#   'level': 9,
#   'best_clear_type': 'Track Complete (Hard Gauge)',
#   'score': 9651239,
#   'shiny_perfect_count': 856,
#   'perfect_count': 991,
#   'near_count': 33,
#   'miss_count': 20,
#   'rank': 12600},
#  {'song_name': 'Iconoclast',
#   'difficulty': 'PAST',
#   'level': 4,
#   'best_clear_type': 'Pure Memory',
#   'score': 10000435,
#   'shiny_perfect_count': 435,
#   'perfect_count': 443,
#   'near_count': 0,
#   'miss_count': 0,
#   'rank': 628},
#  {'song_name': 'Iconoclast',
#   'difficulty': 'PRESENT',
#   'level': 7,
#   'best_clear_type': 'Pure Memory',
#   'score': 10000575,
#   'shiny_perfect_count': 575,
#   'perfect_count': 593,
#   'near_count': 0,
#   'miss_count': 0,
#   'rank': 622},
#  {'song_name': 'Iconoclast',
#   'difficulty': 'FUTURE',
#   'level': 9,
#   'best_clear_type': 'Pure Memory',
#   'score': 10000770,
#   'shiny_perfect_count': 770,
#   'perfect_count': 795,
#   'near_count': 0,
#   'miss_count': 0,
#   'rank': 719},
#  {'song_name': 'conflict',
#   'difficulty': 'PAST',
#   'level': 4,
#   'best_clear_type': 'Pure Memory',
#   'score': 10000514,
#   'shiny_perfect_count': 514,
#   'perfect_count': 520,
#   'near_count': 0,
#   'miss_count': 0,
#   'rank': 303},
#  {'song_name': 'conflict',
#   'difficulty': 'PRESENT',
#   'level': 7,
#   'best_clear_type': 'Pure Memory',
#   'score': 10000683,
#   'shiny_perfect_count': 683,
#   'perfect_count': 731,
#   'near_count': 0,
#   'miss_count': 0,
#   'rank': 873},
#  {'song_name': 'conflict',
#   'difficulty': 'FUTURE',
#   'level': 10,
#   'best_clear_type': 'Track Complete (Normal Gauge)',
#   'score': 9513166,
#   'shiny_perfect_count': 856,
#   'perfect_count': 978,
#   'near_count': 53,
#   'miss_count': 25,
#   'rank': 11489},
#  {'song_name': 'Axium Crisis',
#   'difficulty': 'PAST',
#   'level': 5,
#   'best_clear_type': 'Pure Memory',
#   'score': 10000678,
#   'shiny_perfect_count': 678,
#   'perfect_count': 685,
#   'near_count': 0,
#   'miss_count': 0,
#   'rank': 188},
#  {'song_name': 'Axium Crisis',
#   'difficulty': 'PRESENT',
#   'level': 8,
#   'best_clear_type': 'Pure Memory',
#   'score': 10001007,
#   'shiny_perfect_count': 1007,
#   'perfect_count': 1065,
#   'near_count': 0,
#   'miss_count': 0,
#   'rank': 1009},
#  {'song_name': 'Axium Crisis',
#   'difficulty': 'FUTURE',
#   'level': 10,
#   'best_clear_type': 'Track Complete (Easy Gauge)',
#   'score': 9059317,
#   'shiny_perfect_count': 817,
#   'perfect_count': 959,
#   'near_count': 64,
#   'miss_count': 71,
#   'rank': 13742},
#  {'song_name': 'Grievous Lady',
#   'difficulty': 'PAST',
#   'level': 6,
#   'best_clear_type': 'Pure Memory',
#   'score': 10000950,
#   'shiny_perfect_count': 950,
#   'perfect_count': 956,
#   'near_count': 0,
#   'miss_count': 0,
#   'rank': 66},
#  {'song_name': 'Grievous Lady',
#   'difficulty': 'PRESENT',
#   'level': 9,
#   'best_clear_type': 'Full Recall',
#   'score': 9980176,
#   'shiny_perfect_count': 1115,
#   'perfect_count': 1190,
#   'near_count': 3,
#   'miss_count': 1,
#   'rank': 2150},
#  {'song_name': 'Grievous Lady',
#   'difficulty': 'FUTURE',
#   'level': 11,
#   'best_clear_type': 'Track Lost',
#   'score': 9128701,
#   'shiny_perfect_count': 1115,
#   'perfect_count': 1278,
#   'near_count': 91,
#   'miss_count': 81,
#   'rank': 9973},
#  {'song_name': "Dreamin' Attraction!!",
#   'difficulty': 'PAST',
#   'level': 4,
#   'best_clear_type': 'Pure Memory',
#   'score': 10000587,
#   'shiny_perfect_count': 587,
#   'perfect_count': 592,
#   'near_count': 0,
#   'miss_count': 0,
#   'rank': 81},
#  {'song_name': "Dreamin' Attraction!!",
#   'difficulty': 'PRESENT',
#   'level': 7,
#   'best_clear_type': 'Pure Memory',
#   'score': 10000747,
#   'shiny_perfect_count': 747,
#   'perfect_count': 785,
#   'near_count': 0,
#   'miss_count': 0,
#   'rank': 567},
#  {'song_name': "Dreamin' Attraction!!",
#   'difficulty': 'FUTURE',
#   'level': 9,
#   'best_clear_type': 'Track Complete (Hard Gauge)',
#   'score': 9837134,
#   'shiny_perfect_count': 996,
#   'perfect_count': 1104,
#   'near_count': 13,
#   'miss_count': 12,
#   'rank': 10122},
#  {'song_name': 'Red and Blue',
#   'difficulty': 'PAST',
#   'level': 4,
#   'best_clear_type': 'Pure Memory',
#   'score': 10000461,
#   'shiny_perfect_count': 461,
#   'perfect_count': 464,
#   'near_count': 0,
#   'miss_count': 0,
#   'rank': 129},
#  {'song_name': 'Red and Blue',
#   'difficulty': 'PRESENT',
#   'level': 7,
#   'best_clear_type': 'Pure Memory',
#   'score': 10000573,
#   'shiny_perfect_count': 573,
#   'perfect_count': 597,
#   'near_count': 0,
#   'miss_count': 0,
#   'rank': 445},
#  {'song_name': 'Red and Blue',
#   'difficulty': 'FUTURE',
#   'level': 9,
#   'best_clear_type': 'Track Complete (Hard Gauge)',
#   'score': 9823248,
#   'shiny_perfect_count': 763,
#   'perfect_count': 827,
#   'near_count': 6,
#   'miss_count': 12,
#   'rank': 9772},
#  {'song_name': 'One Last Drive',
#   'difficulty': 'PAST',
#   'level': 2,
#   'best_clear_type': 'Pure Memory',
#   'score': 10000603,
#   'shiny_perfect_count': 603,
#   'perfect_count': 604,
#   'near_count': 0,
#   'miss_count': 0,
#   'rank': 96},
#  {'song_name': 'One Last Drive',
#   'difficulty': 'PRESENT',
#   'level': 5,
#   'best_clear_type': 'Pure Memory',
#   'score': 10000535,
#   'shiny_perfect_count': 535,
#   'perfect_count': 564,
#   'near_count': 0,
#   'miss_count': 0,
#   'rank': 1034},
#  {'song_name': 'One Last Drive',
#   'difficulty': 'FUTURE',
#   'level': 8,
#   'best_clear_type': 'Full Recall',
#   'score': 9983865,
#   'shiny_perfect_count': 815,
#   'perfect_count': 882,
#   'near_count': 3,
#   'miss_count': 0,
#   'rank': 3366},
#  {'song_name': 'Surrender', 'difficulty': 'PAST', 'level': 3},
#  {'song_name': 'Surrender', 'difficulty': 'PRESENT', 'level': 6},
#  {'song_name': 'Surrender', 'difficulty': 'FUTURE', 'level': 8},
#  {'song_name': 'Yosakura Fubuki', 'difficulty': 'PAST', 'level': 4},
#  {'song_name': 'Yosakura Fubuki', 'difficulty': 'PRESENT', 'level': 7},
#  {'song_name': 'Yosakura Fubuki', 'difficulty': 'FUTURE', 'level': 9},
#  {'song_name': 'cyanine', 'difficulty': 'PAST', 'level': 4},
#  {'song_name': 'cyanine', 'difficulty': 'PRESENT', 'level': 7},
#  {'song_name': 'cyanine', 'difficulty': 'FUTURE', 'level': 10},
#  {'song_name': 'Dream goes on', 'difficulty': 'PAST', 'level': 1},
#  {'song_name': 'Dream goes on', 'difficulty': 'PRESENT', 'level': 5},
#  {'song_name': 'Dream goes on', 'difficulty': 'FUTURE', 'level': 7},
#  {'song_name': 'Journey', 'difficulty': 'PAST', 'level': 3},
#  {'song_name': 'Journey', 'difficulty': 'PRESENT', 'level': 6},
#  {'song_name': 'Journey', 'difficulty': 'FUTURE', 'level': 8},
#  {'song_name': 'Specta', 'difficulty': 'PAST', 'level': 3},
#  {'song_name': 'Specta', 'difficulty': 'PRESENT', 'level': 6},
#  {'song_name': 'Specta', 'difficulty': 'FUTURE', 'level': 9},
#  {'song_name': 'Quon', 'difficulty': 'PAST', 'level': 4},
#  {'song_name': 'Quon', 'difficulty': 'PRESENT', 'level': 6},
#  {'song_name': 'Quon', 'difficulty': 'FUTURE', 'level': 9},
#  {'song_name': 'Syro',
#   'difficulty': 'PAST',
#   'level': 3,
#   'best_clear_type': 'Pure Memory',
#   'score': 10000533,
#   'shiny_perfect_count': 533,
#   'perfect_count': 535,
#   'near_count': 0,
#   'miss_count': 0,
#   'rank': 73},
#  {'song_name': 'Syro',
#   'difficulty': 'PRESENT',
#   'level': 6,
#   'best_clear_type': 'Pure Memory',
#   'score': 10000802,
#   'shiny_perfect_count': 802,
#   'perfect_count': 829,
#   'near_count': 0,
#   'miss_count': 0,
#   'rank': 460},
#  {'song_name': 'Syro',
#   'difficulty': 'FUTURE',
#   'level': 9,
#   'best_clear_type': 'Track Complete (Hard Gauge)',
#   'score': 9892341,
#   'shiny_perfect_count': 1037,
#   'perfect_count': 1129,
#   'near_count': 17,
#   'miss_count': 4,
#   'rank': 6646},
#  {'song_name': 'Reinvent',
#   'difficulty': 'PAST',
#   'level': 2,
#   'best_clear_type': 'Pure Memory',
#   'score': 10000564,
#   'shiny_perfect_count': 564,
#   'perfect_count': 570,
#   'near_count': 0,
#   'miss_count': 0,
#   'rank': 686},
#  {'song_name': 'Reinvent',
#   'difficulty': 'PRESENT',
#   'level': 6,
#   'best_clear_type': 'Pure Memory',
#   'score': 10000677,
#   'shiny_perfect_count': 677,
#   'perfect_count': 703,
#   'near_count': 0,
#   'miss_count': 0,
#   'rank': 251},
#  {'song_name': 'Reinvent',
#   'difficulty': 'FUTURE',
#   'level': 8,
#   'best_clear_type': 'Full Recall',
#   'score': 9983182,
#   'shiny_perfect_count': 788,
#   'perfect_count': 849,
#   'near_count': 3,
#   'miss_count': 0,
#   'rank': 2065},
#  {'song_name': 'Silent Rush',
#   'difficulty': 'PAST',
#   'level': 2,
#   'best_clear_type': 'Pure Memory',
#   'score': 10000413,
#   'shiny_perfect_count': 413,
#   'perfect_count': 416,
#   'near_count': 0,
#   'miss_count': 0,
#   'rank': 107},
#  {'song_name': 'Silent Rush',
#   'difficulty': 'PRESENT',
#   'level': 5,
#   'best_clear_type': 'Pure Memory',
#   'score': 10000648,
#   'shiny_perfect_count': 648,
#   'perfect_count': 674,
#   'near_count': 0,
#   'miss_count': 0,
#   'rank': 667},
#  {'song_name': 'Silent Rush',
#   'difficulty': 'FUTURE',
#   'level': 8,
#   'best_clear_type': 'Full Recall',
#   'score': 9974281,
#   'shiny_perfect_count': 849,
#   'perfect_count': 936,
#   'near_count': 5,
#   'miss_count': 0,
#   'rank': 2894},
#  {'song_name': 'Singularity',
#   'difficulty': 'PAST',
#   'level': 4,
#   'best_clear_type': 'Pure Memory',
#   'score': 10000529,
#   'shiny_perfect_count': 529,
#   'perfect_count': 534,
#   'near_count': 0,
#   'miss_count': 0,
#   'rank': 77},
#  {'song_name': 'Singularity',
#   'difficulty': 'PRESENT',
#   'level': 7,
#   'best_clear_type': 'Pure Memory',
#   'score': 10000649,
#   'shiny_perfect_count': 649,
#   'perfect_count': 678,
#   'near_count': 0,
#   'miss_count': 0,
#   'rank': 625},
#  {'song_name': 'Singularity',
#   'difficulty': 'FUTURE',
#   'level': 10,
#   'best_clear_type': 'Track Complete (Normal Gauge)',
#   'score': 9412598,
#   'shiny_perfect_count': 834,
#   'perfect_count': 1015,
#   'near_count': 50,
#   'miss_count': 40,
#   'rank': 8892},
#  {'song_name': 'Memory Forest',
#   'difficulty': 'PAST',
#   'level': 3,
#   'best_clear_type': 'Pure Memory',
#   'score': 10000633,
#   'shiny_perfect_count': 633,
#   'perfect_count': 639,
#   'near_count': 0,
#   'miss_count': 0,
#   'rank': 332},
#  {'song_name': 'Memory Forest',
#   'difficulty': 'PRESENT',
#   'level': 6,
#   'best_clear_type': 'Pure Memory',
#   'score': 10000712,
#   'shiny_perfect_count': 712,
#   'perfect_count': 726,
#   'near_count': 0,
#   'miss_count': 0,
#   'rank': 281},
#  {'song_name': 'Memory Forest',
#   'difficulty': 'FUTURE',
#   'level': 9,
#   'best_clear_type': 'Track Complete (Hard Gauge)',
#   'score': 9821902,
#   'shiny_perfect_count': 839,
#   'perfect_count': 949,
#   'near_count': 23,
#   'miss_count': 6,
#   'rank': 5994},
#  {'song_name': 'Strongholds',
#   'difficulty': 'PAST',
#   'level': 2,
#   'best_clear_type': 'Pure Memory',
#   'score': 10000565,
#   'shiny_perfect_count': 565,
#   'perfect_count': 570,
#   'near_count': 0,
#   'miss_count': 0,
#   'rank': 467},
#  {'song_name': 'Strongholds',
#   'difficulty': 'PRESENT',
#   'level': 5,
#   'best_clear_type': 'Pure Memory',
#   'score': 10000768,
#   'shiny_perfect_count': 768,
#   'perfect_count': 778,
#   'near_count': 0,
#   'miss_count': 0,
#   'rank': 199},
#  {'song_name': 'Strongholds',
#   'difficulty': 'FUTURE',
#   'level': 9,
#   'best_clear_type': 'Track Complete (Hard Gauge)',
#   'score': 9811030,
#   'shiny_perfect_count': 835,
#   'perfect_count': 899,
#   'near_count': 11,
#   'miss_count': 12,
#   'rank': 8717},
#  {'song_name': 'next to you',
#   'difficulty': 'PAST',
#   'level': 4,
#   'best_clear_type': 'Pure Memory',
#   'score': 10000450,
#   'shiny_perfect_count': 450,
#   'perfect_count': 454,
#   'near_count': 0,
#   'miss_count': 0,
#   'rank': 149},
#  {'song_name': 'next to you',
#   'difficulty': 'PRESENT',
#   'level': 7,
#   'best_clear_type': 'Pure Memory',
#   'score': 10000557,
#   'shiny_perfect_count': 557,
#   'perfect_count': 583,
#   'near_count': 0,
#   'miss_count': 0,
#   'rank': 727},
#  {'song_name': 'next to you',
#   'difficulty': 'FUTURE',
#   'level': 8,
#   'best_clear_type': 'Full Recall',
#   'score': 9988631,
#   'shiny_perfect_count': 767,
#   'perfect_count': 822,
#   'near_count': 2,
#   'miss_count': 0,
#   'rank': 3298},
#  {'song_name': 'Metallic Punisher',
#   'difficulty': 'PAST',
#   'level': 3,
#   'best_clear_type': 'Pure Memory',
#   'score': 10000493,
#   'shiny_perfect_count': 493,
#   'perfect_count': 500,
#   'near_count': 0,
#   'miss_count': 0,
#   'rank': 515},
#  {'song_name': 'Metallic Punisher',
#   'difficulty': 'PRESENT',
#   'level': 7,
#   'best_clear_type': 'Pure Memory',
#   'score': 10000823,
#   'shiny_perfect_count': 823,
#   'perfect_count': 846,
#   'near_count': 0,
#   'miss_count': 0,
#   'rank': 387},
#  {'song_name': 'Metallic Punisher',
#   'difficulty': 'FUTURE',
#   'level': 10,
#   'best_clear_type': 'Track Complete (Normal Gauge)',
#   'score': 9605207,
#   'shiny_perfect_count': 1007,
#   'perfect_count': 1166,
#   'near_count': 46,
#   'miss_count': 26,
#   'rank': 6773},
#  {'song_name': 'Blaster',
#   'difficulty': 'PAST',
#   'level': 4,
#   'best_clear_type': 'Pure Memory',
#   'score': 10000567,
#   'shiny_perfect_count': 567,
#   'perfect_count': 571,
#   'near_count': 0,
#   'miss_count': 0,
#   'rank': 213},
#  {'song_name': 'Blaster',
#   'difficulty': 'PRESENT',
#   'level': 7,
#   'best_clear_type': 'Pure Memory',
#   'score': 10000608,
#   'shiny_perfect_count': 608,
#   'perfect_count': 635,
#   'near_count': 0,
#   'miss_count': 0,
#   'rank': 660},
#  {'song_name': 'Blaster',
#   'difficulty': 'FUTURE',
#   'level': 9,
#   'best_clear_type': 'Track Complete (Hard Gauge)',
#   'score': 9886079,
#   'shiny_perfect_count': 850,
#   'perfect_count': 981,
#   'near_count': 19,
#   'miss_count': 2,
#   'rank': 6054},
#  {'song_name': 'γuarδina', 'difficulty': 'PAST', 'level': 4},
#  {'song_name': 'γuarδina', 'difficulty': 'PRESENT', 'level': 7},
#  {'song_name': 'γuarδina', 'difficulty': 'FUTURE', 'level': 10},
#  {'song_name': 'carmine:scythe', 'difficulty': 'PAST', 'level': 4},
#  {'song_name': 'carmine:scythe', 'difficulty': 'PRESENT', 'level': 7},
#  {'song_name': 'carmine:scythe', 'difficulty': 'FUTURE', 'level': 9},
#  {'song_name': 'Be There',
#   'difficulty': 'PAST',
#   'level': 4,
#   'best_clear_type': 'Pure Memory',
#   'score': 10000588,
#   'shiny_perfect_count': 588,
#   'perfect_count': 592,
#   'near_count': 0,
#   'miss_count': 0,
#   'rank': 122},
#  {'song_name': 'Be There',
#   'difficulty': 'PRESENT',
#   'level': 7,
#   'best_clear_type': 'Pure Memory',
#   'score': 10000778,
#   'shiny_perfect_count': 778,
#   'perfect_count': 792,
#   'near_count': 0,
#   'miss_count': 0,
#   'rank': 100},
#  {'song_name': 'Be There',
#   'difficulty': 'FUTURE',
#   'level': 9,
#   'best_clear_type': 'Track Complete (Hard Gauge)',
#   'score': 9873596,
#   'shiny_perfect_count': 888,
#   'perfect_count': 962,
#   'near_count': 15,
#   'miss_count': 5,
#   'rank': 4695},
#  {'song_name': 'Cybernecia Catharsis',
#   'difficulty': 'PAST',
#   'level': 4,
#   'best_clear_type': 'Pure Memory',
#   'score': 10000376,
#   'shiny_perfect_count': 376,
#   'perfect_count': 377,
#   'near_count': 0,
#   'miss_count': 0,
#   'rank': 56},
#  {'song_name': 'Cybernecia Catharsis',
#   'difficulty': 'PRESENT',
#   'level': 7,
#   'best_clear_type': 'Pure Memory',
#   'score': 10000634,
#   'shiny_perfect_count': 634,
#   'perfect_count': 655,
#   'near_count': 0,
#   'miss_count': 0,
#   'rank': 452},
#  {'song_name': 'Cybernecia Catharsis',
#   'difficulty': 'FUTURE',
#   'level': 9,
#   'best_clear_type': 'Track Complete (Hard Gauge)',
#   'score': 9768227,
#   'shiny_perfect_count': 786,
#   'perfect_count': 914,
#   'near_count': 20,
#   'miss_count': 12,
#   'rank': 9056},
#  {'song_name': 'Call My Name feat. Yukacco', 'difficulty': 'PAST', 'level': 3},
#  {'song_name': 'Call My Name feat. Yukacco',
#   'difficulty': 'PRESENT',
#   'level': 6},
#  {'song_name': 'Call My Name feat. Yukacco',
#   'difficulty': 'FUTURE',
#   'level': 8},
#  {'song_name': 'inkar-usi',
#   'difficulty': 'PAST',
#   'level': 2,
#   'best_clear_type': 'Pure Memory',
#   'score': 10000275,
#   'shiny_perfect_count': 275,
#   'perfect_count': 276,
#   'near_count': 0,
#   'miss_count': 0,
#   'rank': 270},
#  {'song_name': 'inkar-usi',
#   'difficulty': 'PRESENT',
#   'level': 4,
#   'best_clear_type': 'Pure Memory',
#   'score': 10000317,
#   'shiny_perfect_count': 317,
#   'perfect_count': 326,
#   'near_count': 0,
#   'miss_count': 0,
#   'rank': 353},
#  {'song_name': 'inkar-usi',
#   'difficulty': 'FUTURE',
#   'level': 7,
#   'best_clear_type': 'Pure Memory',
#   'score': 10000439,
#   'shiny_perfect_count': 439,
#   'perfect_count': 463,
#   'near_count': 0,
#   'miss_count': 0,
#   'rank': 2957},
#  {'song_name': 'Maze No.9',
#   'difficulty': 'PAST',
#   'level': 3,
#   'best_clear_type': 'Pure Memory',
#   'score': 10000489,
#   'shiny_perfect_count': 489,
#   'perfect_count': 494,
#   'near_count': 0,
#   'miss_count': 0,
#   'rank': 267},
#  {'song_name': 'Maze No.9',
#   'difficulty': 'PRESENT',
#   'level': 3,
#   'best_clear_type': 'Pure Memory',
#   'score': 10000440,
#   'shiny_perfect_count': 440,
#   'perfect_count': 445,
#   'near_count': 0,
#   'miss_count': 0,
#   'rank': 428},
#  {'song_name': 'Maze No.9',
#   'difficulty': 'FUTURE',
#   'level': 8,
#   'best_clear_type': 'Full Recall',
#   'score': 9968446,
#   'shiny_perfect_count': 705,
#   'perfect_count': 771,
#   'near_count': 3,
#   'miss_count': 1,
#   'rank': 4585},
#  {'song_name': 'The Message',
#   'difficulty': 'PAST',
#   'level': 3,
#   'best_clear_type': 'Pure Memory',
#   'score': 10000529,
#   'shiny_perfect_count': 529,
#   'perfect_count': 536,
#   'near_count': 0,
#   'miss_count': 0,
#   'rank': 550},
#  {'song_name': 'The Message',
#   'difficulty': 'PRESENT',
#   'level': 6,
#   'best_clear_type': 'Pure Memory',
#   'score': 10000614,
#   'shiny_perfect_count': 614,
#   'perfect_count': 630,
#   'near_count': 0,
#   'miss_count': 0,
#   'rank': 127},
#  {'song_name': 'The Message',
#   'difficulty': 'FUTURE',
#   'level': 9,
#   'best_clear_type': 'Track Complete (Hard Gauge)',
#   'score': 9905143,
#   'shiny_perfect_count': 910,
#   'perfect_count': 979,
#   'near_count': 7,
#   'miss_count': 6,
#   'rank': 4356},
#  {'song_name': 'Sulfur',
#   'difficulty': 'PAST',
#   'level': 4,
#   'best_clear_type': 'Pure Memory',
#   'score': 10000453,
#   'shiny_perfect_count': 453,
#   'perfect_count': 458,
#   'near_count': 0,
#   'miss_count': 0,
#   'rank': 230},
#  {'song_name': 'Sulfur',
#   'difficulty': 'PRESENT',
#   'level': 6,
#   'best_clear_type': 'Pure Memory',
#   'score': 10000588,
#   'shiny_perfect_count': 588,
#   'perfect_count': 608,
#   'near_count': 0,
#   'miss_count': 0,
#   'rank': 539},
#  {'song_name': 'Sulfur',
#   'difficulty': 'FUTURE',
#   'level': 9,
#   'best_clear_type': 'Track Complete (Hard Gauge)',
#   'score': 9718511,
#   'shiny_perfect_count': 808,
#   'perfect_count': 1001,
#   'near_count': 29,
#   'miss_count': 15,
#   'rank': 11170},
#  {'song_name': 'Halcyon',
#   'difficulty': 'PAST',
#   'level': 5,
#   'best_clear_type': 'Pure Memory',
#   'score': 10000654,
#   'shiny_perfect_count': 654,
#   'perfect_count': 662,
#   'near_count': 0,
#   'miss_count': 0,
#   'rank': 130},
#  {'song_name': 'Halcyon',
#   'difficulty': 'PRESENT',
#   'level': 8,
#   'best_clear_type': 'Pure Memory',
#   'score': 10000890,
#   'shiny_perfect_count': 890,
#   'perfect_count': 943,
#   'near_count': 0,
#   'miss_count': 0,
#   'rank': 966},
#  {'song_name': 'Halcyon',
#   'difficulty': 'FUTURE',
#   'level': 10,
#   'best_clear_type': 'Track Complete (Normal Gauge)',
#   'score': 9283757,
#   'shiny_perfect_count': 954,
#   'perfect_count': 1104,
#   'near_count': 70,
#   'miss_count': 53,
#   'rank': 10817},
#  {'song_name': 'Ether Strike',
#   'difficulty': 'PAST',
#   'level': 5,
#   'best_clear_type': 'Pure Memory',
#   'score': 10000653,
#   'shiny_perfect_count': 653,
#   'perfect_count': 659,
#   'near_count': 0,
#   'miss_count': 0,
#   'rank': 92},
#  {'song_name': 'Ether Strike',
#   'difficulty': 'PRESENT',
#   'level': 8,
#   'best_clear_type': 'Pure Memory',
#   'score': 10000810,
#   'shiny_perfect_count': 810,
#   'perfect_count': 837,
#   'near_count': 0,
#   'miss_count': 0,
#   'rank': 241},
#  {'song_name': 'Ether Strike',
#   'difficulty': 'FUTURE',
#   'level': 10,
#   'best_clear_type': 'Track Complete (Normal Gauge)',
#   'score': 9765926,
#   'shiny_perfect_count': 969,
#   'perfect_count': 1126,
#   'near_count': 33,
#   'miss_count': 11,
#   'rank': 5724},
#  {'song_name': 'Fracture Ray',
#   'difficulty': 'PAST',
#   'level': 6,
#   'best_clear_type': 'Pure Memory',
#   'score': 10000973,
#   'shiny_perfect_count': 973,
#   'perfect_count': 983,
#   'near_count': 0,
#   'miss_count': 0,
#   'rank': 100},
#  {'song_name': 'Fracture Ray',
#   'difficulty': 'PRESENT',
#   'level': 9,
#   'best_clear_type': 'Track Complete (Hard Gauge)',
#   'score': 9956581,
#   'shiny_perfect_count': 1258,
#   'perfect_count': 1334,
#   'near_count': 6,
#   'miss_count': 3,
#   'rank': 1839},
#  {'song_name': 'Fracture Ray',
#   'difficulty': 'FUTURE',
#   'level': 11,
#   'best_clear_type': 'Track Lost',
#   'score': 8847701,
#   'shiny_perfect_count': 946,
#   'perfect_count': 1084,
#   'near_count': 95,
#   'miss_count': 100,
#   'rank': 8845},
#  {'song_name': 'Suomi',
#   'difficulty': 'PAST',
#   'level': 2,
#   'best_clear_type': 'Pure Memory',
#   'score': 10000366,
#   'shiny_perfect_count': 366,
#   'perfect_count': 368,
#   'near_count': 0,
#   'miss_count': 0,
#   'rank': 505},
#  {'song_name': 'Suomi',
#   'difficulty': 'PRESENT',
#   'level': 5,
#   'best_clear_type': 'Pure Memory',
#   'score': 10000526,
#   'shiny_perfect_count': 526,
#   'perfect_count': 550,
#   'near_count': 0,
#   'miss_count': 0,
#   'rank': 1030},
#  {'song_name': 'Suomi',
#   'difficulty': 'FUTURE',
#   'level': 7,
#   'best_clear_type': 'Pure Memory',
#   'score': 10000794,
#   'shiny_perfect_count': 794,
#   'perfect_count': 818,
#   'near_count': 0,
#   'miss_count': 0,
#   'rank': 4134},
#  {'song_name': 'Bookmaker (2D Version)',
#   'difficulty': 'PAST',
#   'level': 4,
#   'best_clear_type': 'Pure Memory',
#   'score': 10000531,
#   'shiny_perfect_count': 531,
#   'perfect_count': 538,
#   'near_count': 0,
#   'miss_count': 0,
#   'rank': 291},
#  {'song_name': 'Bookmaker (2D Version)',
#   'difficulty': 'PRESENT',
#   'level': 6,
#   'best_clear_type': 'Pure Memory',
#   'score': 10000707,
#   'shiny_perfect_count': 707,
#   'perfect_count': 728,
#   'near_count': 0,
#   'miss_count': 0,
#   'rank': 340},
#  {'song_name': 'Bookmaker (2D Version)',
#   'difficulty': 'FUTURE',
#   'level': 8,
#   'best_clear_type': 'Pure Memory',
#   'score': 10001106,
#   'shiny_perfect_count': 1106,
#   'perfect_count': 1124,
#   'near_count': 0,
#   'miss_count': 0,
#   'rank': 570},
#  {'song_name': 'Illegal Paradise',
#   'difficulty': 'PAST',
#   'level': 2,
#   'best_clear_type': 'Pure Memory',
#   'score': 10000535,
#   'shiny_perfect_count': 535,
#   'perfect_count': 535,
#   'near_count': 0,
#   'miss_count': 0,
#   'rank': 117},
#  {'song_name': 'Illegal Paradise',
#   'difficulty': 'PRESENT',
#   'level': 7,
#   'best_clear_type': 'Pure Memory',
#   'score': 10000563,
#   'shiny_perfect_count': 563,
#   'perfect_count': 585,
#   'near_count': 0,
#   'miss_count': 0,
#   'rank': 659},
#  {'song_name': 'Illegal Paradise',
#   'difficulty': 'FUTURE',
#   'level': 9,
#   'best_clear_type': 'Track Complete (Hard Gauge)',
#   'score': 9835953,
#   'shiny_perfect_count': 892,
#   'perfect_count': 1033,
#   'near_count': 21,
#   'miss_count': 7,
#   'rank': 7640},
#  {'song_name': 'dropdead', 'difficulty': 'PAST', 'level': 1},
#  {'song_name': 'dropdead', 'difficulty': 'PRESENT', 'level': 9},
#  {'song_name': 'dropdead', 'difficulty': 'FUTURE', 'level': 8},
#  {'song_name': 'Fallensquare',
#   'difficulty': 'PAST',
#   'level': 3,
#   'best_clear_type': 'Pure Memory',
#   'score': 10000314,
#   'shiny_perfect_count': 314,
#   'perfect_count': 316,
#   'near_count': 0,
#   'miss_count': 0,
#   'rank': 50},
#  {'song_name': 'Fallensquare',
#   'difficulty': 'PRESENT',
#   'level': 7,
#   'best_clear_type': 'Pure Memory',
#   'score': 10000473,
#   'shiny_perfect_count': 473,
#   'perfect_count': 486,
#   'near_count': 0,
#   'miss_count': 0,
#   'rank': 114},
#  {'song_name': 'Fallensquare',
#   'difficulty': 'FUTURE',
#   'level': 9,
#   'best_clear_type': 'Track Complete (Hard Gauge)',
#   'score': 9502660,
#   'shiny_perfect_count': 527,
#   'perfect_count': 648,
#   'near_count': 40,
#   'miss_count': 15,
#   'rank': 4581},
#  {'song_name': 'Nhelv',
#   'difficulty': 'PAST',
#   'level': 3,
#   'best_clear_type': 'Pure Memory',
#   'score': 10000647,
#   'shiny_perfect_count': 647,
#   'perfect_count': 647,
#   'near_count': 0,
#   'miss_count': 0,
#   'rank': 11},
#  {'song_name': 'Nhelv',
#   'difficulty': 'PRESENT',
#   'level': 6,
#   'best_clear_type': 'Pure Memory',
#   'score': 10000884,
#   'shiny_perfect_count': 884,
#   'perfect_count': 913,
#   'near_count': 0,
#   'miss_count': 0,
#   'rank': 566},
#  {'song_name': 'Nhelv',
#   'difficulty': 'FUTURE',
#   'level': 9,
#   'best_clear_type': 'Track Complete (Hard Gauge)',
#   'score': 9824972,
#   'shiny_perfect_count': 965,
#   'perfect_count': 1079,
#   'near_count': 19,
#   'miss_count': 10,
#   'rank': 3717},
#  {'song_name': 'LunarOrbit -believe in the Espebranch road-',
#   'difficulty': 'PAST',
#   'level': 3,
#   'best_clear_type': 'Pure Memory',
#   'score': 10000623,
#   'shiny_perfect_count': 623,
#   'perfect_count': 624,
#   'near_count': 0,
#   'miss_count': 0,
#   'rank': 64},
#  {'song_name': 'LunarOrbit -believe in the Espebranch road-',
#   'difficulty': 'PRESENT',
#   'level': 6,
#   'best_clear_type': 'Pure Memory',
#   'score': 10000746,
#   'shiny_perfect_count': 746,
#   'perfect_count': 757,
#   'near_count': 0,
#   'miss_count': 0,
#   'rank': 280},
#  {'song_name': 'LunarOrbit -believe in the Espebranch road-',
#   'difficulty': 'FUTURE',
#   'level': 9,
#   'best_clear_type': 'Track Complete (Hard Gauge)',
#   'score': 9840226,
#   'shiny_perfect_count': 907,
#   'perfect_count': 1034,
#   'near_count': 14,
#   'miss_count': 10,
#   'rank': 4742},
#  {'song_name': 'Purgatorium',
#   'difficulty': 'PAST',
#   'level': 2,
#   'best_clear_type': 'Pure Memory',
#   'score': 10000605,
#   'shiny_perfect_count': 605,
#   'perfect_count': 609,
#   'near_count': 0,
#   'miss_count': 0,
#   'rank': 409},
#  {'song_name': 'Purgatorium',
#   'difficulty': 'PRESENT',
#   'level': 6,
#   'best_clear_type': 'Pure Memory',
#   'score': 10000621,
#   'shiny_perfect_count': 621,
#   'perfect_count': 641,
#   'near_count': 0,
#   'miss_count': 0,
#   'rank': 460},
#  {'song_name': 'Purgatorium',
#   'difficulty': 'FUTURE',
#   'level': 8,
#   'best_clear_type': 'Full Recall',
#   'score': 9975493,
#   'shiny_perfect_count': 926,
#   'perfect_count': 978,
#   'near_count': 5,
#   'miss_count': 0,
#   'rank': 5377},
#  {'song_name': 'Hikari', 'difficulty': 'PAST', 'level': 2},
#  {'song_name': 'Hikari', 'difficulty': 'PRESENT', 'level': 6},
#  {'song_name': 'Hikari', 'difficulty': 'FUTURE', 'level': 8},
#  {'song_name': 'STAGER (ALL STAGE CLEAR)', 'difficulty': 'PAST', 'level': 3},
#  {'song_name': 'STAGER (ALL STAGE CLEAR)',
#   'difficulty': 'PRESENT',
#   'level': 6},
#  {'song_name': 'STAGER (ALL STAGE CLEAR)', 'difficulty': 'FUTURE', 'level': 9},
#  {'song_name': 'Hall of Mirrors', 'difficulty': 'PAST', 'level': 3},
#  {'song_name': 'Hall of Mirrors', 'difficulty': 'PRESENT', 'level': 5},
#  {'song_name': 'Hall of Mirrors', 'difficulty': 'FUTURE', 'level': 8},
#  {'song_name': 'Linear Accelerator', 'difficulty': 'PAST', 'level': 2},
#  {'song_name': 'Linear Accelerator', 'difficulty': 'PRESENT', 'level': 6},
#  {'song_name': 'Linear Accelerator', 'difficulty': 'FUTURE', 'level': 9},
#  {'song_name': 'Tiferet', 'difficulty': 'PAST', 'level': 4},
#  {'song_name': 'Tiferet', 'difficulty': 'PRESENT', 'level': 7},
#  {'song_name': 'Tiferet', 'difficulty': 'FUTURE', 'level': 10},
#  {'song_name': 'Alexandrite',
#   'difficulty': 'PAST',
#   'level': 4,
#   'best_clear_type': 'Pure Memory',
#   'score': 10000498,
#   'shiny_perfect_count': 498,
#   'perfect_count': 507,
#   'near_count': 0,
#   'miss_count': 0,
#   'rank': 190},
#  {'song_name': 'Alexandrite',
#   'difficulty': 'PRESENT',
#   'level': 7,
#   'best_clear_type': 'Pure Memory',
#   'score': 10000666,
#   'shiny_perfect_count': 666,
#   'perfect_count': 699,
#   'near_count': 0,
#   'miss_count': 0,
#   'rank': 250},
#  {'song_name': 'Alexandrite',
#   'difficulty': 'FUTURE',
#   'level': 9,
#   'best_clear_type': 'Track Complete (Hard Gauge)',
#   'score': 9635435,
#   'shiny_perfect_count': 820,
#   'perfect_count': 982,
#   'near_count': 40,
#   'miss_count': 18,
#   'rank': 6889},
#  {'song_name': 'Rugie',
#   'difficulty': 'PAST',
#   'level': 3,
#   'best_clear_type': 'Pure Memory',
#   'score': 10000561,
#   'shiny_perfect_count': 561,
#   'perfect_count': 566,
#   'near_count': 0,
#   'miss_count': 0,
#   'rank': 413},
#  {'song_name': 'Rugie',
#   'difficulty': 'PRESENT',
#   'level': 6,
#   'best_clear_type': 'Pure Memory',
#   'score': 10000739,
#   'shiny_perfect_count': 739,
#   'perfect_count': 754,
#   'near_count': 0,
#   'miss_count': 0,
#   'rank': 224},
#  {'song_name': 'Rugie',
#   'difficulty': 'FUTURE',
#   'level': 9,
#   'best_clear_type': 'Track Complete (Hard Gauge)',
#   'score': 9923987,
#   'shiny_perfect_count': 911,
#   'perfect_count': 964,
#   'near_count': 7,
#   'miss_count': 4,
#   'rank': 5328},
#  {'song_name': 'Astral tale', 'difficulty': 'PAST', 'level': 4},
#  {'song_name': 'Astral tale', 'difficulty': 'PRESENT', 'level': 7},
#  {'song_name': 'Astral tale', 'difficulty': 'FUTURE', 'level': 9},
#  {'song_name': 'Phantasia', 'difficulty': 'PAST', 'level': 4},
#  {'song_name': 'Phantasia', 'difficulty': 'PRESENT', 'level': 5},
#  {'song_name': 'Phantasia', 'difficulty': 'FUTURE', 'level': 9},
#  {'song_name': 'Empire of Winter',
#   'difficulty': 'PAST',
#   'level': 3,
#   'best_clear_type': 'Pure Memory',
#   'score': 10000475,
#   'shiny_perfect_count': 475,
#   'perfect_count': 484,
#   'near_count': 0,
#   'miss_count': 0,
#   'rank': 529},
#  {'song_name': 'Empire of Winter',
#   'difficulty': 'PRESENT',
#   'level': 6,
#   'best_clear_type': 'Pure Memory',
#   'score': 10000640,
#   'shiny_perfect_count': 640,
#   'perfect_count': 662,
#   'near_count': 0,
#   'miss_count': 0,
#   'rank': 319},
#  {'song_name': 'Empire of Winter',
#   'difficulty': 'FUTURE',
#   'level': 9,
#   'best_clear_type': 'Full Recall',
#   'score': 9995448,
#   'shiny_perfect_count': 883,
#   'perfect_count': 919,
#   'near_count': 1,
#   'miss_count': 0,
#   'rank': 1850},
#  {'song_name': 'MERLIN', 'difficulty': 'PAST', 'level': 3},
#  {'song_name': 'MERLIN', 'difficulty': 'PRESENT', 'level': 5},
#  {'song_name': 'MERLIN', 'difficulty': 'FUTURE', 'level': 8},
#  {'song_name': 'DX Choseinou Full Metal Shojo',
#   'difficulty': 'PAST',
#   'level': 3},
#  {'song_name': 'DX Choseinou Full Metal Shojo',
#   'difficulty': 'PRESENT',
#   'level': 6},
#  {'song_name': 'DX Choseinou Full Metal Shojo',
#   'difficulty': 'FUTURE',
#   'level': 9},
#  {'song_name': 'OMAKENO Stroke', 'difficulty': 'PAST', 'level': 3},
#  {'song_name': 'OMAKENO Stroke', 'difficulty': 'PRESENT', 'level': 6},
#  {'song_name': 'OMAKENO Stroke', 'difficulty': 'FUTURE', 'level': 9},
#  {'song_name': 'Scarlet Lance', 'difficulty': 'PAST', 'level': 4},
#  {'song_name': 'Scarlet Lance', 'difficulty': 'PRESENT', 'level': 7},
#  {'song_name': 'Scarlet Lance', 'difficulty': 'FUTURE', 'level': 10},
#  {'song_name': 'ouroboros -twin stroke of the end-',
#   'difficulty': 'PAST',
#   'level': 4},
#  {'song_name': 'ouroboros -twin stroke of the end-',
#   'difficulty': 'PRESENT',
#   'level': 7},
#  {'song_name': 'ouroboros -twin stroke of the end-',
#   'difficulty': 'FUTURE',
#   'level': 10},
#  {'song_name': 'Libertas', 'difficulty': 'PAST', 'level': 3},
#  {'song_name': 'Libertas', 'difficulty': 'PRESENT', 'level': 5},
#  {'song_name': 'Libertas', 'difficulty': 'FUTURE', 'level': 9},
#  {'song_name': 'Solitary Dream',
#   'difficulty': 'PAST',
#   'level': 4,
#   'best_clear_type': 'Pure Memory',
#   'score': 10000706,
#   'shiny_perfect_count': 706,
#   'perfect_count': 712,
#   'near_count': 0,
#   'miss_count': 0,
#   'rank': 275},
#  {'song_name': 'Solitary Dream',
#   'difficulty': 'PRESENT',
#   'level': 7,
#   'best_clear_type': 'Pure Memory',
#   'score': 10000834,
#   'shiny_perfect_count': 834,
#   'perfect_count': 854,
#   'near_count': 0,
#   'miss_count': 0,
#   'rank': 322},
#  {'song_name': 'Solitary Dream',
#   'difficulty': 'FUTURE',
#   'level': 8,
#   'best_clear_type': 'Full Recall',
#   'score': 9975186,
#   'shiny_perfect_count': 907,
#   'perfect_count': 967,
#   'near_count': 5,
#   'miss_count': 0,
#   'rank': 2867},
#  {'song_name': 'Antithese', 'difficulty': 'PAST', 'level': 2},
#  {'song_name': 'Antithese', 'difficulty': 'PRESENT', 'level': 5},
#  {'song_name': 'Antithese', 'difficulty': 'FUTURE', 'level': 8},
#  {'song_name': 'Corruption', 'difficulty': 'PAST', 'level': 3},
#  {'song_name': 'Corruption', 'difficulty': 'PRESENT', 'level': 6},
#  {'song_name': 'Corruption', 'difficulty': 'FUTURE', 'level': 9},
#  {'song_name': 'Black Territory', 'difficulty': 'PAST', 'level': 3},
#  {'song_name': 'Black Territory', 'difficulty': 'PRESENT', 'level': 7},
#  {'song_name': 'Black Territory', 'difficulty': 'FUTURE', 'level': 9},
#  {'song_name': 'Vicious Heroism', 'difficulty': 'PAST', 'level': 4},
#  {'song_name': 'Vicious Heroism', 'difficulty': 'PRESENT', 'level': 7},
#  {'song_name': 'Vicious Heroism', 'difficulty': 'FUTURE', 'level': 9},
#  {'song_name': 'Cyaegha', 'difficulty': 'PAST', 'level': 5},
#  {'song_name': 'Cyaegha', 'difficulty': 'PRESENT', 'level': 8},
#  {'song_name': 'Cyaegha', 'difficulty': 'FUTURE', 'level': 10},
#  {'song_name': 'ReviXy',
#   'difficulty': 'PAST',
#   'level': 3,
#   'best_clear_type': 'Pure Memory',
#   'score': 10000531,
#   'shiny_perfect_count': 531,
#   'perfect_count': 538,
#   'near_count': 0,
#   'miss_count': 0,
#   'rank': 322},
#  {'song_name': 'ReviXy',
#   'difficulty': 'PRESENT',
#   'level': 6,
#   'best_clear_type': 'Pure Memory',
#   'score': 10000708,
#   'shiny_perfect_count': 708,
#   'perfect_count': 729,
#   'near_count': 0,
#   'miss_count': 0,
#   'rank': 122},
#  {'song_name': 'ReviXy',
#   'difficulty': 'FUTURE',
#   'level': 8,
#   'best_clear_type': 'Full Recall',
#   'score': 9977100,
#   'shiny_perfect_count': 978,
#   'perfect_count': 1043,
#   'near_count': 3,
#   'miss_count': 1,
#   'rank': 1486},
#  {'song_name': 'Grimheart',
#   'difficulty': 'PAST',
#   'level': 2,
#   'best_clear_type': 'Pure Memory',
#   'score': 10000727,
#   'shiny_perfect_count': 727,
#   'perfect_count': 728,
#   'near_count': 0,
#   'miss_count': 0,
#   'rank': 68},
#  {'song_name': 'Grimheart',
#   'difficulty': 'PRESENT',
#   'level': 5,
#   'best_clear_type': 'Pure Memory',
#   'score': 10000687,
#   'shiny_perfect_count': 687,
#   'perfect_count': 699,
#   'near_count': 0,
#   'miss_count': 0,
#   'rank': 199},
#  {'song_name': 'Grimheart',
#   'difficulty': 'FUTURE',
#   'level': 8,
#   'best_clear_type': 'Full Recall',
#   'score': 9974835,
#   'shiny_perfect_count': 904,
#   'perfect_count': 956,
#   'near_count': 1,
#   'miss_count': 2,
#   'rank': 2067}]

# %%
with open('arcaea result.csv', 'w', newline="\n", encoding='utf-8') as csv_f:
    fieldnames = ['song_name', 'difficulty', 'level', 'score', 'shiny_perfect_count', 'perfect_count', 'near_count', 'miss_count', 'best_clear_type', 'rank']
    writer = csv.DictWriter(csv_f, fieldnames=fieldnames)
    writer.writeheader()
    for song in song_rlt:
        writer.writerow(song)
